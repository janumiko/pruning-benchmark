# %%
import torch
import torch.nn as nn

from pathlib import Path
from constants import DATA_PATH, MODELS_PATH
from LeNet import LeNet, BATCH_SIZE
import utility
import json
from utility import (
    calculate_total_sparsity,
    get_parameters_to_prune,
)
from utility.cifar_dataset import get_dataloaders

# %%
train_loader, validation_loader, test_loader = get_dataloaders(
    data_path=DATA_PATH, batch_size=BATCH_SIZE
)

# %%
# Get cpu, gpu or mps device for training.
device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")
print(f"Using {torch.cuda.get_device_name(torch.cuda.current_device())}")
# Out:
# Using NVIDIA GeForce GTX 1660 Ti

# %%
base_model = LeNet().to(device)

# Define the loss function
cross_entropy = nn.CrossEntropyLoss()

# %% [markdown]
# ### Load models

# %%
models = []

for file in Path(MODELS_PATH).iterdir():
    if not file.is_dir():
        continue

    for inner_file in file.iterdir():
        if not inner_file.is_file():
            continue
        match inner_file.suffix:
            case ".pth":
                model = LeNet().to(device)
                model.load_state_dict(torch.load(inner_file))
            case ".json":
                metadata = json.load(inner_file.open())
    models.append((model, metadata, file.stem))

# %% [markdown]
# ### Test the models

# %%
results = []
for model, meta, _ in models:
    test_loss, accuracy = utility.training.test(
        model=model, test_dl=test_loader, loss_function=cross_entropy, device=device
    )
    results.append((*meta.values(), accuracy))

# %%
import pandas as pd

columns = [*models[0][1].keys(), "accuracy"]
result_df = (
    pd.DataFrame.from_records(results, columns=columns)
    .sort_values(by="accuracy", ascending=False)
    .reset_index(drop=True)
)
result_df
# Out:
#     total_pruned  pruning_step  finetune_epochs          method  \
# 0           0.60          0.60                4  L1Unstructured
# 1           0.40          0.04                1  L1Unstructured
# 2           0.20          0.04                3  L1Unstructured
# 3           0.60          0.04                1  L1Unstructured
# 4           0.40          0.02                1  L1Unstructured
# ..           ...           ...              ...             ...
# 87          0.96          0.01                2  L1Unstructured
# 88          0.92          0.01                3  L1Unstructured
# 89          0.96          0.01                3  L1Unstructured
# 90          0.92          0.01                4  L1Unstructured
# 91          0.96          0.01                4  L1Unstructured
#
#     early_stopping  accuracy
# 0             True     90.63
# 1            False     90.52
# 2            False     90.50
# 3            False     90.43
# 4            False     90.39
# ..             ...       ...
# 87           False     79.42
# 88           False     76.51
# 89           False     56.29
# 90           False     47.76
# 91           False     19.71
#
# [92 rows x 6 columns]

# %% [markdown]
# ### Print models sparsity.

# %%
for model, _, name in models:
    print(f"Calculating sparsity for {name}")
    print(
        f"Total sparsity: {100 - calculate_total_sparsity(model, get_parameters_to_prune(model)):.2f}%"
    )
    print("-" * 20)
# Out:
# Calculating sparsity for LeNet_iterative_pruned_0.92_step_0
# Total sparsity: 7.96%
# --------------------
# Calculating sparsity for LeNet_pruned_0
# Total sparsity: 60.00%
# --------------------
# Calculating sparsity for LeNet_iterative_pruned_0.96_step_0
# Total sparsity: 3.95%
# --------------------
# Calculating sparsity for LeNet_iterative_pruned_0.88_step_0
# Total sparsity: 11.96%
# --------------------
# Calculating sparsity for LeNet_iterative_pruned_0.8_step_0
# Total sparsity: 20.03%
# --------------------
# Calculating sparsity for LeNet_pruned_0
# Total sparsity: 12.00%
# --------------------
# Calculating sparsity for LeNet_iterative_pruned_0.96_step_0
# Total sparsity: 3.95%
# --------------------
# Calculating sparsity for LeNet_iterative_pruned_0.96_step_0
# Total sparsity: 4.03%
# --------------------
# Calculating sparsity for LeNet_iterative_pruned_0.8_step_0
# Total sparsity: 19.96%
# --------------------
# Calculating sparsity for LeNet_iterative_pruned_0.88_step_0
# Total sparsity: 11.99%
# --------------------
# Calculating sparsity for LeNet_iterative_pruned_0.96_step_0
# Total sparsity: 3.99%
# --------------------
# Calculating sparsity for LeNet_iterative_pruned_0.8_step_0
# Total sparsity: 20.03%
# --------------------
# Calculating sparsity for LeNet_iterative_pruned_0.4_step_0
# Total sparsity: 59.98%
# --------------------
# Calculating sparsity for LeNet_iterative_pruned_0.6_step_0
# Total sparsity: 40.02%
# --------------------
# Calculating sparsity for LeNet_pruned_0
# Total sparsity: 4.00%
# --------------------
# Calculating sparsity for LeNet_iterative_pruned_0.88_step_0
# Total sparsity: 12.03%
# --------------------
# Calculating sparsity for LeNet_fmnist
# Total sparsity: 100.00%
# --------------------
# Calculating sparsity for LeNet_iterative_pruned_0.96_step_0
# Total sparsity: 4.03%
# --------------------
# Calculating sparsity for LeNet_iterative_pruned_0.88_step_0
# Total sparsity: 11.96%
# --------------------
# Calculating sparsity for LeNet_iterative_pruned_0.92_step_0
# Total sparsity: 8.03%
# --------------------
# Calculating sparsity for LeNet_iterative_pruned_0.8_step_0
# Total sparsity: 19.96%
# --------------------
# Calculating sparsity for LeNet_iterative_pruned_0.88_step_0
# Total sparsity: 11.99%
# --------------------
# Calculating sparsity for LeNet_iterative_pruned_0.2_step_0
# Total sparsity: 79.99%
# --------------------
# Calculating sparsity for LeNet_iterative_pruned_0.8_step_0
# Total sparsity: 20.03%
# --------------------
# Calculating sparsity for LeNet_iterative_pruned_0.88_step_0
# Total sparsity: 12.03%
# --------------------
# Calculating sparsity for LeNet_iterative_pruned_0.4_step_0
# Total sparsity: 60.01%
# --------------------
# Calculating sparsity for LeNet_iterative_pruned_0.6_step_0
# Total sparsity: 39.97%
# --------------------
# Calculating sparsity for LeNet_iterative_pruned_0.92_step_0
# Total sparsity: 7.99%
# --------------------
# Calculating sparsity for LeNet_iterative_pruned_0.96_step_0
# Total sparsity: 3.99%
# --------------------
# Calculating sparsity for LeNet_iterative_pruned_0.92_step_0
# Total sparsity: 8.03%
# --------------------
# Calculating sparsity for LeNet_iterative_pruned_0.6_step_0
# Total sparsity: 40.02%
# --------------------
# Calculating sparsity for LeNet_iterative_pruned_0.92_step_0
# Total sparsity: 8.03%
# --------------------
# Calculating sparsity for LeNet_iterative_pruned_0.88_step_0
# Total sparsity: 11.99%
# --------------------
# Calculating sparsity for LeNet_iterative_pruned_0.92_step_0
# Total sparsity: 8.03%
# --------------------
# Calculating sparsity for LeNet_iterative_pruned_0.4_step_0
# Total sparsity: 60.01%
# --------------------
# Calculating sparsity for LeNet_iterative_pruned_0.92_step_0
# Total sparsity: 7.99%
# --------------------
# Calculating sparsity for LeNet_iterative_pruned_0.2_step_0
# Total sparsity: 80.00%
# --------------------
# Calculating sparsity for LeNet_iterative_pruned_0.96_step_0
# Total sparsity: 3.99%
# --------------------
# Calculating sparsity for LeNet_iterative_pruned_0.4_step_0
# Total sparsity: 59.98%
# --------------------
# Calculating sparsity for LeNet_iterative_pruned_0.6_step_0
# Total sparsity: 39.97%
# --------------------
# Calculating sparsity for LeNet_iterative_pruned_0.4_step_0
# Total sparsity: 59.98%
# --------------------
# Calculating sparsity for LeNet_iterative_pruned_0.8_step_0
# Total sparsity: 19.99%
# --------------------
# Calculating sparsity for LeNet_iterative_pruned_0.88_step_0
# Total sparsity: 11.96%
# --------------------
# Calculating sparsity for LeNet_iterative_pruned_0.4_step_0
# Total sparsity: 60.00%
# --------------------
# Calculating sparsity for LeNet_pruned_0
# Total sparsity: 20.00%
# --------------------
# Calculating sparsity for LeNet_iterative_pruned_0.4_step_0
# Total sparsity: 60.01%
# --------------------
# Calculating sparsity for LeNet_pruned_0
# Total sparsity: 40.00%
# --------------------
# Calculating sparsity for LeNet_iterative_pruned_0.96_step_0
# Total sparsity: 4.03%
# --------------------
# Calculating sparsity for LeNet_iterative_pruned_0.2_step_0
# Total sparsity: 79.99%
# --------------------
# Calculating sparsity for LeNet_iterative_pruned_0.2_step_0
# Total sparsity: 80.00%
# --------------------
# Calculating sparsity for LeNet_iterative_pruned_0.6_step_0
# Total sparsity: 39.97%
# --------------------
# Calculating sparsity for LeNet_iterative_pruned_0.8_step_0
# Total sparsity: 19.96%
# --------------------
# Calculating sparsity for LeNet_pruned_0
# Total sparsity: 8.00%
# --------------------
# Calculating sparsity for LeNet_iterative_pruned_0.2_step_0
# Total sparsity: 80.01%
# --------------------
# Calculating sparsity for LeNet_iterative_pruned_0.8_step_0
# Total sparsity: 19.99%
# --------------------
# Calculating sparsity for LeNet_iterative_pruned_0.6_step_0
# Total sparsity: 40.00%
# --------------------
# Calculating sparsity for LeNet_iterative_pruned_0.4_step_0
# Total sparsity: 60.00%
# --------------------
# Calculating sparsity for LeNet_iterative_pruned_0.6_step_0
# Total sparsity: 40.00%
# --------------------
# Calculating sparsity for LeNet_iterative_pruned_0.6_step_0
# Total sparsity: 40.02%
# --------------------
# Calculating sparsity for LeNet_iterative_pruned_0.2_step_0
# Total sparsity: 80.01%
# --------------------
# Calculating sparsity for LeNet_iterative_pruned_0.88_step_0
# Total sparsity: 11.96%
# --------------------
# Calculating sparsity for LeNet_iterative_pruned_0.92_step_0
# Total sparsity: 7.99%
# --------------------
# Calculating sparsity for LeNet_iterative_pruned_0.4_step_0
# Total sparsity: 60.00%
# --------------------
# Calculating sparsity for LeNet_iterative_pruned_0.6_step_0
# Total sparsity: 39.97%
# --------------------
# Calculating sparsity for LeNet_iterative_pruned_0.4_step_0
# Total sparsity: 59.98%
# --------------------
# Calculating sparsity for LeNet_iterative_pruned_0.2_step_0
# Total sparsity: 80.00%
# --------------------
# Calculating sparsity for LeNet_iterative_pruned_0.6_step_0
# Total sparsity: 40.00%
# --------------------
# Calculating sparsity for LeNet_iterative_pruned_0.6_step_0
# Total sparsity: 40.00%
# --------------------
# Calculating sparsity for LeNet_iterative_pruned_0.2_step_0
# Total sparsity: 80.01%
# --------------------
# Calculating sparsity for LeNet_iterative_pruned_0.4_step_0
# Total sparsity: 60.00%
# --------------------
# Calculating sparsity for LeNet_iterative_pruned_0.88_step_0
# Total sparsity: 12.03%
# --------------------
# Calculating sparsity for LeNet_iterative_pruned_0.96_step_0
# Total sparsity: 3.95%
# --------------------
# Calculating sparsity for LeNet_iterative_pruned_0.2_step_0
# Total sparsity: 80.00%
# --------------------
# Calculating sparsity for LeNet_iterative_pruned_0.8_step_0
# Total sparsity: 19.99%
# --------------------
# Calculating sparsity for LeNet_iterative_pruned_0.6_step_0
# Total sparsity: 40.02%
# --------------------
# Calculating sparsity for LeNet_iterative_pruned_0.8_step_0
# Total sparsity: 19.96%
# --------------------
# Calculating sparsity for LeNet_iterative_pruned_0.2_step_0
# Total sparsity: 80.01%
# --------------------
# Calculating sparsity for LeNet_iterative_pruned_0.8_step_0
# Total sparsity: 19.99%
# --------------------
# Calculating sparsity for LeNet_iterative_pruned_0.88_step_0
# Total sparsity: 12.03%
# --------------------
# Calculating sparsity for LeNet_iterative_pruned_0.96_step_0
# Total sparsity: 3.95%
# --------------------
# Calculating sparsity for LeNet_iterative_pruned_0.2_step_0
# Total sparsity: 79.99%
# --------------------
# Calculating sparsity for LeNet_pruned_0
# Total sparsity: 80.00%
# --------------------
# Calculating sparsity for LeNet_iterative_pruned_0.92_step_0
# Total sparsity: 7.96%
# --------------------
# Calculating sparsity for LeNet_iterative_pruned_0.92_step_0
# Total sparsity: 7.99%
# --------------------
# Calculating sparsity for LeNet_iterative_pruned_0.4_step_0
# Total sparsity: 60.01%
# --------------------
# Calculating sparsity for LeNet_iterative_pruned_0.92_step_0
# Total sparsity: 7.96%
# --------------------
# Calculating sparsity for LeNet_iterative_pruned_0.8_step_0
# Total sparsity: 20.03%
# --------------------
# Calculating sparsity for LeNet_iterative_pruned_0.2_step_0
# Total sparsity: 79.99%
# --------------------
# Calculating sparsity for LeNet_iterative_pruned_0.92_step_0
# Total sparsity: 7.96%
# --------------------
# Calculating sparsity for LeNet_iterative_pruned_0.88_step_0
# Total sparsity: 11.99%
# --------------------
# Calculating sparsity for LeNet_iterative_pruned_0.96_step_0
# Total sparsity: 3.99%
# --------------------
# Calculating sparsity for LeNet_iterative_pruned_0.96_step_0
# Total sparsity: 4.03%
# --------------------

# %% [markdown]
# ### Visualize tables with the results

# %%
base_result = result_df[result_df["total_pruned"] == 0.0]
base_result
# Out:
#     total_pruned  pruning_step  finetune_epochs method  early_stopping  \
# 67           0.0           0.0               12   None            True
#
#     accuracy
# 67     89.04

# %%
one_shot_results = result_df[
    (result_df["total_pruned"] == result_df["pruning_step"])
    & (result_df["total_pruned"] != 0.0)
]
one_shot_results
# Out:
#     total_pruned  pruning_step  finetune_epochs          method  \
# 0           0.60          0.60                4  L1Unstructured
# 6           0.20          0.20                4  L1Unstructured
# 26          0.88          0.88                8  L1Unstructured
# 27          0.80          0.80                6  L1Unstructured
# 59          0.40          0.40                9  L1Unstructured
# 69          0.92          0.92               12  L1Unstructured
# 72          0.96          0.96               10  L1Unstructured
#
#     early_stopping  accuracy
# 0             True     90.63
# 6             True     90.27
# 26            True     89.99
# 27            True     89.94
# 59            True     89.25
# 69            True     88.91
# 72            True     88.61

# %%
iterative_results = result_df[result_df["total_pruned"] != result_df["pruning_step"]]
iterative_results
# Out:
#     total_pruned  pruning_step  finetune_epochs          method  \
# 1           0.40          0.04                1  L1Unstructured
# 2           0.20          0.04                3  L1Unstructured
# 3           0.60          0.04                1  L1Unstructured
# 4           0.40          0.02                1  L1Unstructured
# 5           0.40          0.04                4  L1Unstructured
# ..           ...           ...              ...             ...
# 87          0.96          0.01                2  L1Unstructured
# 88          0.92          0.01                3  L1Unstructured
# 89          0.96          0.01                3  L1Unstructured
# 90          0.92          0.01                4  L1Unstructured
# 91          0.96          0.01                4  L1Unstructured
#
#     early_stopping  accuracy
# 1            False     90.52
# 2            False     90.50
# 3            False     90.43
# 4            False     90.39
# 5            False     90.29
# ..             ...       ...
# 87           False     79.42
# 88           False     76.51
# 89           False     56.29
# 90           False     47.76
# 91           False     19.71
#
# [84 rows x 6 columns]

# %%
pruned_20 = result_df[result_df["total_pruned"] == 0.20].sort_values(
    by=["pruning_step", "finetune_epochs"], ascending=False
)
pruned_40 = result_df[result_df["total_pruned"] == 0.40].sort_values(
    by=["pruning_step", "finetune_epochs"], ascending=False
)
pruned_60 = result_df[result_df["total_pruned"] == 0.60].sort_values(
    by=["pruning_step", "finetune_epochs"], ascending=False
)
pruned_80 = result_df[result_df["total_pruned"] == 0.80].sort_values(
    by=["pruning_step", "finetune_epochs"], ascending=False
)
pruned_92 = result_df[result_df["total_pruned"] == 0.92].sort_values(
    by=["pruning_step", "finetune_epochs"], ascending=False
)
pruned_96 = result_df[result_df["total_pruned"] == 0.96].sort_values(
    by=["pruning_step", "finetune_epochs"], ascending=False
)

# %%
pruned_20
# Out:
#     total_pruned  pruning_step  finetune_epochs          method  \
# 6            0.2          0.20                4  L1Unstructured
# 22           0.2          0.04                4  L1Unstructured
# 2            0.2          0.04                3  L1Unstructured
# 14           0.2          0.04                2  L1Unstructured
# 49           0.2          0.04                1  L1Unstructured
# 17           0.2          0.02                4  L1Unstructured
# 7            0.2          0.02                3  L1Unstructured
# 16           0.2          0.02                2  L1Unstructured
# 15           0.2          0.02                1  L1Unstructured
# 25           0.2          0.01                4  L1Unstructured
# 32           0.2          0.01                3  L1Unstructured
# 58           0.2          0.01                2  L1Unstructured
# 18           0.2          0.01                1  L1Unstructured
#
#     early_stopping  accuracy
# 6             True     90.27
# 22           False     90.07
# 2            False     90.50
# 14           False     90.17
# 49           False     89.51
# 17           False     90.15
# 7            False     90.26
# 16           False     90.16
# 15           False     90.17
# 25           False     90.04
# 32           False     89.86
# 58           False     89.28
# 18           False     90.15

# %%
pruned_40
# Out:
#     total_pruned  pruning_step  finetune_epochs          method  \
# 59           0.4          0.40                9  L1Unstructured
# 5            0.4          0.04                4  L1Unstructured
# 43           0.4          0.04                3  L1Unstructured
# 31           0.4          0.04                2  L1Unstructured
# 1            0.4          0.04                1  L1Unstructured
# 34           0.4          0.02                4  L1Unstructured
# 45           0.4          0.02                3  L1Unstructured
# 33           0.4          0.02                2  L1Unstructured
# 4            0.4          0.02                1  L1Unstructured
# 13           0.4          0.01                4  L1Unstructured
# 48           0.4          0.01                3  L1Unstructured
# 52           0.4          0.01                2  L1Unstructured
# 11           0.4          0.01                1  L1Unstructured
#
#     early_stopping  accuracy
# 59            True     89.25
# 5            False     90.29
# 43           False     89.65
# 31           False     89.87
# 1            False     90.52
# 34           False     89.82
# 45           False     89.60
# 33           False     89.84
# 4            False     90.39
# 13           False     90.18
# 48           False     89.53
# 52           False     89.38
# 11           False     90.22

# %%
pruned_60
# Out:
#     total_pruned  pruning_step  finetune_epochs          method  \
# 0            0.6          0.60                4  L1Unstructured
# 20           0.6          0.04                4  L1Unstructured
# 23           0.6          0.04                3  L1Unstructured
# 19           0.6          0.04                2  L1Unstructured
# 3            0.6          0.04                1  L1Unstructured
# 28           0.6          0.02                4  L1Unstructured
# 37           0.6          0.02                3  L1Unstructured
# 53           0.6          0.02                2  L1Unstructured
# 8            0.6          0.02                1  L1Unstructured
# 56           0.6          0.01                4  L1Unstructured
# 63           0.6          0.01                3  L1Unstructured
# 40           0.6          0.01                2  L1Unstructured
# 38           0.6          0.01                1  L1Unstructured
#
#     early_stopping  accuracy
# 0             True     90.63
# 20           False     90.14
# 23           False     90.04
# 19           False     90.14
# 3            False     90.43
# 28           False     89.93
# 37           False     89.78
# 53           False     89.34
# 8            False     90.24
# 56           False     89.31
# 63           False     89.23
# 40           False     89.66
# 38           False     89.72

# %%
pruned_80
# Out:
#     total_pruned  pruning_step  finetune_epochs          method  \
# 27           0.8          0.80                6  L1Unstructured
# 50           0.8          0.04                4  L1Unstructured
# 12           0.8          0.04                3  L1Unstructured
# 24           0.8          0.04                2  L1Unstructured
# 9            0.8          0.04                1  L1Unstructured
# 51           0.8          0.02                4  L1Unstructured
# 29           0.8          0.02                3  L1Unstructured
# 35           0.8          0.02                2  L1Unstructured
# 39           0.8          0.02                1  L1Unstructured
# 71           0.8          0.01                4  L1Unstructured
# 66           0.8          0.01                3  L1Unstructured
# 55           0.8          0.01                2  L1Unstructured
# 44           0.8          0.01                1  L1Unstructured
#
#     early_stopping  accuracy
# 27            True     89.94
# 50           False     89.50
# 12           False     90.19
# 24           False     90.04
# 9            False     90.24
# 51           False     89.43
# 29           False     89.90
# 35           False     89.81
# 39           False     89.67
# 71           False     88.62
# 66           False     89.08
# 55           False     89.31
# 44           False     89.62

# %%
pruned_92
# Out:
#     total_pruned  pruning_step  finetune_epochs          method  \
# 69          0.92          0.92               12  L1Unstructured
# 64          0.92          0.04                4  L1Unstructured
# 30          0.92          0.04                3  L1Unstructured
# 46          0.92          0.04                2  L1Unstructured
# 62          0.92          0.04                1  L1Unstructured
# 78          0.92          0.02                4  L1Unstructured
# 75          0.92          0.02                3  L1Unstructured
# 65          0.92          0.02                2  L1Unstructured
# 54          0.92          0.02                1  L1Unstructured
# 90          0.92          0.01                4  L1Unstructured
# 88          0.92          0.01                3  L1Unstructured
# 81          0.92          0.01                2  L1Unstructured
# 57          0.92          0.01                1  L1Unstructured
#
#     early_stopping  accuracy
# 69            True     88.91
# 64           False     89.19
# 30           False     89.88
# 46           False     89.58
# 62           False     89.24
# 78           False     87.85
# 75           False     88.31
# 65           False     89.10
# 54           False     89.33
# 90           False     47.76
# 88           False     76.51
# 81           False     87.50
# 57           False     89.31

# %%
pruned_96
# Out:
#     total_pruned  pruning_step  finetune_epochs          method  \
# 72          0.96          0.96               10  L1Unstructured
# 80          0.96          0.04                4  L1Unstructured
# 76          0.96          0.04                3  L1Unstructured
# 74          0.96          0.04                2  L1Unstructured
# 70          0.96          0.04                1  L1Unstructured
# 86          0.96          0.02                4  L1Unstructured
# 84          0.96          0.02                3  L1Unstructured
# 82          0.96          0.02                2  L1Unstructured
# 77          0.96          0.02                1  L1Unstructured
# 91          0.96          0.01                4  L1Unstructured
# 89          0.96          0.01                3  L1Unstructured
# 87          0.96          0.01                2  L1Unstructured
# 79          0.96          0.01                1  L1Unstructured
#
#     early_stopping  accuracy
# 72            True     88.61
# 80           False     87.58
# 76           False     88.15
# 74           False     88.37
# 70           False     88.80
# 86           False     81.49
# 84           False     83.75
# 82           False     87.48
# 77           False     87.92
# 91           False     19.71
# 89           False     56.29
# 87           False     79.42
# 79           False     87.59
