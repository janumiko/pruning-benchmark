# %%
import torch.nn.utils.prune as prune

import torch

import torch.nn as nn
import torch.optim as optim
from pathlib import Path
from constants import DATA_PATH, MODELS_PATH
from LeNet import LeNet, BATCH_SIZE
from pruning_metadata import PruningMetadata
from utility.pruning import (
    calculate_parameters_amount,
    get_parameters_to_prune,
)
from utility.cifar_dataset import get_dataloaders
from dataclasses import asdict

import utility
import itertools
import copy
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 13
#      11 from pathlib import Path
#      12 from constants import DATA_PATH, MODELS_PATH
# ---> 13 from LeNet import LeNet, BATCH_SIZE, LEARNING_RATE, EPOCHS, MOMENTUM
#      14 from pruning_metadata import PruningMetadata
#      15 from utility.pruning import (
#      16     calculate_parameters_amount,
#      17     calculate_total_sparsity,
#      18     get_parameters_to_prune,
#      19 )
#
# ImportError: cannot import name 'LEARNING_RATE' from 'LeNet' (/home/bubuss/source/ml-pruning/LeNet.py)

# %%
train_loader, validation_loader, test_loader = get_dataloaders(
    data_path=DATA_PATH, batch_size=BATCH_SIZE
)

# %%
# Get cpu, gpu or mps device for training.
device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")
print(f"Using {torch.cuda.get_device_name(torch.cuda.current_device())}")
# Out:
# Using NVIDIA GeForce GTX 1660 Ti

# %%
base_model = LeNet().to(device)

# Define the loss function and optimizer
cross_entropy = nn.CrossEntropyLoss()
optimizer = optim.AdamW(base_model.parameters())

# %%
PRUNING_VALUES = [0.20, 0.40, 0.60]
PRUNING_NAME_TO_METHOD = {
    "RandomUnstructured": prune.RandomUnstructured,
    "L1Unstructured": prune.L1Unstructured,
}

# %%
ITER_PRUNING_RATES = [0.01, 0.02, 0.04]
RETRAIN_EPOCHS = [1, 2]
max_pruning_percent = max(PRUNING_VALUES)

# %%
iterative_pruning_configs = []

for pruning_step, finetune_epochs in itertools.product(
    ITER_PRUNING_RATES, RETRAIN_EPOCHS
):
    iterative_pruning_configs.append(
        PruningMetadata(
            total_pruned=max_pruning_percent,
            pruning_step=pruning_step,
            finetune_epochs=finetune_epochs,
            total_epochs=None,  # set later
            method=prune.L1Unstructured,
            early_stopping=False,
        )
    )

# %%
for config in iterative_pruning_configs:
    total_pruned = config.total_pruned
    pruning_step = config.pruning_step
    finetune_epochs = config.finetune_epochs
    method = config.method
    method_name = method.__name__

    pruning_value = int(
        round(
            calculate_parameters_amount(get_parameters_to_prune(base_model))
            * pruning_step
        )
    )

    print(
        f"Target total pruning: {total_pruned}, pruning_step: {pruning_step}, method: {method_name}, finetune_epochs: {finetune_epochs}"
    )

    iterative_model = LeNet().to(device)
    iterative_model.load_state_dict(
        torch.load(MODELS_PATH / Path("LeNet_cifar10/LeNet_cifar10.pth"))
    )
    model_name = iterative_model.__class__.__name__

    iterative_model_parameters = get_parameters_to_prune(iterative_model)
    iterative_optimizer = optim.AdamW(iterative_model.parameters())

    target_sparsity = int(total_pruned * 100)
    pruning_step_percent = int(pruning_step * 100)
    for pruned in range(
        pruning_step_percent,
        target_sparsity + pruning_step_percent,
        pruning_step_percent,
    ):
        prune.global_unstructured(
            parameters=iterative_model_parameters,
            pruning_method=method,
            amount=pruning_value,
        )

        val_loss, val_accuracy = utility.training.validate(
            module=iterative_model,
            valid_dl=validation_loader,
            loss_function=cross_entropy,
            device=device,
        )
        print(
            f"Pre-Finetuning Validation loss: {val_loss:.4f}\t validation accuracy: {val_accuracy:.4f}"
        )

        print("Fine tuning the model")
        for epoch in range(finetune_epochs):
            train_loss = utility.training.train_epoch(
                module=iterative_model,
                train_dl=train_loader,
                optimizer=iterative_optimizer,
                loss_function=cross_entropy,
                device=device,
            )

            val_loss, val_accuracy = utility.training.validate(
                module=iterative_model,
                valid_dl=validation_loader,
                loss_function=cross_entropy,
                device=device,
            )

            print(
                f"Pruned {pruned} / {target_sparsity}% | Epoch #{epoch}\tvalidation loss: {val_loss:.4f}\t validation accuracy: {val_accuracy:.4f}"
            )

        if pruned in map(lambda x: int(x * 100), PRUNING_VALUES):
            tmp = copy.deepcopy(iterative_model)
            for module, name in get_parameters_to_prune(tmp):
                prune.remove(module, name)

            tmp_config = copy.deepcopy(config)
            tmp_config.total_pruned = pruned / 100
            tmp_config.method = method.__name__
            tmp_config.total_epochs = (
                int(pruned // pruning_step_percent) * finetune_epochs
            )
            utility.save.save_model_with_metadata(
                model=tmp,
                path=f"{MODELS_PATH}/{model_name}_iterative_pruned_{pruned / 100}_step_{pruning_step}_{method_name}_epochs_{finetune_epochs}",
                model_name=f"{model_name}_iterative_pruned_{pruned / 100}_step_{pruning_step}_{method_name}_epochs_{finetune_epochs}",
                metadata=asdict(tmp_config),
            )

    for module, name in iterative_model_parameters:
        prune.remove(module, name)

    config.method = method.__name__
    utility.save.save_model_with_metadata(
        model=iterative_model,
        path=f"{MODELS_PATH}/{model_name}_iterative_pruned_{total_pruned}_step_{pruning_step}_{method_name}_epochs_{finetune_epochs}",
        model_name=f"{model_name}_iterative_pruned_{total_pruned}_step_{pruning_step}_{method_name}_epochs_{finetune_epochs}",
        metadata=asdict(config),
    )
# Out:
# Target total pruning: 0.96, pruning_step: 0.01, method: L1Unstructured, finetune_epochs: 1
# Pre-Finetuning Validation loss: 0.2411	 validation accuracy: 0.9047
# Fine tuning the model
# Pruned 1 / 96% | Epoch #0	validation loss: 0.2384	 validation accuracy: 0.9104
# Pre-Finetuning Validation loss: 0.2384	 validation accuracy: 0.9104
# Fine tuning the model
# Pruned 2 / 96% | Epoch #0	validation loss: 0.2335	 validation accuracy: 0.9126
# Pre-Finetuning Validation loss: 0.2335	 validation accuracy: 0.9126
# Fine tuning the model
# Pruned 3 / 96% | Epoch #0	validation loss: 0.2376	 validation accuracy: 0.9139
# Pre-Finetuning Validation loss: 0.2375	 validation accuracy: 0.9139
# Fine tuning the model
# Pruned 4 / 96% | Epoch #0	validation loss: 0.2411	 validation accuracy: 0.9132
# Pre-Finetuning Validation loss: 0.2411	 validation accuracy: 0.9132
# Fine tuning the model
# Pruned 5 / 96% | Epoch #0	validation loss: 0.2406	 validation accuracy: 0.9152
# Pre-Finetuning Validation loss: 0.2405	 validation accuracy: 0.9151
# Fine tuning the model
# Pruned 6 / 96% | Epoch #0	validation loss: 0.2427	 validation accuracy: 0.9110
# Pre-Finetuning Validation loss: 0.2427	 validation accuracy: 0.9110
# Fine tuning the model
# Pruned 7 / 96% | Epoch #0	validation loss: 0.2361	 validation accuracy: 0.9161
# Pre-Finetuning Validation loss: 0.2361	 validation accuracy: 0.9162
# Fine tuning the model
# Pruned 8 / 96% | Epoch #0	validation loss: 0.2424	 validation accuracy: 0.9155
# Pre-Finetuning Validation loss: 0.2425	 validation accuracy: 0.9155
# Fine tuning the model
# Pruned 9 / 96% | Epoch #0	validation loss: 0.2805	 validation accuracy: 0.9029
# Pre-Finetuning Validation loss: 0.2805	 validation accuracy: 0.9028
# Fine tuning the model
# Pruned 10 / 96% | Epoch #0	validation loss: 0.2544	 validation accuracy: 0.9137
# Pre-Finetuning Validation loss: 0.2544	 validation accuracy: 0.9138
# Fine tuning the model
# Pruned 11 / 96% | Epoch #0	validation loss: 0.2639	 validation accuracy: 0.9095
# Pre-Finetuning Validation loss: 0.2639	 validation accuracy: 0.9094
# Fine tuning the model
# Pruned 12 / 96% | Epoch #0	validation loss: 0.2589	 validation accuracy: 0.9116
# Pre-Finetuning Validation loss: 0.2590	 validation accuracy: 0.9115
# Fine tuning the model
# Pruned 13 / 96% | Epoch #0	validation loss: 0.2675	 validation accuracy: 0.9092
# Pre-Finetuning Validation loss: 0.2675	 validation accuracy: 0.9092
# Fine tuning the model
# Pruned 14 / 96% | Epoch #0	validation loss: 0.2803	 validation accuracy: 0.9062
# Pre-Finetuning Validation loss: 0.2803	 validation accuracy: 0.9062
# Fine tuning the model
# Pruned 15 / 96% | Epoch #0	validation loss: 0.2861	 validation accuracy: 0.9107
# Pre-Finetuning Validation loss: 0.2861	 validation accuracy: 0.9107
# Fine tuning the model
# Pruned 16 / 96% | Epoch #0	validation loss: 0.2810	 validation accuracy: 0.9102
# Pre-Finetuning Validation loss: 0.2809	 validation accuracy: 0.9102
# Fine tuning the model
# Pruned 17 / 96% | Epoch #0	validation loss: 0.3052	 validation accuracy: 0.9004
# Pre-Finetuning Validation loss: 0.3052	 validation accuracy: 0.9005
# Fine tuning the model
# Pruned 18 / 96% | Epoch #0	validation loss: 0.2894	 validation accuracy: 0.9108
# Pre-Finetuning Validation loss: 0.2894	 validation accuracy: 0.9105
# Fine tuning the model
# Pruned 19 / 96% | Epoch #0	validation loss: 0.3168	 validation accuracy: 0.9021
# Pre-Finetuning Validation loss: 0.3168	 validation accuracy: 0.9022
# Fine tuning the model
# Pruned 20 / 96% | Epoch #0	validation loss: 0.3071	 validation accuracy: 0.9072
# Pre-Finetuning Validation loss: 0.3071	 validation accuracy: 0.9070
# Fine tuning the model
# Pruned 21 / 96% | Epoch #0	validation loss: 0.3412	 validation accuracy: 0.8992
# Pre-Finetuning Validation loss: 0.3411	 validation accuracy: 0.8993
# Fine tuning the model
# Pruned 22 / 96% | Epoch #0	validation loss: 0.3860	 validation accuracy: 0.8997
# Pre-Finetuning Validation loss: 0.3859	 validation accuracy: 0.8993
# Fine tuning the model
# Pruned 23 / 96% | Epoch #0	validation loss: 0.3321	 validation accuracy: 0.9067
# Pre-Finetuning Validation loss: 0.3322	 validation accuracy: 0.9067
# Fine tuning the model
# Pruned 24 / 96% | Epoch #0	validation loss: 0.3475	 validation accuracy: 0.9081
# Pre-Finetuning Validation loss: 0.3472	 validation accuracy: 0.9080
# Fine tuning the model
# Pruned 25 / 96% | Epoch #0	validation loss: 0.3301	 validation accuracy: 0.9092
# Pre-Finetuning Validation loss: 0.3302	 validation accuracy: 0.9089
# Fine tuning the model
# Pruned 26 / 96% | Epoch #0	validation loss: 0.3449	 validation accuracy: 0.9078
# Pre-Finetuning Validation loss: 0.3448	 validation accuracy: 0.9082
# Fine tuning the model
# Pruned 27 / 96% | Epoch #0	validation loss: 0.4090	 validation accuracy: 0.9038
# Pre-Finetuning Validation loss: 0.4092	 validation accuracy: 0.9037
# Fine tuning the model
# Pruned 28 / 96% | Epoch #0	validation loss: 0.3719	 validation accuracy: 0.9043
# Pre-Finetuning Validation loss: 0.3722	 validation accuracy: 0.9044
# Fine tuning the model
# Pruned 29 / 96% | Epoch #0	validation loss: 0.3830	 validation accuracy: 0.9074
# Pre-Finetuning Validation loss: 0.3829	 validation accuracy: 0.9078
# Fine tuning the model
# Pruned 30 / 96% | Epoch #0	validation loss: 0.4094	 validation accuracy: 0.9044
# Pre-Finetuning Validation loss: 0.4097	 validation accuracy: 0.9047
# Fine tuning the model
# Pruned 31 / 96% | Epoch #0	validation loss: 0.4042	 validation accuracy: 0.9071
# Pre-Finetuning Validation loss: 0.4048	 validation accuracy: 0.9070
# Fine tuning the model
# Pruned 32 / 96% | Epoch #0	validation loss: 0.3976	 validation accuracy: 0.9021
# Pre-Finetuning Validation loss: 0.3974	 validation accuracy: 0.9020
# Fine tuning the model
# Pruned 33 / 96% | Epoch #0	validation loss: 0.4568	 validation accuracy: 0.9023
# Pre-Finetuning Validation loss: 0.4577	 validation accuracy: 0.9020
# Fine tuning the model
# Pruned 34 / 96% | Epoch #0	validation loss: 0.4251	 validation accuracy: 0.9044
# Pre-Finetuning Validation loss: 0.4260	 validation accuracy: 0.9046
# Fine tuning the model
# Pruned 35 / 96% | Epoch #0	validation loss: 0.4239	 validation accuracy: 0.9053
# Pre-Finetuning Validation loss: 0.4247	 validation accuracy: 0.9050
# Fine tuning the model
# Pruned 36 / 96% | Epoch #0	validation loss: 0.4654	 validation accuracy: 0.9031
# Pre-Finetuning Validation loss: 0.4659	 validation accuracy: 0.9027
# Fine tuning the model
# Pruned 37 / 96% | Epoch #0	validation loss: 0.4558	 validation accuracy: 0.8997
# Pre-Finetuning Validation loss: 0.4566	 validation accuracy: 0.8992
# Fine tuning the model
# Pruned 38 / 96% | Epoch #0	validation loss: 0.4919	 validation accuracy: 0.9013
# Pre-Finetuning Validation loss: 0.4938	 validation accuracy: 0.9011
# Fine tuning the model
# Pruned 39 / 96% | Epoch #0	validation loss: 0.4796	 validation accuracy: 0.9040
# Pre-Finetuning Validation loss: 0.4812	 validation accuracy: 0.9042
# Fine tuning the model
# Pruned 40 / 96% | Epoch #0	validation loss: 0.4926	 validation accuracy: 0.9045
# Pre-Finetuning Validation loss: 0.4940	 validation accuracy: 0.9048
# Fine tuning the model
# Pruned 41 / 96% | Epoch #0	validation loss: 0.5618	 validation accuracy: 0.8980
# Pre-Finetuning Validation loss: 0.5637	 validation accuracy: 0.8978
# Fine tuning the model
# Pruned 42 / 96% | Epoch #0	validation loss: 0.5211	 validation accuracy: 0.9007
# Pre-Finetuning Validation loss: 0.5217	 validation accuracy: 0.9007
# Fine tuning the model
# Pruned 43 / 96% | Epoch #0	validation loss: 0.5341	 validation accuracy: 0.8997
# Pre-Finetuning Validation loss: 0.5367	 validation accuracy: 0.8992
# Fine tuning the model
# Pruned 44 / 96% | Epoch #0	validation loss: 0.5262	 validation accuracy: 0.9003
# Pre-Finetuning Validation loss: 0.5290	 validation accuracy: 0.8986
# Fine tuning the model
# Pruned 45 / 96% | Epoch #0	validation loss: 0.5720	 validation accuracy: 0.9040
# Pre-Finetuning Validation loss: 0.5778	 validation accuracy: 0.9037
# Fine tuning the model
# Pruned 46 / 96% | Epoch #0	validation loss: 0.5705	 validation accuracy: 0.9034
# Pre-Finetuning Validation loss: 0.5736	 validation accuracy: 0.9019
# Fine tuning the model
# Pruned 47 / 96% | Epoch #0	validation loss: 0.6191	 validation accuracy: 0.8973
# Pre-Finetuning Validation loss: 0.6212	 validation accuracy: 0.8960
# Fine tuning the model
# Pruned 48 / 96% | Epoch #0	validation loss: 0.6173	 validation accuracy: 0.9049
# Pre-Finetuning Validation loss: 0.6198	 validation accuracy: 0.9048
# Fine tuning the model
# Pruned 49 / 96% | Epoch #0	validation loss: 0.5955	 validation accuracy: 0.8959
# Pre-Finetuning Validation loss: 0.6025	 validation accuracy: 0.8948
# Fine tuning the model
# Pruned 50 / 96% | Epoch #0	validation loss: 0.5814	 validation accuracy: 0.9007
# Pre-Finetuning Validation loss: 0.5841	 validation accuracy: 0.8997
# Fine tuning the model
# Pruned 51 / 96% | Epoch #0	validation loss: 0.5845	 validation accuracy: 0.9064
# Pre-Finetuning Validation loss: 0.5903	 validation accuracy: 0.9063
# Fine tuning the model
# Pruned 52 / 96% | Epoch #0	validation loss: 0.5974	 validation accuracy: 0.9013
# Pre-Finetuning Validation loss: 0.5987	 validation accuracy: 0.9003
# Fine tuning the model
# Pruned 53 / 96% | Epoch #0	validation loss: 0.5933	 validation accuracy: 0.9058
# Pre-Finetuning Validation loss: 0.5990	 validation accuracy: 0.9034
# Fine tuning the model
# Pruned 54 / 96% | Epoch #0	validation loss: 0.6244	 validation accuracy: 0.8994
# Pre-Finetuning Validation loss: 0.6261	 validation accuracy: 0.8982
# Fine tuning the model
# Pruned 55 / 96% | Epoch #0	validation loss: 0.6074	 validation accuracy: 0.9033
# Pre-Finetuning Validation loss: 0.6146	 validation accuracy: 0.9018
# Fine tuning the model
# Pruned 56 / 96% | Epoch #0	validation loss: 0.6223	 validation accuracy: 0.9030
# Pre-Finetuning Validation loss: 0.6266	 validation accuracy: 0.9022
# Fine tuning the model
# Pruned 57 / 96% | Epoch #0	validation loss: 0.6551	 validation accuracy: 0.9022
# Pre-Finetuning Validation loss: 0.6634	 validation accuracy: 0.9017
# Fine tuning the model
# Pruned 58 / 96% | Epoch #0	validation loss: 0.6072	 validation accuracy: 0.9028
# Pre-Finetuning Validation loss: 0.6156	 validation accuracy: 0.9032
# Fine tuning the model
# Pruned 59 / 96% | Epoch #0	validation loss: 0.6508	 validation accuracy: 0.9032
# Pre-Finetuning Validation loss: 0.6642	 validation accuracy: 0.9019
# Fine tuning the model
# Pruned 60 / 96% | Epoch #0	validation loss: 0.6461	 validation accuracy: 0.8995
# Pre-Finetuning Validation loss: 0.6531	 validation accuracy: 0.8955
# Fine tuning the model
# Pruned 61 / 96% | Epoch #0	validation loss: 0.6460	 validation accuracy: 0.8979
# Pre-Finetuning Validation loss: 0.6564	 validation accuracy: 0.8960
# Fine tuning the model
# Pruned 62 / 96% | Epoch #0	validation loss: 0.6587	 validation accuracy: 0.9011
# Pre-Finetuning Validation loss: 0.6799	 validation accuracy: 0.9003
# Fine tuning the model
# Pruned 63 / 96% | Epoch #0	validation loss: 0.6730	 validation accuracy: 0.9058
# Pre-Finetuning Validation loss: 0.6700	 validation accuracy: 0.9050
# Fine tuning the model
# Pruned 64 / 96% | Epoch #0	validation loss: 0.6791	 validation accuracy: 0.8965
# Pre-Finetuning Validation loss: 0.6892	 validation accuracy: 0.8961
# Fine tuning the model
# Pruned 65 / 96% | Epoch #0	validation loss: 0.6959	 validation accuracy: 0.9022
# Pre-Finetuning Validation loss: 0.7162	 validation accuracy: 0.9029
# Fine tuning the model
# Pruned 66 / 96% | Epoch #0	validation loss: 0.7216	 validation accuracy: 0.8996
# Pre-Finetuning Validation loss: 0.7477	 validation accuracy: 0.8967
# Fine tuning the model
# Pruned 67 / 96% | Epoch #0	validation loss: 0.6713	 validation accuracy: 0.9010
# Pre-Finetuning Validation loss: 0.6864	 validation accuracy: 0.9003
# Fine tuning the model
# Pruned 68 / 96% | Epoch #0	validation loss: 0.7243	 validation accuracy: 0.8986
# Pre-Finetuning Validation loss: 0.7504	 validation accuracy: 0.8906
# Fine tuning the model
# Pruned 69 / 96% | Epoch #0	validation loss: 0.6603	 validation accuracy: 0.8995
# Pre-Finetuning Validation loss: 0.6764	 validation accuracy: 0.8963
# Fine tuning the model
# Pruned 70 / 96% | Epoch #0	validation loss: 0.6470	 validation accuracy: 0.9037
# Pre-Finetuning Validation loss: 0.6596	 validation accuracy: 0.8998
# Fine tuning the model
# Pruned 71 / 96% | Epoch #0	validation loss: 0.6665	 validation accuracy: 0.9003
# Pre-Finetuning Validation loss: 0.6943	 validation accuracy: 0.8964
# Fine tuning the model
# Pruned 72 / 96% | Epoch #0	validation loss: 0.6652	 validation accuracy: 0.8972
# Pre-Finetuning Validation loss: 0.6978	 validation accuracy: 0.8939
# Fine tuning the model
# Pruned 73 / 96% | Epoch #0	validation loss: 0.6515	 validation accuracy: 0.8994
# Pre-Finetuning Validation loss: 0.6551	 validation accuracy: 0.8936
# Fine tuning the model
# Pruned 74 / 96% | Epoch #0	validation loss: 0.6459	 validation accuracy: 0.9025
# Pre-Finetuning Validation loss: 0.6717	 validation accuracy: 0.8972
# Fine tuning the model
# Pruned 75 / 96% | Epoch #0	validation loss: 0.6584	 validation accuracy: 0.8951
# Pre-Finetuning Validation loss: 0.6973	 validation accuracy: 0.8867
# Fine tuning the model
# Pruned 76 / 96% | Epoch #0	validation loss: 0.6194	 validation accuracy: 0.8978
# Pre-Finetuning Validation loss: 0.6600	 validation accuracy: 0.8916
# Fine tuning the model
# Pruned 77 / 96% | Epoch #0	validation loss: 0.6197	 validation accuracy: 0.8982
# Pre-Finetuning Validation loss: 0.6632	 validation accuracy: 0.8909
# Fine tuning the model
# Pruned 78 / 96% | Epoch #0	validation loss: 0.6130	 validation accuracy: 0.8990
# Pre-Finetuning Validation loss: 0.6637	 validation accuracy: 0.8897
# Fine tuning the model
# Pruned 79 / 96% | Epoch #0	validation loss: 0.6089	 validation accuracy: 0.8953
# Pre-Finetuning Validation loss: 0.6670	 validation accuracy: 0.8879
# Fine tuning the model
# Pruned 80 / 96% | Epoch #0	validation loss: 0.5641	 validation accuracy: 0.8997
# Pre-Finetuning Validation loss: 0.5966	 validation accuracy: 0.8935
# Fine tuning the model
# Pruned 81 / 96% | Epoch #0	validation loss: 0.5736	 validation accuracy: 0.8895
# Pre-Finetuning Validation loss: 0.6034	 validation accuracy: 0.8820
# Fine tuning the model
# Pruned 82 / 96% | Epoch #0	validation loss: 0.5129	 validation accuracy: 0.8940
# Pre-Finetuning Validation loss: 0.5661	 validation accuracy: 0.8804
# Fine tuning the model
# Pruned 83 / 96% | Epoch #0	validation loss: 0.4999	 validation accuracy: 0.8977
# Pre-Finetuning Validation loss: 0.5743	 validation accuracy: 0.8871
# Fine tuning the model
# Pruned 84 / 96% | Epoch #0	validation loss: 0.4788	 validation accuracy: 0.8983
# Pre-Finetuning Validation loss: 0.5698	 validation accuracy: 0.8757
# Fine tuning the model
# Pruned 85 / 96% | Epoch #0	validation loss: 0.4515	 validation accuracy: 0.8996
# Pre-Finetuning Validation loss: 0.5123	 validation accuracy: 0.8812
# Fine tuning the model
# Pruned 86 / 96% | Epoch #0	validation loss: 0.4583	 validation accuracy: 0.8926
# Pre-Finetuning Validation loss: 0.5343	 validation accuracy: 0.8687
# Fine tuning the model
# Pruned 87 / 96% | Epoch #0	validation loss: 0.3963	 validation accuracy: 0.8961
# Pre-Finetuning Validation loss: 0.4801	 validation accuracy: 0.8702
# Fine tuning the model
# Pruned 88 / 96% | Epoch #0	validation loss: 0.3710	 validation accuracy: 0.9008
# Pre-Finetuning Validation loss: 0.4474	 validation accuracy: 0.8867
# Fine tuning the model
# Pruned 89 / 96% | Epoch #0	validation loss: 0.3783	 validation accuracy: 0.8943
# Pre-Finetuning Validation loss: 0.4951	 validation accuracy: 0.8554
# Fine tuning the model
# Pruned 90 / 96% | Epoch #0	validation loss: 0.3610	 validation accuracy: 0.8920
# Pre-Finetuning Validation loss: 0.4588	 validation accuracy: 0.8675
# Fine tuning the model
# Pruned 91 / 96% | Epoch #0	validation loss: 0.3435	 validation accuracy: 0.8926
# Pre-Finetuning Validation loss: 0.4807	 validation accuracy: 0.8560
# Fine tuning the model
# Pruned 92 / 96% | Epoch #0	validation loss: 0.3357	 validation accuracy: 0.8906
# Pre-Finetuning Validation loss: 0.5083	 validation accuracy: 0.8378
# Fine tuning the model
# Pruned 93 / 96% | Epoch #0	validation loss: 0.3159	 validation accuracy: 0.8931
# Pre-Finetuning Validation loss: 0.5187	 validation accuracy: 0.8326
# Fine tuning the model
# Pruned 94 / 96% | Epoch #0	validation loss: 0.3209	 validation accuracy: 0.8949
# Pre-Finetuning Validation loss: 0.6162	 validation accuracy: 0.7999
# Fine tuning the model
# Pruned 95 / 96% | Epoch #0	validation loss: 0.3248	 validation accuracy: 0.8882
# Pre-Finetuning Validation loss: 0.6403	 validation accuracy: 0.7729
# Fine tuning the model
# Pruned 96 / 96% | Epoch #0	validation loss: 0.3493	 validation accuracy: 0.8770
# Target total pruning: 0.96, pruning_step: 0.01, method: L1Unstructured, finetune_epochs: 2
# Pre-Finetuning Validation loss: 0.2411	 validation accuracy: 0.9047
# Fine tuning the model
# Pruned 1 / 96% | Epoch #0	validation loss: 0.2318	 validation accuracy: 0.9128
# Pruned 1 / 96% | Epoch #1	validation loss: 0.2492	 validation accuracy: 0.9063
# Pre-Finetuning Validation loss: 0.2492	 validation accuracy: 0.9064
# Fine tuning the model
# Pruned 2 / 96% | Epoch #0	validation loss: 0.2598	 validation accuracy: 0.9056
# Pruned 2 / 96% | Epoch #1	validation loss: 0.2408	 validation accuracy: 0.9100
# Pre-Finetuning Validation loss: 0.2408	 validation accuracy: 0.9099
# Fine tuning the model
# Pruned 3 / 96% | Epoch #0	validation loss: 0.2383	 validation accuracy: 0.9123
# Pruned 3 / 96% | Epoch #1	validation loss: 0.2391	 validation accuracy: 0.9121
# Pre-Finetuning Validation loss: 0.2391	 validation accuracy: 0.9122
# Fine tuning the model
# Pruned 4 / 96% | Epoch #0	validation loss: 0.2402	 validation accuracy: 0.9135
# Pruned 4 / 96% | Epoch #1	validation loss: 0.2596	 validation accuracy: 0.9089
# Pre-Finetuning Validation loss: 0.2596	 validation accuracy: 0.9090
# Fine tuning the model
# Pruned 5 / 96% | Epoch #0	validation loss: 0.2495	 validation accuracy: 0.9122
# Pruned 5 / 96% | Epoch #1	validation loss: 0.2616	 validation accuracy: 0.9127
# Pre-Finetuning Validation loss: 0.2616	 validation accuracy: 0.9126
# Fine tuning the model
# Pruned 6 / 96% | Epoch #0	validation loss: 0.2692	 validation accuracy: 0.9112
# Pruned 6 / 96% | Epoch #1	validation loss: 0.2805	 validation accuracy: 0.9045
# Pre-Finetuning Validation loss: 0.2805	 validation accuracy: 0.9044
# Fine tuning the model
# Pruned 7 / 96% | Epoch #0	validation loss: 0.2838	 validation accuracy: 0.9057
# Pruned 7 / 96% | Epoch #1	validation loss: 0.2794	 validation accuracy: 0.9094
# Pre-Finetuning Validation loss: 0.2795	 validation accuracy: 0.9094
# Fine tuning the model
# Pruned 8 / 96% | Epoch #0	validation loss: 0.3030	 validation accuracy: 0.9063
# Pruned 8 / 96% | Epoch #1	validation loss: 0.2979	 validation accuracy: 0.9003
# Pre-Finetuning Validation loss: 0.2979	 validation accuracy: 0.9003
# Fine tuning the model
# Pruned 9 / 96% | Epoch #0	validation loss: 0.2974	 validation accuracy: 0.9069
# Pruned 9 / 96% | Epoch #1	validation loss: 0.2967	 validation accuracy: 0.9100
# Pre-Finetuning Validation loss: 0.2967	 validation accuracy: 0.9102
# Fine tuning the model
# Pruned 10 / 96% | Epoch #0	validation loss: 0.3125	 validation accuracy: 0.9087
# Pruned 10 / 96% | Epoch #1	validation loss: 0.3170	 validation accuracy: 0.9064
# Pre-Finetuning Validation loss: 0.3170	 validation accuracy: 0.9062
# Fine tuning the model
# Pruned 11 / 96% | Epoch #0	validation loss: 0.3207	 validation accuracy: 0.9078
# Pruned 11 / 96% | Epoch #1	validation loss: 0.3488	 validation accuracy: 0.9104
# Pre-Finetuning Validation loss: 0.3489	 validation accuracy: 0.9104
# Fine tuning the model
# Pruned 12 / 96% | Epoch #0	validation loss: 0.3540	 validation accuracy: 0.9051
# Pruned 12 / 96% | Epoch #1	validation loss: 0.3434	 validation accuracy: 0.9069
# Pre-Finetuning Validation loss: 0.3435	 validation accuracy: 0.9069
# Fine tuning the model
# Pruned 13 / 96% | Epoch #0	validation loss: 0.4079	 validation accuracy: 0.9009
# Pruned 13 / 96% | Epoch #1	validation loss: 0.3581	 validation accuracy: 0.9053
# Pre-Finetuning Validation loss: 0.3581	 validation accuracy: 0.9053
# Fine tuning the model
# Pruned 14 / 96% | Epoch #0	validation loss: 0.3758	 validation accuracy: 0.9070
# Pruned 14 / 96% | Epoch #1	validation loss: 0.3934	 validation accuracy: 0.9075
# Pre-Finetuning Validation loss: 0.3935	 validation accuracy: 0.9076
# Fine tuning the model
# Pruned 15 / 96% | Epoch #0	validation loss: 0.4099	 validation accuracy: 0.9051
# Pruned 15 / 96% | Epoch #1	validation loss: 0.3776	 validation accuracy: 0.9026
# Pre-Finetuning Validation loss: 0.3776	 validation accuracy: 0.9027
# Fine tuning the model
# Pruned 16 / 96% | Epoch #0	validation loss: 0.4409	 validation accuracy: 0.9020
# Pruned 16 / 96% | Epoch #1	validation loss: 0.4009	 validation accuracy: 0.9028
# Pre-Finetuning Validation loss: 0.4009	 validation accuracy: 0.9030
# Fine tuning the model
# Pruned 17 / 96% | Epoch #0	validation loss: 0.4506	 validation accuracy: 0.9032
# Pruned 17 / 96% | Epoch #1	validation loss: 0.4463	 validation accuracy: 0.9057
# Pre-Finetuning Validation loss: 0.4463	 validation accuracy: 0.9057
# Fine tuning the model
# Pruned 18 / 96% | Epoch #0	validation loss: 0.4472	 validation accuracy: 0.9008
# Pruned 18 / 96% | Epoch #1	validation loss: 0.4721	 validation accuracy: 0.9006
# Pre-Finetuning Validation loss: 0.4720	 validation accuracy: 0.9003
# Fine tuning the model
# Pruned 19 / 96% | Epoch #0	validation loss: 0.4814	 validation accuracy: 0.9049
# Pruned 19 / 96% | Epoch #1	validation loss: 0.4943	 validation accuracy: 0.8985
# Pre-Finetuning Validation loss: 0.4942	 validation accuracy: 0.8987
# Fine tuning the model
# Pruned 20 / 96% | Epoch #0	validation loss: 0.4877	 validation accuracy: 0.8970
# Pruned 20 / 96% | Epoch #1	validation loss: 0.4981	 validation accuracy: 0.8964
# Pre-Finetuning Validation loss: 0.4982	 validation accuracy: 0.8963
# Fine tuning the model
# Pruned 21 / 96% | Epoch #0	validation loss: 0.5088	 validation accuracy: 0.9015
# Pruned 21 / 96% | Epoch #1	validation loss: 0.5333	 validation accuracy: 0.8966
# Pre-Finetuning Validation loss: 0.5334	 validation accuracy: 0.8963
# Fine tuning the model
# Pruned 22 / 96% | Epoch #0	validation loss: 0.5425	 validation accuracy: 0.8989
# Pruned 22 / 96% | Epoch #1	validation loss: 0.5929	 validation accuracy: 0.8955
# Pre-Finetuning Validation loss: 0.5932	 validation accuracy: 0.8952
# Fine tuning the model
# Pruned 23 / 96% | Epoch #0	validation loss: 0.5505	 validation accuracy: 0.8984
# Pruned 23 / 96% | Epoch #1	validation loss: 0.5320	 validation accuracy: 0.8981
# Pre-Finetuning Validation loss: 0.5320	 validation accuracy: 0.8981
# Fine tuning the model
# Pruned 24 / 96% | Epoch #0	validation loss: 0.5417	 validation accuracy: 0.9007
# Pruned 24 / 96% | Epoch #1	validation loss: 0.5908	 validation accuracy: 0.8938
# Pre-Finetuning Validation loss: 0.5909	 validation accuracy: 0.8937
# Fine tuning the model
# Pruned 25 / 96% | Epoch #0	validation loss: 0.5912	 validation accuracy: 0.9031
# Pruned 25 / 96% | Epoch #1	validation loss: 0.5943	 validation accuracy: 0.8977
# Pre-Finetuning Validation loss: 0.5944	 validation accuracy: 0.8977
# Fine tuning the model
# Pruned 26 / 96% | Epoch #0	validation loss: 0.6891	 validation accuracy: 0.8925
# Pruned 26 / 96% | Epoch #1	validation loss: 0.6665	 validation accuracy: 0.8966
# Pre-Finetuning Validation loss: 0.6661	 validation accuracy: 0.8965
# Fine tuning the model
# Pruned 27 / 96% | Epoch #0	validation loss: 0.6607	 validation accuracy: 0.8917
# Pruned 27 / 96% | Epoch #1	validation loss: 0.6212	 validation accuracy: 0.9017
# Pre-Finetuning Validation loss: 0.6213	 validation accuracy: 0.9015
# Fine tuning the model
# Pruned 28 / 96% | Epoch #0	validation loss: 0.6461	 validation accuracy: 0.8976
# Pruned 28 / 96% | Epoch #1	validation loss: 0.6844	 validation accuracy: 0.8968
# Pre-Finetuning Validation loss: 0.6847	 validation accuracy: 0.8967
# Fine tuning the model
# Pruned 29 / 96% | Epoch #0	validation loss: 0.6442	 validation accuracy: 0.8988
# Pruned 29 / 96% | Epoch #1	validation loss: 0.7545	 validation accuracy: 0.8963
# Pre-Finetuning Validation loss: 0.7542	 validation accuracy: 0.8964
# Fine tuning the model
# Pruned 30 / 96% | Epoch #0	validation loss: 0.6189	 validation accuracy: 0.8994
# Pruned 30 / 96% | Epoch #1	validation loss: 0.7636	 validation accuracy: 0.8872
# Pre-Finetuning Validation loss: 0.7639	 validation accuracy: 0.8866
# Fine tuning the model
# Pruned 31 / 96% | Epoch #0	validation loss: 0.6941	 validation accuracy: 0.8980
# Pruned 31 / 96% | Epoch #1	validation loss: 0.6959	 validation accuracy: 0.9001
# Pre-Finetuning Validation loss: 0.6960	 validation accuracy: 0.9000
# Fine tuning the model
# Pruned 32 / 96% | Epoch #0	validation loss: 0.7447	 validation accuracy: 0.8985
# Pruned 32 / 96% | Epoch #1	validation loss: 0.6959	 validation accuracy: 0.8997
# Pre-Finetuning Validation loss: 0.6970	 validation accuracy: 0.8996
# Fine tuning the model
# Pruned 33 / 96% | Epoch #0	validation loss: 0.6989	 validation accuracy: 0.8990
# Pruned 33 / 96% | Epoch #1	validation loss: 0.6914	 validation accuracy: 0.8931
# Pre-Finetuning Validation loss: 0.6912	 validation accuracy: 0.8928
# Fine tuning the model
# Pruned 34 / 96% | Epoch #0	validation loss: 0.6988	 validation accuracy: 0.8967
# Pruned 34 / 96% | Epoch #1	validation loss: 0.7674	 validation accuracy: 0.8936
# Pre-Finetuning Validation loss: 0.7682	 validation accuracy: 0.8937
# Fine tuning the model
# Pruned 35 / 96% | Epoch #0	validation loss: 0.7536	 validation accuracy: 0.8968
# Pruned 35 / 96% | Epoch #1	validation loss: 0.8337	 validation accuracy: 0.8963
# Pre-Finetuning Validation loss: 0.8353	 validation accuracy: 0.8960
# Fine tuning the model
# Pruned 36 / 96% | Epoch #0	validation loss: 0.8110	 validation accuracy: 0.8986
# Pruned 36 / 96% | Epoch #1	validation loss: 0.8347	 validation accuracy: 0.8984
# Pre-Finetuning Validation loss: 0.8350	 validation accuracy: 0.8983
# Fine tuning the model
# Pruned 37 / 96% | Epoch #0	validation loss: 0.8324	 validation accuracy: 0.8975
# Pruned 37 / 96% | Epoch #1	validation loss: 0.7986	 validation accuracy: 0.9003
# Pre-Finetuning Validation loss: 0.7994	 validation accuracy: 0.9003
# Fine tuning the model
# Pruned 38 / 96% | Epoch #0	validation loss: 0.8313	 validation accuracy: 0.8933
# Pruned 38 / 96% | Epoch #1	validation loss: 0.7792	 validation accuracy: 0.9000
# Pre-Finetuning Validation loss: 0.7800	 validation accuracy: 0.9003
# Fine tuning the model
# Pruned 39 / 96% | Epoch #0	validation loss: 0.7898	 validation accuracy: 0.8976
# Pruned 39 / 96% | Epoch #1	validation loss: 0.8655	 validation accuracy: 0.9009
# Pre-Finetuning Validation loss: 0.8667	 validation accuracy: 0.9015
# Fine tuning the model
# Pruned 40 / 96% | Epoch #0	validation loss: 0.8398	 validation accuracy: 0.8925
# Pruned 40 / 96% | Epoch #1	validation loss: 0.8153	 validation accuracy: 0.8913
# Pre-Finetuning Validation loss: 0.8181	 validation accuracy: 0.8915
# Fine tuning the model
# Pruned 41 / 96% | Epoch #0	validation loss: 0.8555	 validation accuracy: 0.8996
# Pruned 41 / 96% | Epoch #1	validation loss: 0.8855	 validation accuracy: 0.8997
# Pre-Finetuning Validation loss: 0.8869	 validation accuracy: 0.8997
# Fine tuning the model
# Pruned 42 / 96% | Epoch #0	validation loss: 0.8816	 validation accuracy: 0.8932
# Pruned 42 / 96% | Epoch #1	validation loss: 0.9063	 validation accuracy: 0.8999
# Pre-Finetuning Validation loss: 0.9061	 validation accuracy: 0.9001
# Fine tuning the model
# Pruned 43 / 96% | Epoch #0	validation loss: 0.9327	 validation accuracy: 0.8906
# Pruned 43 / 96% | Epoch #1	validation loss: 0.8712	 validation accuracy: 0.8974
# Pre-Finetuning Validation loss: 0.8764	 validation accuracy: 0.8972
# Fine tuning the model
# Pruned 44 / 96% | Epoch #0	validation loss: 0.9041	 validation accuracy: 0.9005
# Pruned 44 / 96% | Epoch #1	validation loss: 0.9253	 validation accuracy: 0.8978
# Pre-Finetuning Validation loss: 0.9287	 validation accuracy: 0.8981
# Fine tuning the model
# Pruned 45 / 96% | Epoch #0	validation loss: 0.9080	 validation accuracy: 0.8966
# Pruned 45 / 96% | Epoch #1	validation loss: 0.9157	 validation accuracy: 0.8917
# Pre-Finetuning Validation loss: 0.9167	 validation accuracy: 0.8908
# Fine tuning the model
# Pruned 46 / 96% | Epoch #0	validation loss: 0.9159	 validation accuracy: 0.8965
# Pruned 46 / 96% | Epoch #1	validation loss: 0.9979	 validation accuracy: 0.8972
# Pre-Finetuning Validation loss: 1.0008	 validation accuracy: 0.8964
# Fine tuning the model
# Pruned 47 / 96% | Epoch #0	validation loss: 0.9858	 validation accuracy: 0.8944
# Pruned 47 / 96% | Epoch #1	validation loss: 0.9397	 validation accuracy: 0.8952
# Pre-Finetuning Validation loss: 0.9433	 validation accuracy: 0.8950
# Fine tuning the model
# Pruned 48 / 96% | Epoch #0	validation loss: 0.9850	 validation accuracy: 0.8981
# Pruned 48 / 96% | Epoch #1	validation loss: 1.0147	 validation accuracy: 0.8956
# Pre-Finetuning Validation loss: 1.0225	 validation accuracy: 0.8958
# Fine tuning the model
# Pruned 49 / 96% | Epoch #0	validation loss: 0.9550	 validation accuracy: 0.8948
# Pruned 49 / 96% | Epoch #1	validation loss: 1.0071	 validation accuracy: 0.9003
# Pre-Finetuning Validation loss: 1.0073	 validation accuracy: 0.9004
# Fine tuning the model
# Pruned 50 / 96% | Epoch #0	validation loss: 1.0543	 validation accuracy: 0.8922
# Pruned 50 / 96% | Epoch #1	validation loss: 1.0130	 validation accuracy: 0.8961
# Pre-Finetuning Validation loss: 1.0191	 validation accuracy: 0.8956
# Fine tuning the model
# Pruned 51 / 96% | Epoch #0	validation loss: 1.0967	 validation accuracy: 0.8967
# Pruned 51 / 96% | Epoch #1	validation loss: 1.0077	 validation accuracy: 0.8960
# Pre-Finetuning Validation loss: 1.0118	 validation accuracy: 0.8958
# Fine tuning the model
# Pruned 52 / 96% | Epoch #0	validation loss: 1.0194	 validation accuracy: 0.8973
# Pruned 52 / 96% | Epoch #1	validation loss: 1.0950	 validation accuracy: 0.8970
# Pre-Finetuning Validation loss: 1.0999	 validation accuracy: 0.8970
# Fine tuning the model
# Pruned 53 / 96% | Epoch #0	validation loss: 1.0457	 validation accuracy: 0.8990
# Pruned 53 / 96% | Epoch #1	validation loss: 1.1842	 validation accuracy: 0.8907
# Pre-Finetuning Validation loss: 1.1931	 validation accuracy: 0.8892
# Fine tuning the model
# Pruned 54 / 96% | Epoch #0	validation loss: 1.0179	 validation accuracy: 0.8995
# Pruned 54 / 96% | Epoch #1	validation loss: 1.0525	 validation accuracy: 0.8894
# Pre-Finetuning Validation loss: 1.0791	 validation accuracy: 0.8862
# Fine tuning the model
# Pruned 55 / 96% | Epoch #0	validation loss: 0.9869	 validation accuracy: 0.9003
# Pruned 55 / 96% | Epoch #1	validation loss: 1.0521	 validation accuracy: 0.8940
# Pre-Finetuning Validation loss: 1.0611	 validation accuracy: 0.8937
# Fine tuning the model
# Pruned 56 / 96% | Epoch #0	validation loss: 1.0977	 validation accuracy: 0.8943
# Pruned 56 / 96% | Epoch #1	validation loss: 1.0922	 validation accuracy: 0.8952
# Pre-Finetuning Validation loss: 1.1077	 validation accuracy: 0.8946
# Fine tuning the model
# Pruned 57 / 96% | Epoch #0	validation loss: 1.0589	 validation accuracy: 0.8979
# Pruned 57 / 96% | Epoch #1	validation loss: 1.0491	 validation accuracy: 0.8960
# Pre-Finetuning Validation loss: 1.0607	 validation accuracy: 0.8949
# Fine tuning the model
# Pruned 58 / 96% | Epoch #0	validation loss: 1.0865	 validation accuracy: 0.8933
# Pruned 58 / 96% | Epoch #1	validation loss: 0.9681	 validation accuracy: 0.8933
# Pre-Finetuning Validation loss: 0.9658	 validation accuracy: 0.8929
# Fine tuning the model
# Pruned 59 / 96% | Epoch #0	validation loss: 1.0190	 validation accuracy: 0.8942
# Pruned 59 / 96% | Epoch #1	validation loss: 1.1096	 validation accuracy: 0.8968
# Pre-Finetuning Validation loss: 1.1220	 validation accuracy: 0.8929
# Fine tuning the model
# Pruned 60 / 96% | Epoch #0	validation loss: 1.1045	 validation accuracy: 0.8902
# Pruned 60 / 96% | Epoch #1	validation loss: 1.1203	 validation accuracy: 0.8976
# Pre-Finetuning Validation loss: 1.1359	 validation accuracy: 0.8943
# Fine tuning the model
# Pruned 61 / 96% | Epoch #0	validation loss: 1.1493	 validation accuracy: 0.8878
# Pruned 61 / 96% | Epoch #1	validation loss: 1.1786	 validation accuracy: 0.8957
# Pre-Finetuning Validation loss: 1.2031	 validation accuracy: 0.8938
# Fine tuning the model
# Pruned 62 / 96% | Epoch #0	validation loss: 0.9996	 validation accuracy: 0.8925
# Pruned 62 / 96% | Epoch #1	validation loss: 1.0899	 validation accuracy: 0.8949
# Pre-Finetuning Validation loss: 1.0960	 validation accuracy: 0.8941
# Fine tuning the model
# Pruned 63 / 96% | Epoch #0	validation loss: 1.0773	 validation accuracy: 0.8923
# Pruned 63 / 96% | Epoch #1	validation loss: 1.0919	 validation accuracy: 0.8941
# Pre-Finetuning Validation loss: 1.0968	 validation accuracy: 0.8944
# Fine tuning the model
# Pruned 64 / 96% | Epoch #0	validation loss: 1.1057	 validation accuracy: 0.8968
# Pruned 64 / 96% | Epoch #1	validation loss: 1.1575	 validation accuracy: 0.8957
# Pre-Finetuning Validation loss: 1.1988	 validation accuracy: 0.8942
# Fine tuning the model
# Pruned 65 / 96% | Epoch #0	validation loss: 1.1054	 validation accuracy: 0.8947
# Pruned 65 / 96% | Epoch #1	validation loss: 1.1077	 validation accuracy: 0.8941
# Pre-Finetuning Validation loss: 1.1227	 validation accuracy: 0.8932
# Fine tuning the model
# Pruned 66 / 96% | Epoch #0	validation loss: 1.0697	 validation accuracy: 0.8944
# Pruned 66 / 96% | Epoch #1	validation loss: 1.0836	 validation accuracy: 0.8935
# Pre-Finetuning Validation loss: 1.0862	 validation accuracy: 0.8893
# Fine tuning the model
# Pruned 67 / 96% | Epoch #0	validation loss: 1.1141	 validation accuracy: 0.8945
# Pruned 67 / 96% | Epoch #1	validation loss: 1.1563	 validation accuracy: 0.8901
# Pre-Finetuning Validation loss: 1.1838	 validation accuracy: 0.8862
# Fine tuning the model
# Pruned 68 / 96% | Epoch #0	validation loss: 1.0487	 validation accuracy: 0.8965
# Pruned 68 / 96% | Epoch #1	validation loss: 1.0643	 validation accuracy: 0.8965
# Pre-Finetuning Validation loss: 1.0935	 validation accuracy: 0.8942
# Fine tuning the model
# Pruned 69 / 96% | Epoch #0	validation loss: 1.0370	 validation accuracy: 0.8968
# Pruned 69 / 96% | Epoch #1	validation loss: 1.0552	 validation accuracy: 0.8957
# Pre-Finetuning Validation loss: 1.0663	 validation accuracy: 0.8961
# Fine tuning the model
# Pruned 70 / 96% | Epoch #0	validation loss: 1.0064	 validation accuracy: 0.8937
# Pruned 70 / 96% | Epoch #1	validation loss: 1.0332	 validation accuracy: 0.8971
# Pre-Finetuning Validation loss: 1.0357	 validation accuracy: 0.8946
# Fine tuning the model
# Pruned 71 / 96% | Epoch #0	validation loss: 1.0988	 validation accuracy: 0.8935
# Pruned 71 / 96% | Epoch #1	validation loss: 1.0414	 validation accuracy: 0.8928
# Pre-Finetuning Validation loss: 1.0545	 validation accuracy: 0.8898
# Fine tuning the model
# Pruned 72 / 96% | Epoch #0	validation loss: 1.0035	 validation accuracy: 0.8898
# Pruned 72 / 96% | Epoch #1	validation loss: 1.0314	 validation accuracy: 0.8919
# Pre-Finetuning Validation loss: 1.0941	 validation accuracy: 0.8879
# Fine tuning the model
# Pruned 73 / 96% | Epoch #0	validation loss: 0.9332	 validation accuracy: 0.8972
# Pruned 73 / 96% | Epoch #1	validation loss: 1.0151	 validation accuracy: 0.8953
# Pre-Finetuning Validation loss: 1.0475	 validation accuracy: 0.8895
# Fine tuning the model
# Pruned 74 / 96% | Epoch #0	validation loss: 0.9662	 validation accuracy: 0.8975
# Pruned 74 / 96% | Epoch #1	validation loss: 0.9821	 validation accuracy: 0.8953
# Pre-Finetuning Validation loss: 1.0014	 validation accuracy: 0.8906
# Fine tuning the model
# Pruned 75 / 96% | Epoch #0	validation loss: 0.8815	 validation accuracy: 0.8963
# Pruned 75 / 96% | Epoch #1	validation loss: 0.9705	 validation accuracy: 0.8953
# Pre-Finetuning Validation loss: 0.9827	 validation accuracy: 0.8923
# Fine tuning the model
# Pruned 76 / 96% | Epoch #0	validation loss: 0.9081	 validation accuracy: 0.8921
# Pruned 76 / 96% | Epoch #1	validation loss: 0.9172	 validation accuracy: 0.8928
# Pre-Finetuning Validation loss: 0.9369	 validation accuracy: 0.8913
# Fine tuning the model
# Pruned 77 / 96% | Epoch #0	validation loss: 0.8634	 validation accuracy: 0.8957
# Pruned 77 / 96% | Epoch #1	validation loss: 0.8849	 validation accuracy: 0.8970
# Pre-Finetuning Validation loss: 0.9025	 validation accuracy: 0.8904
# Fine tuning the model
# Pruned 78 / 96% | Epoch #0	validation loss: 0.8300	 validation accuracy: 0.8923
# Pruned 78 / 96% | Epoch #1	validation loss: 0.8378	 validation accuracy: 0.8945
# Pre-Finetuning Validation loss: 0.8585	 validation accuracy: 0.8868
# Fine tuning the model
# Pruned 79 / 96% | Epoch #0	validation loss: 0.7323	 validation accuracy: 0.8967
# Pruned 79 / 96% | Epoch #1	validation loss: 0.7428	 validation accuracy: 0.8947
# Pre-Finetuning Validation loss: 0.7682	 validation accuracy: 0.8866
# Fine tuning the model
# Pruned 80 / 96% | Epoch #0	validation loss: 0.7418	 validation accuracy: 0.8913
# Pruned 80 / 96% | Epoch #1	validation loss: 0.7972	 validation accuracy: 0.8944
# Pre-Finetuning Validation loss: 0.8841	 validation accuracy: 0.8815
# Fine tuning the model
# Pruned 81 / 96% | Epoch #0	validation loss: 0.7254	 validation accuracy: 0.8911
# Pruned 81 / 96% | Epoch #1	validation loss: 0.7363	 validation accuracy: 0.8923
# Pre-Finetuning Validation loss: 0.7524	 validation accuracy: 0.8839
# Fine tuning the model
# Pruned 82 / 96% | Epoch #0	validation loss: 0.6734	 validation accuracy: 0.8872
# Pruned 82 / 96% | Epoch #1	validation loss: 0.6614	 validation accuracy: 0.8950
# Pre-Finetuning Validation loss: 0.7118	 validation accuracy: 0.8877
# Fine tuning the model
# Pruned 83 / 96% | Epoch #0	validation loss: 0.6380	 validation accuracy: 0.8938
# Pruned 83 / 96% | Epoch #1	validation loss: 0.6220	 validation accuracy: 0.8957
# Pre-Finetuning Validation loss: 0.6807	 validation accuracy: 0.8805
# Fine tuning the model
# Pruned 84 / 96% | Epoch #0	validation loss: 0.5297	 validation accuracy: 0.8913
# Pruned 84 / 96% | Epoch #1	validation loss: 0.5790	 validation accuracy: 0.8903
# Pre-Finetuning Validation loss: 0.6523	 validation accuracy: 0.8744
# Fine tuning the model
# Pruned 85 / 96% | Epoch #0	validation loss: 0.5031	 validation accuracy: 0.8917
# Pruned 85 / 96% | Epoch #1	validation loss: 0.5121	 validation accuracy: 0.8912
# Pre-Finetuning Validation loss: 0.5930	 validation accuracy: 0.8734
# Fine tuning the model
# Pruned 86 / 96% | Epoch #0	validation loss: 0.4620	 validation accuracy: 0.8931
# Pruned 86 / 96% | Epoch #1	validation loss: 0.4838	 validation accuracy: 0.8898
# Pre-Finetuning Validation loss: 0.6120	 validation accuracy: 0.8449
# Fine tuning the model
# Pruned 87 / 96% | Epoch #0	validation loss: 0.4041	 validation accuracy: 0.8887
# Pruned 87 / 96% | Epoch #1	validation loss: 0.4118	 validation accuracy: 0.8920
# Pre-Finetuning Validation loss: 0.5053	 validation accuracy: 0.8581
# Fine tuning the model
# Pruned 88 / 96% | Epoch #0	validation loss: 0.3969	 validation accuracy: 0.8817
# Pruned 88 / 96% | Epoch #1	validation loss: 0.3816	 validation accuracy: 0.8882
# Pre-Finetuning Validation loss: 0.5917	 validation accuracy: 0.7962
# Fine tuning the model
# Pruned 89 / 96% | Epoch #0	validation loss: 0.3742	 validation accuracy: 0.8761
# Pruned 89 / 96% | Epoch #1	validation loss: 0.3581	 validation accuracy: 0.8827
# Pre-Finetuning Validation loss: 0.4797	 validation accuracy: 0.8378
# Fine tuning the model
# Pruned 90 / 96% | Epoch #0	validation loss: 0.3657	 validation accuracy: 0.8740
# Pruned 90 / 96% | Epoch #1	validation loss: 0.3552	 validation accuracy: 0.8790
# Pre-Finetuning Validation loss: 0.5082	 validation accuracy: 0.8240
# Fine tuning the model
# Pruned 91 / 96% | Epoch #0	validation loss: 0.3595	 validation accuracy: 0.8774
# Pruned 91 / 96% | Epoch #1	validation loss: 0.3540	 validation accuracy: 0.8824
# Pre-Finetuning Validation loss: 0.6374	 validation accuracy: 0.7882
# Fine tuning the model
# Pruned 92 / 96% | Epoch #0	validation loss: 0.3619	 validation accuracy: 0.8737
# Pruned 92 / 96% | Epoch #1	validation loss: 0.3588	 validation accuracy: 0.8744
# Pre-Finetuning Validation loss: 0.6895	 validation accuracy: 0.7557
# Fine tuning the model
# Pruned 93 / 96% | Epoch #0	validation loss: 0.4153	 validation accuracy: 0.8528
# Pruned 93 / 96% | Epoch #1	validation loss: 0.3958	 validation accuracy: 0.8640
# Pre-Finetuning Validation loss: 0.6580	 validation accuracy: 0.7490
# Fine tuning the model
# Pruned 94 / 96% | Epoch #0	validation loss: 0.4454	 validation accuracy: 0.8377
# Pruned 94 / 96% | Epoch #1	validation loss: 0.4205	 validation accuracy: 0.8510
# Pre-Finetuning Validation loss: 1.4342	 validation accuracy: 0.5592
# Fine tuning the model
# Pruned 95 / 96% | Epoch #0	validation loss: 0.5054	 validation accuracy: 0.8180
# Pruned 95 / 96% | Epoch #1	validation loss: 0.4749	 validation accuracy: 0.8315
# Pre-Finetuning Validation loss: 1.0241	 validation accuracy: 0.6554
# Fine tuning the model
# Pruned 96 / 96% | Epoch #0	validation loss: 0.5764	 validation accuracy: 0.7728
# Pruned 96 / 96% | Epoch #1	validation loss: 0.5387	 validation accuracy: 0.8031
# Target total pruning: 0.96, pruning_step: 0.01, method: L1Unstructured, finetune_epochs: 3
# Pre-Finetuning Validation loss: 0.2411	 validation accuracy: 0.9047
# Fine tuning the model
# Pruned 1 / 96% | Epoch #0	validation loss: 0.2442	 validation accuracy: 0.9096
# Pruned 1 / 96% | Epoch #1	validation loss: 0.2328	 validation accuracy: 0.9114
# Pruned 1 / 96% | Epoch #2	validation loss: 0.2504	 validation accuracy: 0.9079
# Pre-Finetuning Validation loss: 0.2504	 validation accuracy: 0.9079
# Fine tuning the model
# Pruned 2 / 96% | Epoch #0	validation loss: 0.2502	 validation accuracy: 0.9082
# Pruned 2 / 96% | Epoch #1	validation loss: 0.2529	 validation accuracy: 0.9065
# Pruned 2 / 96% | Epoch #2	validation loss: 0.2577	 validation accuracy: 0.9077
# Pre-Finetuning Validation loss: 0.2578	 validation accuracy: 0.9075
# Fine tuning the model
# Pruned 3 / 96% | Epoch #0	validation loss: 0.2466	 validation accuracy: 0.9087
# Pruned 3 / 96% | Epoch #1	validation loss: 0.2502	 validation accuracy: 0.9148
# Pruned 3 / 96% | Epoch #2	validation loss: 0.2580	 validation accuracy: 0.9091
# Pre-Finetuning Validation loss: 0.2580	 validation accuracy: 0.9091
# Fine tuning the model
# Pruned 4 / 96% | Epoch #0	validation loss: 0.2610	 validation accuracy: 0.9109
# Pruned 4 / 96% | Epoch #1	validation loss: 0.2692	 validation accuracy: 0.9075
# Pruned 4 / 96% | Epoch #2	validation loss: 0.2544	 validation accuracy: 0.9154
# Pre-Finetuning Validation loss: 0.2544	 validation accuracy: 0.9154
# Fine tuning the model
# Pruned 5 / 96% | Epoch #0	validation loss: 0.2890	 validation accuracy: 0.9053
# Pruned 5 / 96% | Epoch #1	validation loss: 0.2725	 validation accuracy: 0.9084
# Pruned 5 / 96% | Epoch #2	validation loss: 0.2847	 validation accuracy: 0.9092
# Pre-Finetuning Validation loss: 0.2847	 validation accuracy: 0.9092
# Fine tuning the model
# Pruned 6 / 96% | Epoch #0	validation loss: 0.2773	 validation accuracy: 0.9103
# Pruned 6 / 96% | Epoch #1	validation loss: 0.3182	 validation accuracy: 0.9050
# Pruned 6 / 96% | Epoch #2	validation loss: 0.2954	 validation accuracy: 0.9055
# Pre-Finetuning Validation loss: 0.2954	 validation accuracy: 0.9054
# Fine tuning the model
# Pruned 7 / 96% | Epoch #0	validation loss: 0.3245	 validation accuracy: 0.9024
# Pruned 7 / 96% | Epoch #1	validation loss: 0.3255	 validation accuracy: 0.9074
# Pruned 7 / 96% | Epoch #2	validation loss: 0.3474	 validation accuracy: 0.9028
# Pre-Finetuning Validation loss: 0.3475	 validation accuracy: 0.9028
# Fine tuning the model
# Pruned 8 / 96% | Epoch #0	validation loss: 0.3369	 validation accuracy: 0.9014
# Pruned 8 / 96% | Epoch #1	validation loss: 0.3273	 validation accuracy: 0.9068
# Pruned 8 / 96% | Epoch #2	validation loss: 0.3547	 validation accuracy: 0.9078
# Pre-Finetuning Validation loss: 0.3547	 validation accuracy: 0.9078
# Fine tuning the model
# Pruned 9 / 96% | Epoch #0	validation loss: 0.4128	 validation accuracy: 0.8999
# Pruned 9 / 96% | Epoch #1	validation loss: 0.3447	 validation accuracy: 0.9103
# Pruned 9 / 96% | Epoch #2	validation loss: 0.4193	 validation accuracy: 0.8953
# Pre-Finetuning Validation loss: 0.4194	 validation accuracy: 0.8953
# Fine tuning the model
# Pruned 10 / 96% | Epoch #0	validation loss: 0.4372	 validation accuracy: 0.8949
# Pruned 10 / 96% | Epoch #1	validation loss: 0.3828	 validation accuracy: 0.9000
# Pruned 10 / 96% | Epoch #2	validation loss: 0.4010	 validation accuracy: 0.9051
# Pre-Finetuning Validation loss: 0.4011	 validation accuracy: 0.9051
# Fine tuning the model
# Pruned 11 / 96% | Epoch #0	validation loss: 0.4307	 validation accuracy: 0.9013
# Pruned 11 / 96% | Epoch #1	validation loss: 0.4394	 validation accuracy: 0.9047
# Pruned 11 / 96% | Epoch #2	validation loss: 0.4170	 validation accuracy: 0.9045
# Pre-Finetuning Validation loss: 0.4170	 validation accuracy: 0.9045
# Fine tuning the model
# Pruned 12 / 96% | Epoch #0	validation loss: 0.4580	 validation accuracy: 0.9004
# Pruned 12 / 96% | Epoch #1	validation loss: 0.4662	 validation accuracy: 0.8979
# Pruned 12 / 96% | Epoch #2	validation loss: 0.4441	 validation accuracy: 0.8993
# Pre-Finetuning Validation loss: 0.4441	 validation accuracy: 0.8991
# Fine tuning the model
# Pruned 13 / 96% | Epoch #0	validation loss: 0.5466	 validation accuracy: 0.8962
# Pruned 13 / 96% | Epoch #1	validation loss: 0.4548	 validation accuracy: 0.8979
# Pruned 13 / 96% | Epoch #2	validation loss: 0.4997	 validation accuracy: 0.8984
# Pre-Finetuning Validation loss: 0.4995	 validation accuracy: 0.8981
# Fine tuning the model
# Pruned 14 / 96% | Epoch #0	validation loss: 0.5045	 validation accuracy: 0.9051
# Pruned 14 / 96% | Epoch #1	validation loss: 0.5354	 validation accuracy: 0.9042
# Pruned 14 / 96% | Epoch #2	validation loss: 0.5263	 validation accuracy: 0.8974
# Pre-Finetuning Validation loss: 0.5262	 validation accuracy: 0.8975
# Fine tuning the model
# Pruned 15 / 96% | Epoch #0	validation loss: 0.5150	 validation accuracy: 0.9019
# Pruned 15 / 96% | Epoch #1	validation loss: 0.5232	 validation accuracy: 0.8992
# Pruned 15 / 96% | Epoch #2	validation loss: 0.5254	 validation accuracy: 0.8947
# Pre-Finetuning Validation loss: 0.5254	 validation accuracy: 0.8947
# Fine tuning the model
# Pruned 16 / 96% | Epoch #0	validation loss: 0.5061	 validation accuracy: 0.9007
# Pruned 16 / 96% | Epoch #1	validation loss: 0.5729	 validation accuracy: 0.8988
# Pruned 16 / 96% | Epoch #2	validation loss: 0.5836	 validation accuracy: 0.8972
# Pre-Finetuning Validation loss: 0.5834	 validation accuracy: 0.8972
# Fine tuning the model
# Pruned 17 / 96% | Epoch #0	validation loss: 0.5496	 validation accuracy: 0.8993
# Pruned 17 / 96% | Epoch #1	validation loss: 0.5724	 validation accuracy: 0.9026
# Pruned 17 / 96% | Epoch #2	validation loss: 0.5804	 validation accuracy: 0.9008
# Pre-Finetuning Validation loss: 0.5803	 validation accuracy: 0.9007
# Fine tuning the model
# Pruned 18 / 96% | Epoch #0	validation loss: 0.5582	 validation accuracy: 0.9013
# Pruned 18 / 96% | Epoch #1	validation loss: 0.6016	 validation accuracy: 0.9013
# Pruned 18 / 96% | Epoch #2	validation loss: 0.5903	 validation accuracy: 0.8973
# Pre-Finetuning Validation loss: 0.5902	 validation accuracy: 0.8972
# Fine tuning the model
# Pruned 19 / 96% | Epoch #0	validation loss: 0.6122	 validation accuracy: 0.8994
# Pruned 19 / 96% | Epoch #1	validation loss: 0.6178	 validation accuracy: 0.9011
# Pruned 19 / 96% | Epoch #2	validation loss: 0.6547	 validation accuracy: 0.8978
# Pre-Finetuning Validation loss: 0.6545	 validation accuracy: 0.8977
# Fine tuning the model
# Pruned 20 / 96% | Epoch #0	validation loss: 0.6476	 validation accuracy: 0.9026
# Pruned 20 / 96% | Epoch #1	validation loss: 0.6439	 validation accuracy: 0.9007
# Pruned 20 / 96% | Epoch #2	validation loss: 0.6198	 validation accuracy: 0.9007
# Pre-Finetuning Validation loss: 0.6196	 validation accuracy: 0.9007
# Fine tuning the model
# Pruned 21 / 96% | Epoch #0	validation loss: 0.6342	 validation accuracy: 0.8984
# Pruned 21 / 96% | Epoch #1	validation loss: 0.6851	 validation accuracy: 0.8997
# Pruned 21 / 96% | Epoch #2	validation loss: 0.6888	 validation accuracy: 0.9004
# Pre-Finetuning Validation loss: 0.6889	 validation accuracy: 0.9003
# Fine tuning the model
# Pruned 22 / 96% | Epoch #0	validation loss: 0.7122	 validation accuracy: 0.8983
# Pruned 22 / 96% | Epoch #1	validation loss: 0.6842	 validation accuracy: 0.9007
# Pruned 22 / 96% | Epoch #2	validation loss: 0.6995	 validation accuracy: 0.8997
# Pre-Finetuning Validation loss: 0.6995	 validation accuracy: 0.8999
# Fine tuning the model
# Pruned 23 / 96% | Epoch #0	validation loss: 0.7126	 validation accuracy: 0.8981
# ...
# Pruned 24 / 96% | Epoch #2	validation loss: 0.3010	 validation accuracy: 0.9056
# Pre-Finetuning Validation loss: 0.3012	 validation accuracy: 0.9047
# Fine tuning the model
# Pruned 28 / 96% | Epoch #0	validation loss: 0.2945	 validation accuracy: 0.9097
# Pruned 28 / 96% | Epoch #1	validation loss: 0.3064	 validation accuracy: 0.9094
# Pruned 28 / 96% | Epoch #2	validation loss: 0.3284	 validation accuracy: 0.9072
# Pre-Finetuning Validation loss: 0.3295	 validation accuracy: 0.9067
# Fine tuning the model
# Pruned 32 / 96% | Epoch #0	validation loss: 0.3194	 validation accuracy: 0.9098
# Pruned 32 / 96% | Epoch #1	validation loss: 0.3390	 validation accuracy: 0.9067
# Pruned 32 / 96% | Epoch #2	validation loss: 0.3313	 validation accuracy: 0.9097
# Pre-Finetuning Validation loss: 0.3328	 validation accuracy: 0.9087
# Fine tuning the model
# Pruned 36 / 96% | Epoch #0	validation loss: 0.3532	 validation accuracy: 0.9069
# Pruned 36 / 96% | Epoch #1	validation loss: 0.3456	 validation accuracy: 0.9066
# Pruned 36 / 96% | Epoch #2	validation loss: 0.4102	 validation accuracy: 0.9026
# Pre-Finetuning Validation loss: 0.4137	 validation accuracy: 0.9023
# Fine tuning the model
# Pruned 40 / 96% | Epoch #0	validation loss: 0.3709	 validation accuracy: 0.9095
# Pruned 40 / 96% | Epoch #1	validation loss: 0.4035	 validation accuracy: 0.9038
# Pruned 40 / 96% | Epoch #2	validation loss: 0.3965	 validation accuracy: 0.9032
# Pre-Finetuning Validation loss: 0.4048	 validation accuracy: 0.9011
# Fine tuning the model
# Pruned 44 / 96% | Epoch #0	validation loss: 0.3958	 validation accuracy: 0.9025
# Pruned 44 / 96% | Epoch #1	validation loss: 0.4298	 validation accuracy: 0.9052
# Pruned 44 / 96% | Epoch #2	validation loss: 0.4258	 validation accuracy: 0.9060
# Pre-Finetuning Validation loss: 0.4353	 validation accuracy: 0.9040
# Fine tuning the model
# Pruned 48 / 96% | Epoch #0	validation loss: 0.4404	 validation accuracy: 0.9007
# Pruned 48 / 96% | Epoch #1	validation loss: 0.4233	 validation accuracy: 0.9003
# Pruned 48 / 96% | Epoch #2	validation loss: 0.4507	 validation accuracy: 0.9038
# Pre-Finetuning Validation loss: 0.4602	 validation accuracy: 0.9017
# Fine tuning the model
# Pruned 52 / 96% | Epoch #0	validation loss: 0.4652	 validation accuracy: 0.9049
# Pruned 52 / 96% | Epoch #1	validation loss: 0.4766	 validation accuracy: 0.9041
# Pruned 52 / 96% | Epoch #2	validation loss: 0.4432	 validation accuracy: 0.9053
# Pre-Finetuning Validation loss: 0.4504	 validation accuracy: 0.9029
# Fine tuning the model
# Pruned 56 / 96% | Epoch #0	validation loss: 0.4716	 validation accuracy: 0.9054
# Pruned 56 / 96% | Epoch #1	validation loss: 0.4769	 validation accuracy: 0.9053
# Pruned 56 / 96% | Epoch #2	validation loss: 0.4965	 validation accuracy: 0.9047
# Pre-Finetuning Validation loss: 0.5097	 validation accuracy: 0.9013
# Fine tuning the model
# Pruned 60 / 96% | Epoch #0	validation loss: 0.5114	 validation accuracy: 0.9017
# Pruned 60 / 96% | Epoch #1	validation loss: 0.4947	 validation accuracy: 0.9042
# Pruned 60 / 96% | Epoch #2	validation loss: 0.5842	 validation accuracy: 0.9010
# Pre-Finetuning Validation loss: 0.6409	 validation accuracy: 0.8961
# Fine tuning the model
# Pruned 64 / 96% | Epoch #0	validation loss: 0.5081	 validation accuracy: 0.8971
# Pruned 64 / 96% | Epoch #1	validation loss: 0.5199	 validation accuracy: 0.9009
# Pruned 64 / 96% | Epoch #2	validation loss: 0.5450	 validation accuracy: 0.9058
# Pre-Finetuning Validation loss: 0.5461	 validation accuracy: 0.8975
# Fine tuning the model
# Pruned 68 / 96% | Epoch #0	validation loss: 0.5275	 validation accuracy: 0.9028
# Pruned 68 / 96% | Epoch #1	validation loss: 0.5805	 validation accuracy: 0.9018
# Pruned 68 / 96% | Epoch #2	validation loss: 0.5576	 validation accuracy: 0.9038
# Pre-Finetuning Validation loss: 0.6132	 validation accuracy: 0.8924
# Fine tuning the model
# Pruned 72 / 96% | Epoch #0	validation loss: 0.5264	 validation accuracy: 0.9047
# Pruned 72 / 96% | Epoch #1	validation loss: 0.5448	 validation accuracy: 0.9008
# Pruned 72 / 96% | Epoch #2	validation loss: 0.5354	 validation accuracy: 0.9025
# Pre-Finetuning Validation loss: 0.5964	 validation accuracy: 0.8913
# Fine tuning the model
# Pruned 76 / 96% | Epoch #0	validation loss: 0.4914	 validation accuracy: 0.8996
# Pruned 76 / 96% | Epoch #1	validation loss: 0.5339	 validation accuracy: 0.8987
# Pruned 76 / 96% | Epoch #2	validation loss: 0.5184	 validation accuracy: 0.9039
# Pre-Finetuning Validation loss: 0.5805	 validation accuracy: 0.8844
# Fine tuning the model
# Pruned 80 / 96% | Epoch #0	validation loss: 0.4837	 validation accuracy: 0.8971
# Pruned 80 / 96% | Epoch #1	validation loss: 0.4750	 validation accuracy: 0.9003
# Pruned 80 / 96% | Epoch #2	validation loss: 0.4876	 validation accuracy: 0.8984
# Pre-Finetuning Validation loss: 0.6393	 validation accuracy: 0.8648
# Fine tuning the model
# Pruned 84 / 96% | Epoch #0	validation loss: 0.3963	 validation accuracy: 0.8961
# Pruned 84 / 96% | Epoch #1	validation loss: 0.4247	 validation accuracy: 0.9020
# Pruned 84 / 96% | Epoch #2	validation loss: 0.4422	 validation accuracy: 0.9028
# Pre-Finetuning Validation loss: 0.6111	 validation accuracy: 0.8541
# Fine tuning the model
# Pruned 88 / 96% | Epoch #0	validation loss: 0.3435	 validation accuracy: 0.8966
# Pruned 88 / 96% | Epoch #1	validation loss: 0.3525	 validation accuracy: 0.8970
# Pruned 88 / 96% | Epoch #2	validation loss: 0.3547	 validation accuracy: 0.8953
# Pre-Finetuning Validation loss: 0.6206	 validation accuracy: 0.8197
# Fine tuning the model
# Pruned 92 / 96% | Epoch #0	validation loss: 0.3102	 validation accuracy: 0.8938
# Pruned 92 / 96% | Epoch #1	validation loss: 0.3186	 validation accuracy: 0.8892
# Pruned 92 / 96% | Epoch #2	validation loss: 0.3035	 validation accuracy: 0.8956
# Pre-Finetuning Validation loss: 1.0644	 validation accuracy: 0.6219
# Fine tuning the model
# Pruned 96 / 96% | Epoch #0	validation loss: 0.3742	 validation accuracy: 0.8680
# Pruned 96 / 96% | Epoch #1	validation loss: 0.3345	 validation accuracy: 0.8831
# Pruned 96 / 96% | Epoch #2	validation loss: 0.3248	 validation accuracy: 0.8864
# Target total pruning: 0.96, pruning_step: 0.04, method: L1Unstructured, finetune_epochs: 4
# Pre-Finetuning Validation loss: 0.2411	 validation accuracy: 0.9046
# Fine tuning the model
# Pruned 4 / 96% | Epoch #0	validation loss: 0.2433	 validation accuracy: 0.9107
# Pruned 4 / 96% | Epoch #1	validation loss: 0.2370	 validation accuracy: 0.9133
# Pruned 4 / 96% | Epoch #2	validation loss: 0.2651	 validation accuracy: 0.9011
# Pruned 4 / 96% | Epoch #3	validation loss: 0.2407	 validation accuracy: 0.9107
# Pre-Finetuning Validation loss: 0.2407	 validation accuracy: 0.9105
# Fine tuning the model
# Pruned 8 / 96% | Epoch #0	validation loss: 0.2481	 validation accuracy: 0.9085
# Pruned 8 / 96% | Epoch #1	validation loss: 0.2370	 validation accuracy: 0.9138
# Pruned 8 / 96% | Epoch #2	validation loss: 0.2550	 validation accuracy: 0.9118
# Pruned 8 / 96% | Epoch #3	validation loss: 0.2477	 validation accuracy: 0.9127
# Pre-Finetuning Validation loss: 0.2479	 validation accuracy: 0.9123
# Fine tuning the model
# Pruned 12 / 96% | Epoch #0	validation loss: 0.2416	 validation accuracy: 0.9152
# Pruned 12 / 96% | Epoch #1	validation loss: 0.2640	 validation accuracy: 0.9057
# Pruned 12 / 96% | Epoch #2	validation loss: 0.2496	 validation accuracy: 0.9126
# Pruned 12 / 96% | Epoch #3	validation loss: 0.2589	 validation accuracy: 0.9117
# Pre-Finetuning Validation loss: 0.2591	 validation accuracy: 0.9112
# Fine tuning the model
# Pruned 16 / 96% | Epoch #0	validation loss: 0.2852	 validation accuracy: 0.9019
# Pruned 16 / 96% | Epoch #1	validation loss: 0.2632	 validation accuracy: 0.9114
# Pruned 16 / 96% | Epoch #2	validation loss: 0.2830	 validation accuracy: 0.9097
# Pruned 16 / 96% | Epoch #3	validation loss: 0.2872	 validation accuracy: 0.9083
# Pre-Finetuning Validation loss: 0.2875	 validation accuracy: 0.9081
# Fine tuning the model
# Pruned 20 / 96% | Epoch #0	validation loss: 0.3063	 validation accuracy: 0.9018
# Pruned 20 / 96% | Epoch #1	validation loss: 0.2956	 validation accuracy: 0.9088
# Pruned 20 / 96% | Epoch #2	validation loss: 0.3198	 validation accuracy: 0.9043
# Pruned 20 / 96% | Epoch #3	validation loss: 0.3139	 validation accuracy: 0.9043
# Pre-Finetuning Validation loss: 0.3138	 validation accuracy: 0.9044
# Fine tuning the model
# Pruned 24 / 96% | Epoch #0	validation loss: 0.3119	 validation accuracy: 0.9093
# Pruned 24 / 96% | Epoch #1	validation loss: 0.3281	 validation accuracy: 0.9089
# Pruned 24 / 96% | Epoch #2	validation loss: 0.3524	 validation accuracy: 0.9021
# Pruned 24 / 96% | Epoch #3	validation loss: 0.3531	 validation accuracy: 0.9089
# Pre-Finetuning Validation loss: 0.3539	 validation accuracy: 0.9088
# Fine tuning the model
# Pruned 28 / 96% | Epoch #0	validation loss: 0.3628	 validation accuracy: 0.9017
# Pruned 28 / 96% | Epoch #1	validation loss: 0.3724	 validation accuracy: 0.9114
# Pruned 28 / 96% | Epoch #2	validation loss: 0.3673	 validation accuracy: 0.9094
# Pruned 28 / 96% | Epoch #3	validation loss: 0.4018	 validation accuracy: 0.9032
# Pre-Finetuning Validation loss: 0.4025	 validation accuracy: 0.9026
# Fine tuning the model
# Pruned 32 / 96% | Epoch #0	validation loss: 0.4163	 validation accuracy: 0.9005
# Pruned 32 / 96% | Epoch #1	validation loss: 0.3897	 validation accuracy: 0.9078
# Pruned 32 / 96% | Epoch #2	validation loss: 0.4070	 validation accuracy: 0.9106
# Pruned 32 / 96% | Epoch #3	validation loss: 0.4097	 validation accuracy: 0.9017
# Pre-Finetuning Validation loss: 0.4107	 validation accuracy: 0.9009
# Fine tuning the model
# Pruned 36 / 96% | Epoch #0	validation loss: 0.4912	 validation accuracy: 0.8947
# Pruned 36 / 96% | Epoch #1	validation loss: 0.4320	 validation accuracy: 0.9026
# Pruned 36 / 96% | Epoch #2	validation loss: 0.4484	 validation accuracy: 0.9024
# Pruned 36 / 96% | Epoch #3	validation loss: 0.4422	 validation accuracy: 0.9041
# Pre-Finetuning Validation loss: 0.4437	 validation accuracy: 0.9037
# Fine tuning the model
# Pruned 40 / 96% | Epoch #0	validation loss: 0.4638	 validation accuracy: 0.9041
# Pruned 40 / 96% | Epoch #1	validation loss: 0.4977	 validation accuracy: 0.9050
# Pruned 40 / 96% | Epoch #2	validation loss: 0.5001	 validation accuracy: 0.8980
# Pruned 40 / 96% | Epoch #3	validation loss: 0.4777	 validation accuracy: 0.9045
# Pre-Finetuning Validation loss: 0.4812	 validation accuracy: 0.9027
# Fine tuning the model
# Pruned 44 / 96% | Epoch #0	validation loss: 0.5230	 validation accuracy: 0.8980
# Pruned 44 / 96% | Epoch #1	validation loss: 0.5272	 validation accuracy: 0.8957
# Pruned 44 / 96% | Epoch #2	validation loss: 0.5059	 validation accuracy: 0.9008
# Pruned 44 / 96% | Epoch #3	validation loss: 0.5291	 validation accuracy: 0.9028
# Pre-Finetuning Validation loss: 0.5333	 validation accuracy: 0.9028
# Fine tuning the model
# Pruned 48 / 96% | Epoch #0	validation loss: 0.5236	 validation accuracy: 0.9052
# Pruned 48 / 96% | Epoch #1	validation loss: 0.5644	 validation accuracy: 0.9049
# Pruned 48 / 96% | Epoch #2	validation loss: 0.5840	 validation accuracy: 0.9056
# Pruned 48 / 96% | Epoch #3	validation loss: 0.5767	 validation accuracy: 0.9034
# Pre-Finetuning Validation loss: 0.5859	 validation accuracy: 0.9004
# Fine tuning the model
# Pruned 52 / 96% | Epoch #0	validation loss: 0.5593	 validation accuracy: 0.8991
# Pruned 52 / 96% | Epoch #1	validation loss: 0.6167	 validation accuracy: 0.8978
# Pruned 52 / 96% | Epoch #2	validation loss: 0.5954	 validation accuracy: 0.8951
# Pruned 52 / 96% | Epoch #3	validation loss: 0.5872	 validation accuracy: 0.9013
# Pre-Finetuning Validation loss: 0.5997	 validation accuracy: 0.9012
# Fine tuning the model
# Pruned 56 / 96% | Epoch #0	validation loss: 0.6048	 validation accuracy: 0.8967
# Pruned 56 / 96% | Epoch #1	validation loss: 0.6340	 validation accuracy: 0.9005
# Pruned 56 / 96% | Epoch #2	validation loss: 0.6309	 validation accuracy: 0.9038
# Pruned 56 / 96% | Epoch #3	validation loss: 0.6470	 validation accuracy: 0.8997
# Pre-Finetuning Validation loss: 0.6604	 validation accuracy: 0.8974
# Fine tuning the model
# Pruned 60 / 96% | Epoch #0	validation loss: 0.6164	 validation accuracy: 0.9023
# Pruned 60 / 96% | Epoch #1	validation loss: 0.6226	 validation accuracy: 0.8967
# Pruned 60 / 96% | Epoch #2	validation loss: 0.6629	 validation accuracy: 0.9008
# Pruned 60 / 96% | Epoch #3	validation loss: 0.6789	 validation accuracy: 0.9016
# Pre-Finetuning Validation loss: 0.6958	 validation accuracy: 0.8966
# Fine tuning the model
# Pruned 64 / 96% | Epoch #0	validation loss: 0.7115	 validation accuracy: 0.8990
# Pruned 64 / 96% | Epoch #1	validation loss: 0.7107	 validation accuracy: 0.8988
# Pruned 64 / 96% | Epoch #2	validation loss: 0.6779	 validation accuracy: 0.8988
# Pruned 64 / 96% | Epoch #3	validation loss: 0.7111	 validation accuracy: 0.9022
# Pre-Finetuning Validation loss: 0.7449	 validation accuracy: 0.8982
# Fine tuning the model
# Pruned 68 / 96% | Epoch #0	validation loss: 0.6745	 validation accuracy: 0.9004
# Pruned 68 / 96% | Epoch #1	validation loss: 0.6571	 validation accuracy: 0.8997
# Pruned 68 / 96% | Epoch #2	validation loss: 0.6697	 validation accuracy: 0.8995
# Pruned 68 / 96% | Epoch #3	validation loss: 0.7243	 validation accuracy: 0.8992
# Pre-Finetuning Validation loss: 0.7592	 validation accuracy: 0.8866
# Fine tuning the model
# Pruned 72 / 96% | Epoch #0	validation loss: 0.5965	 validation accuracy: 0.8975
# Pruned 72 / 96% | Epoch #1	validation loss: 0.6887	 validation accuracy: 0.8932
# Pruned 72 / 96% | Epoch #2	validation loss: 0.6722	 validation accuracy: 0.9012
# Pruned 72 / 96% | Epoch #3	validation loss: 0.7098	 validation accuracy: 0.9010
# Pre-Finetuning Validation loss: 0.8444	 validation accuracy: 0.8861
# Fine tuning the model
# Pruned 76 / 96% | Epoch #0	validation loss: 0.6627	 validation accuracy: 0.8914
# Pruned 76 / 96% | Epoch #1	validation loss: 0.5904	 validation accuracy: 0.8996
# Pruned 76 / 96% | Epoch #2	validation loss: 0.6343	 validation accuracy: 0.9002
# Pruned 76 / 96% | Epoch #3	validation loss: 0.6805	 validation accuracy: 0.9007
# Pre-Finetuning Validation loss: 0.9594	 validation accuracy: 0.8520
# Fine tuning the model
# Pruned 80 / 96% | Epoch #0	validation loss: 0.5695	 validation accuracy: 0.8900
# Pruned 80 / 96% | Epoch #1	validation loss: 0.5181	 validation accuracy: 0.8967
# Pruned 80 / 96% | Epoch #2	validation loss: 0.6035	 validation accuracy: 0.8921
# Pruned 80 / 96% | Epoch #3	validation loss: 0.6133	 validation accuracy: 0.8954
# Pre-Finetuning Validation loss: 0.7558	 validation accuracy: 0.8606
# Fine tuning the model
# Pruned 84 / 96% | Epoch #0	validation loss: 0.4559	 validation accuracy: 0.8927
# Pruned 84 / 96% | Epoch #1	validation loss: 0.4884	 validation accuracy: 0.8913
# Pruned 84 / 96% | Epoch #2	validation loss: 0.5302	 validation accuracy: 0.8942
# Pruned 84 / 96% | Epoch #3	validation loss: 0.5053	 validation accuracy: 0.8967
# Pre-Finetuning Validation loss: 0.7684	 validation accuracy: 0.8287
# Fine tuning the model
# Pruned 88 / 96% | Epoch #0	validation loss: 0.3907	 validation accuracy: 0.8907
# Pruned 88 / 96% | Epoch #1	validation loss: 0.3854	 validation accuracy: 0.8947
# Pruned 88 / 96% | Epoch #2	validation loss: 0.3845	 validation accuracy: 0.8938
# Pruned 88 / 96% | Epoch #3	validation loss: 0.3904	 validation accuracy: 0.8940
# Pre-Finetuning Validation loss: 0.9677	 validation accuracy: 0.7621
# Fine tuning the model
# Pruned 92 / 96% | Epoch #0	validation loss: 0.3463	 validation accuracy: 0.8825
# Pruned 92 / 96% | Epoch #1	validation loss: 0.3178	 validation accuracy: 0.8963
# Pruned 92 / 96% | Epoch #2	validation loss: 0.3239	 validation accuracy: 0.8956
# Pruned 92 / 96% | Epoch #3	validation loss: 0.3351	 validation accuracy: 0.8942
# Pre-Finetuning Validation loss: 1.8781	 validation accuracy: 0.4742
# Fine tuning the model
# Pruned 96 / 96% | Epoch #0	validation loss: 0.4057	 validation accuracy: 0.8634
# Pruned 96 / 96% | Epoch #1	validation loss: 0.3720	 validation accuracy: 0.8737
# Pruned 96 / 96% | Epoch #2	validation loss: 0.4032	 validation accuracy: 0.8608
# Pruned 96 / 96% | Epoch #3	validation loss: 0.3467	 validation accuracy: 0.8795
