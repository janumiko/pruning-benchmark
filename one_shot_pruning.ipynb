# %%
import torch.nn.utils.prune as prune

import torch

import torch.nn as nn
import torch.optim as optim

from pathlib import Path
from constants import DATA_PATH, MODELS_PATH
from LeNet import LeNet, BATCH_SIZE
from pruning_metadata import PruningMetadata
from utility.pruning import (
    calculate_parameters_amount,
    get_parameters_to_prune,
)
from utility.cifar_dataset import get_dataloaders
from dataclasses import asdict

import utility
import itertools

# %% [markdown]
# ### Load the data

# %%
train_loader, validation_loader, test_loader = get_dataloaders(
    data_path=DATA_PATH, batch_size=BATCH_SIZE
)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
# Get cpu, gpu or mps device for training.
device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")
print(f"Using {torch.cuda.get_device_name(torch.cuda.current_device())}")
# Out:
# Using NVIDIA GeForce GTX 1660 Ti

# %%
base_model = LeNet().to(device)

# Define the loss function and optimizer
cross_entropy = nn.CrossEntropyLoss()
early_stopper = utility.early_stopping.EarlyStopper(patience=3, min_delta=0)
optimizer = optim.AdamW(base_model.parameters())

# %% [markdown]
# ## Pruning Phase

# %% [markdown]
# ### One shot pruning

# %%
PRUNING_VALUES = [0.20, 0.40, 0.60]
PRUNING_NAME_TO_METHOD = {
    "RandomUnstructured": prune.RandomUnstructured,
    "L1Unstructured": prune.L1Unstructured,
}
ITER_STEPS = [2, 4]
FINETUNE_EPOCHS = [1]

# %%
one_shot_configs = []

for pruning_rate, iter_step, finetune_epochs in itertools.product(
    PRUNING_VALUES, ITER_STEPS, FINETUNE_EPOCHS
):
    one_shot_configs.append(
        PruningMetadata(
            total_pruned=pruning_rate,
            pruning_step=pruning_rate,
            finetune_epochs=(int(pruning_rate * 100) // iter_step) * finetune_epochs,
            total_epochs=(int(pruning_rate * 100) // iter_step) * finetune_epochs,
            method=prune.L1Unstructured,
            early_stopping=False,
        )
    )

# %%
results = []

for config in one_shot_configs:
    pruning_rate = config.pruning_step
    method = config.method
    early_stopping = config.early_stopping
    fine_tune_epochs = config.finetune_epochs

    pruning_value = int(
        round(
            calculate_parameters_amount(get_parameters_to_prune(base_model))
            * pruning_rate
        )
    )

    # load the model
    temp_model = LeNet().to(device)
    temp_model.load_state_dict(
        torch.load(MODELS_PATH / Path("LeNet_cifar10/LeNet_cifar10.pth"))
    )
    model_name = temp_model.__class__.__name__
    model_parameters = get_parameters_to_prune(temp_model)

    optimizer = optim.AdamW(temp_model.parameters())

    # prune the model
    prune.global_unstructured(
        parameters=model_parameters,
        pruning_method=method,
        amount=pruning_value,
    )

    print(
        f"Pruning rate: {pruning_rate}, method: {method.__name__}, fine tune epochs: {fine_tune_epochs}"
    )

    valid_loss, valid_accuracy = utility.training.validate(
        module=temp_model,
        valid_dl=validation_loader,
        loss_function=cross_entropy,
        device=device,
    )

    print(
        f"After pruning:\nValid Loss: {valid_loss:.4f}, Valid Accuracy: {valid_accuracy:.4f}"
    )

    # retrain the model
    print("Retraining the model")
    for epoch in range(fine_tune_epochs):
        train_loss = utility.training.train_epoch(
            module=temp_model,
            train_dl=train_loader,
            optimizer=optimizer,
            loss_function=cross_entropy,
            device=device,
        )

        valid_loss, valid_accuracy = utility.training.validate(
            module=temp_model,
            valid_dl=validation_loader,
            loss_function=cross_entropy,
            device=device,
        )

        print(
            f"Epoch: {epoch:}\nTrain Loss: {train_loss:.4f}, Valid Loss: {valid_loss:.4f}, Valid Accuracy: {valid_accuracy:.4f}"
        )

    for module, name in model_parameters:
        prune.remove(module, name)

    config.method = method.__name__
    utility.save.save_model_with_metadata(
        model=temp_model,
        path=f"{MODELS_PATH}/{model_name}_pruned_{pruning_rate}_{method.__name__}",
        model_name=f"{model_name}_pruned_{pruning_rate}_{method.__name__}",
        metadata=asdict(config),
    )
# Out:
# Pruning rate: 0.2, method: L1Unstructured, fine tune epochs: 10
# After pruning:
# Valid Loss: 0.6920, Valid Accuracy: 0.7610
# Retraining the model
# Epoch: 0
# Train Loss: 0.6923, Valid Loss: 0.7047, Valid Accuracy: 0.7571
# Epoch: 1
# Train Loss: 0.6493, Valid Loss: 0.7548, Valid Accuracy: 0.7405
# Epoch: 2
# Train Loss: 0.6217, Valid Loss: 0.7680, Valid Accuracy: 0.7344
# Epoch: 3
# Train Loss: 0.5941, Valid Loss: 0.7729, Valid Accuracy: 0.7279
# Epoch: 4
# Train Loss: 0.5775, Valid Loss: 0.7889, Valid Accuracy: 0.7307
# Epoch: 5
# Train Loss: 0.5510, Valid Loss: 0.8091, Valid Accuracy: 0.7296
# Epoch: 6
# Train Loss: 0.5372, Valid Loss: 0.8556, Valid Accuracy: 0.7151
# Epoch: 7
# Train Loss: 0.5119, Valid Loss: 0.8750, Valid Accuracy: 0.7034
# Epoch: 8
# Train Loss: 0.4956, Valid Loss: 0.8900, Valid Accuracy: 0.7032
# Epoch: 9
# Train Loss: 0.4698, Valid Loss: 0.9172, Valid Accuracy: 0.7101
# Pruning rate: 0.2, method: L1Unstructured, fine tune epochs: 5
# After pruning:
# Valid Loss: 0.6920, Valid Accuracy: 0.7610
# Retraining the model
# Epoch: 0
# Train Loss: 0.6927, Valid Loss: 0.7218, Valid Accuracy: 0.7477
# Epoch: 1
# Train Loss: 0.6524, Valid Loss: 0.7218, Valid Accuracy: 0.7483
# Epoch: 2
# Train Loss: 0.6272, Valid Loss: 0.7499, Valid Accuracy: 0.7348
# Epoch: 3
# Train Loss: 0.5969, Valid Loss: 0.7801, Valid Accuracy: 0.7326
# Epoch: 4
# Train Loss: 0.5772, Valid Loss: 0.8014, Valid Accuracy: 0.7227
# Pruning rate: 0.4, method: L1Unstructured, fine tune epochs: 20
# After pruning:
# Valid Loss: 0.7524, Valid Accuracy: 0.7391
# Retraining the model
# Epoch: 0
# Train Loss: 0.6890, Valid Loss: 0.6934, Valid Accuracy: 0.7563
# Epoch: 1
# Train Loss: 0.6476, Valid Loss: 0.7228, Valid Accuracy: 0.7459
# Epoch: 2
# Train Loss: 0.6244, Valid Loss: 0.7382, Valid Accuracy: 0.7401
# Epoch: 3
# Train Loss: 0.5997, Valid Loss: 0.7392, Valid Accuracy: 0.7447
# Epoch: 4
# Train Loss: 0.5763, Valid Loss: 0.7933, Valid Accuracy: 0.7260
# Epoch: 5
# Train Loss: 0.5576, Valid Loss: 0.7883, Valid Accuracy: 0.7308
# Epoch: 6
# Train Loss: 0.5361, Valid Loss: 0.8227, Valid Accuracy: 0.7272
# Epoch: 7
# Train Loss: 0.5208, Valid Loss: 0.8177, Valid Accuracy: 0.7253
# Epoch: 8
# Train Loss: 0.5029, Valid Loss: 0.8644, Valid Accuracy: 0.7168
# Epoch: 9
# Train Loss: 0.4900, Valid Loss: 0.8741, Valid Accuracy: 0.7137
# Epoch: 10
# Train Loss: 0.4761, Valid Loss: 0.8998, Valid Accuracy: 0.7087
# Epoch: 11
# Train Loss: 0.4607, Valid Loss: 0.9127, Valid Accuracy: 0.7124
# Epoch: 12
# Train Loss: 0.4433, Valid Loss: 0.9379, Valid Accuracy: 0.7031
# Epoch: 13
# Train Loss: 0.4324, Valid Loss: 0.9437, Valid Accuracy: 0.7075
# Epoch: 14
# Train Loss: 0.4172, Valid Loss: 1.0020, Valid Accuracy: 0.7001
# Epoch: 15
# Train Loss: 0.3990, Valid Loss: 1.0272, Valid Accuracy: 0.7018
# Epoch: 16
# Train Loss: 0.3956, Valid Loss: 1.0239, Valid Accuracy: 0.6999
# Epoch: 17
# Train Loss: 0.3785, Valid Loss: 1.0598, Valid Accuracy: 0.6960
# Epoch: 18
# Train Loss: 0.3654, Valid Loss: 1.0904, Valid Accuracy: 0.6960
# Epoch: 19
# Train Loss: 0.3572, Valid Loss: 1.1187, Valid Accuracy: 0.6935
# Pruning rate: 0.4, method: L1Unstructured, fine tune epochs: 10
# After pruning:
# Valid Loss: 0.7524, Valid Accuracy: 0.7391
# Retraining the model
# Epoch: 0
# Train Loss: 0.6865, Valid Loss: 0.6968, Valid Accuracy: 0.7591
# Epoch: 1
# Train Loss: 0.6420, Valid Loss: 0.7191, Valid Accuracy: 0.7525
# Epoch: 2
# Train Loss: 0.6221, Valid Loss: 0.7308, Valid Accuracy: 0.7495
# Epoch: 3
# Train Loss: 0.5960, Valid Loss: 0.7570, Valid Accuracy: 0.7344
# Epoch: 4
# Train Loss: 0.5741, Valid Loss: 0.7602, Valid Accuracy: 0.7348
# Epoch: 5
# Train Loss: 0.5559, Valid Loss: 0.8382, Valid Accuracy: 0.7110
# Epoch: 6
# Train Loss: 0.5406, Valid Loss: 0.8339, Valid Accuracy: 0.7210
# Epoch: 7
# Train Loss: 0.5214, Valid Loss: 0.8252, Valid Accuracy: 0.7195
# Epoch: 8
# Train Loss: 0.4997, Valid Loss: 0.8596, Valid Accuracy: 0.7171
# Epoch: 9
# Train Loss: 0.4895, Valid Loss: 0.8832, Valid Accuracy: 0.7168
# Pruning rate: 0.6, method: L1Unstructured, fine tune epochs: 30
# After pruning:
# Valid Loss: 1.1725, Valid Accuracy: 0.6002
# Retraining the model
# Epoch: 0
# Train Loss: 0.7237, Valid Loss: 0.7023, Valid Accuracy: 0.7532
# Epoch: 1
# Train Loss: 0.6647, Valid Loss: 0.7314, Valid Accuracy: 0.7453
# Epoch: 2
# Train Loss: 0.6381, Valid Loss: 0.7542, Valid Accuracy: 0.7361
# Epoch: 3
# Train Loss: 0.6197, Valid Loss: 0.7421, Valid Accuracy: 0.7397
# Epoch: 4
# Train Loss: 0.6023, Valid Loss: 0.7547, Valid Accuracy: 0.7371
# Epoch: 5
# Train Loss: 0.5832, Valid Loss: 0.7683, Valid Accuracy: 0.7296
# Epoch: 6
# Train Loss: 0.5710, Valid Loss: 0.7834, Valid Accuracy: 0.7291
# Epoch: 7
# Train Loss: 0.5527, Valid Loss: 0.8097, Valid Accuracy: 0.7257
# Epoch: 8
# Train Loss: 0.5391, Valid Loss: 0.8249, Valid Accuracy: 0.7209
# Epoch: 9
# Train Loss: 0.5257, Valid Loss: 0.8284, Valid Accuracy: 0.7255
# Epoch: 10
# Train Loss: 0.5132, Valid Loss: 0.8351, Valid Accuracy: 0.7183
# Epoch: 11
# Train Loss: 0.5014, Valid Loss: 0.8536, Valid Accuracy: 0.7149
# Epoch: 12
# Train Loss: 0.4892, Valid Loss: 0.8692, Valid Accuracy: 0.7141
# Epoch: 13
# Train Loss: 0.4809, Valid Loss: 0.8881, Valid Accuracy: 0.7098
# Epoch: 14
# Train Loss: 0.4683, Valid Loss: 0.9069, Valid Accuracy: 0.7043
# Epoch: 15
# Train Loss: 0.4593, Valid Loss: 0.9511, Valid Accuracy: 0.7033
# Epoch: 16
# Train Loss: 0.4511, Valid Loss: 0.9567, Valid Accuracy: 0.7041
# Epoch: 17
# Train Loss: 0.4405, Valid Loss: 0.9955, Valid Accuracy: 0.6949
# Epoch: 18
# Train Loss: 0.4304, Valid Loss: 0.9717, Valid Accuracy: 0.7016
# Epoch: 19
# Train Loss: 0.4230, Valid Loss: 1.0045, Valid Accuracy: 0.6954
# Epoch: 20
# Train Loss: 0.4138, Valid Loss: 1.0162, Valid Accuracy: 0.6983
# Epoch: 21
# Train Loss: 0.4074, Valid Loss: 1.0492, Valid Accuracy: 0.6960
# Epoch: 22
# Train Loss: 0.3955, Valid Loss: 1.0647, Valid Accuracy: 0.6941
# Epoch: 23
# Train Loss: 0.3866, Valid Loss: 1.0960, Valid Accuracy: 0.6891
# Epoch: 24
# Train Loss: 0.3808, Valid Loss: 1.1099, Valid Accuracy: 0.6912
# Epoch: 25
# Train Loss: 0.3710, Valid Loss: 1.1462, Valid Accuracy: 0.6896
# Epoch: 26
# Train Loss: 0.3682, Valid Loss: 1.1516, Valid Accuracy: 0.6892
# Epoch: 27
# Train Loss: 0.3563, Valid Loss: 1.1738, Valid Accuracy: 0.6816
# Epoch: 28
# Train Loss: 0.3493, Valid Loss: 1.1889, Valid Accuracy: 0.6872
# Epoch: 29
# Train Loss: 0.3456, Valid Loss: 1.2189, Valid Accuracy: 0.6849
# Pruning rate: 0.6, method: L1Unstructured, fine tune epochs: 15
# After pruning:
# Valid Loss: 1.1725, Valid Accuracy: 0.6002
# Retraining the model
# Epoch: 0
# Train Loss: 0.7238, Valid Loss: 0.7101, Valid Accuracy: 0.7530
# Epoch: 1
# Train Loss: 0.6660, Valid Loss: 0.7260, Valid Accuracy: 0.7459
# Epoch: 2
# Train Loss: 0.6373, Valid Loss: 0.7250, Valid Accuracy: 0.7489
# Epoch: 3
# Train Loss: 0.6169, Valid Loss: 0.7460, Valid Accuracy: 0.7365
# Epoch: 4
# Train Loss: 0.6003, Valid Loss: 0.7625, Valid Accuracy: 0.7371
# Epoch: 5
# Train Loss: 0.5811, Valid Loss: 0.7655, Valid Accuracy: 0.7306
# Epoch: 6
# Train Loss: 0.5680, Valid Loss: 0.7873, Valid Accuracy: 0.7276
# Epoch: 7
# Train Loss: 0.5516, Valid Loss: 0.8014, Valid Accuracy: 0.7258
# Epoch: 8
# Train Loss: 0.5388, Valid Loss: 0.8158, Valid Accuracy: 0.7197
# Epoch: 9
# Train Loss: 0.5257, Valid Loss: 0.8285, Valid Accuracy: 0.7182
# Epoch: 10
# Train Loss: 0.5144, Valid Loss: 0.8602, Valid Accuracy: 0.7105
# Epoch: 11
# Train Loss: 0.5038, Valid Loss: 0.8590, Valid Accuracy: 0.7159
# Epoch: 12
# Train Loss: 0.4909, Valid Loss: 0.8893, Valid Accuracy: 0.7071
# Epoch: 13
# Train Loss: 0.4816, Valid Loss: 0.9010, Valid Accuracy: 0.7109
# Epoch: 14
# Train Loss: 0.4672, Valid Loss: 0.9223, Valid Accuracy: 0.7037
