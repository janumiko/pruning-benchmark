# %%
import torch
import torch.nn as nn

from torch.utils.data import DataLoader, random_split
from torchvision import datasets, transforms
from typing import Iterable
from pathlib import Path
from constants import DATA_PATH, MODELS_PATH
from LeNet import LeNet, BATCH_SIZE
import utility
import json

# %%
# load FashionMNIST data
transform = transforms.Compose([transforms.ToTensor()])

# split into validation and train datasets
train_ds = datasets.FashionMNIST(
    DATA_PATH, train=True, transform=transform, download=True
)
train_ds, valid_ds = random_split(train_ds, [0.8, 0.2])

test_ds = datasets.FashionMNIST(
    DATA_PATH, train=False, transform=transform, download=True
)

# %%
# Get cpu, gpu or mps device for training.
device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")
print(f"Using {torch.cuda.get_device_name(torch.cuda.current_device())}")
# Out:
# Using NVIDIA GeForce GTX 1660 Ti

# %%
base_model = LeNet().to(device)

# Define the loss function
cross_entropy = nn.CrossEntropyLoss()

# create the data loaders
train_loader = DataLoader(train_ds, batch_size=BATCH_SIZE, shuffle=True)
validation_loader = DataLoader(valid_ds, batch_size=BATCH_SIZE)
test_loader = DataLoader(test_ds, batch_size=BATCH_SIZE)

# %%
def get_parameters_to_prune(model: nn.Module) -> list[nn.Parameter]:
    return [
        (module, "weight")
        for module in model.modules()
        if isinstance(module, nn.Conv2d | nn.Linear)
    ]


def calculate_total_sparsity(
    module: nn.Module, parameters_to_prune: Iterable[tuple[nn.Module, str]]
) -> float:
    total_weights = 0
    total_zero_weights = 0

    pruned_parameters: set[tuple[nn.Module, str]] = set(parameters_to_prune)

    for _, module in module.named_children():
        for param_name, param in module.named_parameters():
            if (module, param_name) not in pruned_parameters:
                continue

            if "weight" in param_name:
                total_weights += float(param.nelement())
                total_zero_weights += float(torch.sum(param == 0))

    sparsity = 100.0 * total_zero_weights / total_weights
    return sparsity

# %% [markdown]
# ### Load models

# %%
models = []

for file in Path(MODELS_PATH).iterdir():
    if not file.is_dir():
        continue

    for inner_file in file.iterdir():
        if not inner_file.is_file():
            continue
        match inner_file.suffix:
            case ".pth":
                model = LeNet().to(device)
                model.load_state_dict(torch.load(inner_file))
            case ".json":
                metadata = json.load(inner_file.open())
    models.append((model, metadata, file.stem))

# %% [markdown]
# ### Test the models

# %%
results = []
for model, meta, _ in models:
    test_loss, accuracy = utility.training.test(
        model=model, test_dl=test_loader, loss_function=cross_entropy, device=device
    )
    results.append((*meta.values(), accuracy))

# %%
import pandas as pd

columns = [*models[0][1].keys(), "accuracy"]
result_df = (
    pd.DataFrame.from_records(results, columns=columns)
    .sort_values(by="accuracy", ascending=False)
    .reset_index(drop=True)
)
result_df
# Out:
#     total_pruned  pruning_step  finetune_epochs          method  \
# 0           0.60          0.60                4  L1Unstructured
# 1           0.20          0.20                4  L1Unstructured
# 2           0.88          0.88                8  L1Unstructured
# 3           0.80          0.80                6  L1Unstructured
# 4           0.40          0.40                9  L1Unstructured
# ..           ...           ...              ...             ...
# 87          0.96          0.01                4  L1Unstructured
# 88          0.96          0.04                4  L1Unstructured
# 89          0.96          0.04                2  L1Unstructured
# 90          0.96          0.04                1  L1Unstructured
# 91          0.96          0.04                3  L1Unstructured
#
#     early_stopping  accuracy
# 0             True     90.63
# 1             True     90.27
# 2             True     89.99
# 3             True     89.94
# 4             True     89.25
# ..             ...       ...
# 87           False     42.19
# 88           False     41.36
# 89           False     41.36
# 90           False     41.36
# 91           False     41.36
#
# [92 rows x 6 columns]

# %% [markdown]
# ### Print models sparsity.

# %%
for model, _, name in models:
    print(f"Calculating sparsity for {name}")
    print(
        f"Total sparsity: {100 - calculate_total_sparsity(model, get_parameters_to_prune(model)):.2f}%"
    )
    print("-" * 20)
# Out:
# Calculating sparsity for LeNet_iterative_pruned_0.92_step_0
# Total sparsity: 7.96%
# --------------------
# Calculating sparsity for LeNet_pruned_0
# Total sparsity: 60.00%
# --------------------
# Calculating sparsity for LeNet_iterative_pruned_0.96_step_0
# Total sparsity: 3.95%
# --------------------
# Calculating sparsity for LeNet_iterative_pruned_0.88_step_0
# Total sparsity: 11.96%
# --------------------
# Calculating sparsity for LeNet_iterative_pruned_0.8_step_0
# Total sparsity: 20.03%
# --------------------
# Calculating sparsity for LeNet_pruned_0
# Total sparsity: 12.00%
# --------------------
# Calculating sparsity for LeNet_iterative_pruned_0.96_step_0
# Total sparsity: 3.95%
# --------------------
# Calculating sparsity for LeNet_iterative_pruned_0.96_step_0
# Total sparsity: 4.03%
# --------------------
# Calculating sparsity for LeNet_iterative_pruned_0.8_step_0
# Total sparsity: 19.96%
# --------------------
# Calculating sparsity for LeNet_iterative_pruned_0.88_step_0
# Total sparsity: 11.99%
# --------------------
# Calculating sparsity for LeNet_iterative_pruned_0.96_step_0
# Total sparsity: 3.99%
# --------------------
# Calculating sparsity for LeNet_iterative_pruned_0.8_step_0
# Total sparsity: 20.03%
# --------------------
# Calculating sparsity for LeNet_iterative_pruned_0.4_step_0
# Total sparsity: 59.98%
# --------------------
# Calculating sparsity for LeNet_iterative_pruned_0.6_step_0
# Total sparsity: 40.02%
# --------------------
# Calculating sparsity for LeNet_pruned_0
# Total sparsity: 4.00%
# --------------------
# Calculating sparsity for LeNet_iterative_pruned_0.88_step_0
# Total sparsity: 12.03%
# --------------------
# Calculating sparsity for LeNet_fmnist
# Total sparsity: 100.00%
# --------------------
# Calculating sparsity for LeNet_iterative_pruned_0.96_step_0
# Total sparsity: 4.03%
# --------------------
# Calculating sparsity for LeNet_iterative_pruned_0.88_step_0
# Total sparsity: 11.96%
# --------------------
# Calculating sparsity for LeNet_iterative_pruned_0.92_step_0
# Total sparsity: 8.03%
# --------------------
# Calculating sparsity for LeNet_iterative_pruned_0.8_step_0
# Total sparsity: 19.96%
# --------------------
# Calculating sparsity for LeNet_iterative_pruned_0.88_step_0
# Total sparsity: 11.99%
# --------------------
# Calculating sparsity for LeNet_iterative_pruned_0.2_step_0
# Total sparsity: 79.99%
# --------------------
# Calculating sparsity for LeNet_iterative_pruned_0.8_step_0
# Total sparsity: 20.03%
# --------------------
# Calculating sparsity for LeNet_iterative_pruned_0.88_step_0
# Total sparsity: 12.03%
# --------------------
# Calculating sparsity for LeNet_iterative_pruned_0.4_step_0
# Total sparsity: 60.01%
# --------------------
# Calculating sparsity for LeNet_iterative_pruned_0.6_step_0
# Total sparsity: 39.97%
# --------------------
# Calculating sparsity for LeNet_iterative_pruned_0.92_step_0
# Total sparsity: 7.99%
# --------------------
# Calculating sparsity for LeNet_iterative_pruned_0.96_step_0
# Total sparsity: 3.99%
# --------------------
# Calculating sparsity for LeNet_iterative_pruned_0.92_step_0
# Total sparsity: 8.03%
# --------------------
# Calculating sparsity for LeNet_iterative_pruned_0.6_step_0
# Total sparsity: 40.02%
# --------------------
# Calculating sparsity for LeNet_iterative_pruned_0.92_step_0
# Total sparsity: 8.03%
# --------------------
# Calculating sparsity for LeNet_iterative_pruned_0.88_step_0
# Total sparsity: 11.99%
# --------------------
# Calculating sparsity for LeNet_iterative_pruned_0.92_step_0
# Total sparsity: 8.03%
# --------------------
# Calculating sparsity for LeNet_iterative_pruned_0.4_step_0
# Total sparsity: 60.01%
# --------------------
# Calculating sparsity for LeNet_iterative_pruned_0.92_step_0
# Total sparsity: 7.99%
# --------------------
# Calculating sparsity for LeNet_iterative_pruned_0.2_step_0
# Total sparsity: 80.00%
# --------------------
# Calculating sparsity for LeNet_iterative_pruned_0.96_step_0
# Total sparsity: 3.99%
# --------------------
# Calculating sparsity for LeNet_iterative_pruned_0.4_step_0
# Total sparsity: 59.98%
# --------------------
# Calculating sparsity for LeNet_iterative_pruned_0.6_step_0
# Total sparsity: 39.97%
# --------------------
# Calculating sparsity for LeNet_iterative_pruned_0.4_step_0
# Total sparsity: 59.98%
# --------------------
# Calculating sparsity for LeNet_iterative_pruned_0.8_step_0
# Total sparsity: 19.99%
# --------------------
# Calculating sparsity for LeNet_iterative_pruned_0.88_step_0
# Total sparsity: 11.96%
# --------------------
# Calculating sparsity for LeNet_iterative_pruned_0.4_step_0
# Total sparsity: 60.00%
# --------------------
# Calculating sparsity for LeNet_pruned_0
# Total sparsity: 20.00%
# --------------------
# Calculating sparsity for LeNet_iterative_pruned_0.4_step_0
# Total sparsity: 60.01%
# --------------------
# Calculating sparsity for LeNet_pruned_0
# Total sparsity: 40.00%
# --------------------
# Calculating sparsity for LeNet_iterative_pruned_0.96_step_0
# Total sparsity: 4.03%
# --------------------
# Calculating sparsity for LeNet_iterative_pruned_0.2_step_0
# Total sparsity: 79.99%
# --------------------
# Calculating sparsity for LeNet_iterative_pruned_0.2_step_0
# Total sparsity: 80.00%
# --------------------
# Calculating sparsity for LeNet_iterative_pruned_0.6_step_0
# Total sparsity: 39.97%
# --------------------
# Calculating sparsity for LeNet_iterative_pruned_0.8_step_0
# Total sparsity: 19.96%
# --------------------
# Calculating sparsity for LeNet_pruned_0
# Total sparsity: 8.00%
# --------------------
# Calculating sparsity for LeNet_iterative_pruned_0.2_step_0
# Total sparsity: 80.01%
# --------------------
# Calculating sparsity for LeNet_iterative_pruned_0.8_step_0
# Total sparsity: 19.99%
# --------------------
# Calculating sparsity for LeNet_iterative_pruned_0.6_step_0
# Total sparsity: 40.00%
# --------------------
# Calculating sparsity for LeNet_iterative_pruned_0.4_step_0
# Total sparsity: 60.00%
# --------------------
# Calculating sparsity for LeNet_iterative_pruned_0.6_step_0
# Total sparsity: 40.00%
# --------------------
# Calculating sparsity for LeNet_iterative_pruned_0.6_step_0
# Total sparsity: 40.02%
# --------------------
# Calculating sparsity for LeNet_iterative_pruned_0.2_step_0
# Total sparsity: 80.01%
# --------------------
# Calculating sparsity for LeNet_iterative_pruned_0.88_step_0
# Total sparsity: 11.96%
# --------------------
# Calculating sparsity for LeNet_iterative_pruned_0.92_step_0
# Total sparsity: 7.99%
# --------------------
# Calculating sparsity for LeNet_iterative_pruned_0.4_step_0
# Total sparsity: 60.00%
# --------------------
# Calculating sparsity for LeNet_iterative_pruned_0.6_step_0
# Total sparsity: 39.97%
# --------------------
# Calculating sparsity for LeNet_iterative_pruned_0.4_step_0
# Total sparsity: 59.98%
# --------------------
# Calculating sparsity for LeNet_iterative_pruned_0.2_step_0
# Total sparsity: 80.00%
# --------------------
# Calculating sparsity for LeNet_iterative_pruned_0.6_step_0
# Total sparsity: 40.00%
# --------------------
# Calculating sparsity for LeNet_iterative_pruned_0.6_step_0
# Total sparsity: 40.00%
# --------------------
# Calculating sparsity for LeNet_iterative_pruned_0.2_step_0
# Total sparsity: 80.01%
# --------------------
# Calculating sparsity for LeNet_iterative_pruned_0.4_step_0
# Total sparsity: 60.00%
# --------------------
# Calculating sparsity for LeNet_iterative_pruned_0.88_step_0
# Total sparsity: 12.03%
# --------------------
# Calculating sparsity for LeNet_iterative_pruned_0.96_step_0
# Total sparsity: 3.95%
# --------------------
# Calculating sparsity for LeNet_iterative_pruned_0.2_step_0
# Total sparsity: 80.00%
# --------------------
# Calculating sparsity for LeNet_iterative_pruned_0.8_step_0
# Total sparsity: 19.99%
# --------------------
# Calculating sparsity for LeNet_iterative_pruned_0.6_step_0
# Total sparsity: 40.02%
# --------------------
# Calculating sparsity for LeNet_iterative_pruned_0.8_step_0
# Total sparsity: 19.96%
# --------------------
# Calculating sparsity for LeNet_iterative_pruned_0.2_step_0
# Total sparsity: 80.01%
# --------------------
# Calculating sparsity for LeNet_iterative_pruned_0.8_step_0
# Total sparsity: 19.99%
# --------------------
# Calculating sparsity for LeNet_iterative_pruned_0.88_step_0
# Total sparsity: 12.03%
# --------------------
# Calculating sparsity for LeNet_iterative_pruned_0.96_step_0
# Total sparsity: 3.95%
# --------------------
# Calculating sparsity for LeNet_iterative_pruned_0.2_step_0
# Total sparsity: 79.99%
# --------------------
# Calculating sparsity for LeNet_pruned_0
# Total sparsity: 80.00%
# --------------------
# Calculating sparsity for LeNet_iterative_pruned_0.92_step_0
# Total sparsity: 7.96%
# --------------------
# Calculating sparsity for LeNet_iterative_pruned_0.92_step_0
# Total sparsity: 7.99%
# --------------------
# Calculating sparsity for LeNet_iterative_pruned_0.4_step_0
# Total sparsity: 60.01%
# --------------------
# Calculating sparsity for LeNet_iterative_pruned_0.92_step_0
# Total sparsity: 7.96%
# --------------------
# Calculating sparsity for LeNet_iterative_pruned_0.8_step_0
# Total sparsity: 20.03%
# --------------------
# Calculating sparsity for LeNet_iterative_pruned_0.2_step_0
# Total sparsity: 79.99%
# --------------------
# Calculating sparsity for LeNet_iterative_pruned_0.92_step_0
# Total sparsity: 7.96%
# --------------------
# Calculating sparsity for LeNet_iterative_pruned_0.88_step_0
# Total sparsity: 11.99%
# --------------------
# Calculating sparsity for LeNet_iterative_pruned_0.96_step_0
# Total sparsity: 3.99%
# --------------------
# Calculating sparsity for LeNet_iterative_pruned_0.96_step_0
# Total sparsity: 4.03%
# --------------------

# %% [markdown]
# ### Visualize tables with the results

# %%
base_result = result_df[result_df["total_pruned"] == 0.0]
base_result
# Out:
#     total_pruned  pruning_step  finetune_epochs method  early_stopping  \
# 17           0.0           0.0               12   None            True
#
#     accuracy
# 17     89.04

# %%
one_shot_results = result_df[
    (result_df["total_pruned"] == result_df["pruning_step"])
    & (result_df["total_pruned"] != 0.0)
]
one_shot_results
# Out:
#     total_pruned  pruning_step  finetune_epochs          method  \
# 0           0.60          0.60                4  L1Unstructured
# 1           0.20          0.20                4  L1Unstructured
# 2           0.88          0.88                8  L1Unstructured
# 3           0.80          0.80                6  L1Unstructured
# 4           0.40          0.40                9  L1Unstructured
# 30          0.92          0.92               12  L1Unstructured
# 43          0.96          0.96               10  L1Unstructured
#
#     early_stopping  accuracy
# 0             True     90.63
# 1             True     90.27
# 2             True     89.99
# 3             True     89.94
# 4             True     89.25
# 30            True     88.91
# 43            True     88.61

# %%
iterative_results = result_df[result_df["total_pruned"] != result_df["pruning_step"]]
iterative_results
# Out:
#     total_pruned  pruning_step  finetune_epochs          method  \
# 5           0.40          0.04                2  L1Unstructured
# 6           0.40          0.04                1  L1Unstructured
# 7           0.40          0.04                4  L1Unstructured
# 8           0.40          0.04                3  L1Unstructured
# 9           0.40          0.02                3  L1Unstructured
# ..           ...           ...              ...             ...
# 87          0.96          0.01                4  L1Unstructured
# 88          0.96          0.04                4  L1Unstructured
# 89          0.96          0.04                2  L1Unstructured
# 90          0.96          0.04                1  L1Unstructured
# 91          0.96          0.04                3  L1Unstructured
#
#     early_stopping  accuracy
# 5            False     89.15
# 6            False     89.15
# 7            False     89.15
# 8            False     89.15
# 9            False     89.14
# ..             ...       ...
# 87           False     42.19
# 88           False     41.36
# 89           False     41.36
# 90           False     41.36
# 91           False     41.36
#
# [84 rows x 6 columns]

# %%
pruned_20 = result_df[result_df["total_pruned"] == 0.20].sort_values(
    by=["pruning_step", "finetune_epochs"], ascending=False
)
pruned_40 = result_df[result_df["total_pruned"] == 0.40].sort_values(
    by=["pruning_step", "finetune_epochs"], ascending=False
)
pruned_60 = result_df[result_df["total_pruned"] == 0.60].sort_values(
    by=["pruning_step", "finetune_epochs"], ascending=False
)
pruned_80 = result_df[result_df["total_pruned"] == 0.80].sort_values(
    by=["pruning_step", "finetune_epochs"], ascending=False
)
pruned_92 = result_df[result_df["total_pruned"] == 0.92].sort_values(
    by=["pruning_step", "finetune_epochs"], ascending=False
)
pruned_96 = result_df[result_df["total_pruned"] == 0.96].sort_values(
    by=["pruning_step", "finetune_epochs"], ascending=False
)

# %%
pruned_20
# Out:
#     total_pruned  pruning_step  finetune_epochs          method  \
# 1            0.2          0.20                4  L1Unstructured
# 20           0.2          0.04                4  L1Unstructured
# 21           0.2          0.04                3  L1Unstructured
# 18           0.2          0.04                2  L1Unstructured
# 22           0.2          0.04                1  L1Unstructured
# 19           0.2          0.02                4  L1Unstructured
# 25           0.2          0.02                3  L1Unstructured
# 23           0.2          0.02                2  L1Unstructured
# 24           0.2          0.02                1  L1Unstructured
# 27           0.2          0.01                4  L1Unstructured
# 28           0.2          0.01                3  L1Unstructured
# 26           0.2          0.01                2  L1Unstructured
# 29           0.2          0.01                1  L1Unstructured
#
#     early_stopping  accuracy
# 1             True     90.27
# 20           False     88.97
# 21           False     88.97
# 18           False     88.97
# 22           False     88.97
# 19           False     88.97
# 25           False     88.97
# 23           False     88.97
# 24           False     88.97
# 27           False     88.96
# 28           False     88.96
# 26           False     88.96
# 29           False     88.96

# %%
pruned_40
# Out:
#     total_pruned  pruning_step  finetune_epochs          method  \
# 4            0.4          0.40                9  L1Unstructured
# 7            0.4          0.04                4  L1Unstructured
# 8            0.4          0.04                3  L1Unstructured
# 5            0.4          0.04                2  L1Unstructured
# 6            0.4          0.04                1  L1Unstructured
# 12           0.4          0.02                4  L1Unstructured
# 9            0.4          0.02                3  L1Unstructured
# 11           0.4          0.02                2  L1Unstructured
# 10           0.4          0.02                1  L1Unstructured
# 13           0.4          0.01                4  L1Unstructured
# 16           0.4          0.01                3  L1Unstructured
# 14           0.4          0.01                2  L1Unstructured
# 15           0.4          0.01                1  L1Unstructured
#
#     early_stopping  accuracy
# 4             True     89.25
# 7            False     89.15
# 8            False     89.15
# 5            False     89.15
# 6            False     89.15
# 12           False     89.14
# 9            False     89.14
# 11           False     89.14
# 10           False     89.14
# 13           False     89.13
# 16           False     89.13
# 14           False     89.13
# 15           False     89.13

# %%
pruned_60
# Out:
#     total_pruned  pruning_step  finetune_epochs          method  \
# 0            0.6          0.60                4  L1Unstructured
# 33           0.6          0.04                4  L1Unstructured
# 32           0.6          0.04                3  L1Unstructured
# 31           0.6          0.04                2  L1Unstructured
# 34           0.6          0.04                1  L1Unstructured
# 36           0.6          0.02                4  L1Unstructured
# 38           0.6          0.02                3  L1Unstructured
# 37           0.6          0.02                2  L1Unstructured
# 35           0.6          0.02                1  L1Unstructured
# 40           0.6          0.01                4  L1Unstructured
# 39           0.6          0.01                3  L1Unstructured
# 42           0.6          0.01                2  L1Unstructured
# 41           0.6          0.01                1  L1Unstructured
#
#     early_stopping  accuracy
# 0             True     90.63
# 33           False     88.68
# 32           False     88.68
# 31           False     88.68
# 34           False     88.68
# 36           False     88.66
# 38           False     88.66
# 37           False     88.66
# 35           False     88.66
# 40           False     88.65
# 39           False     88.65
# 42           False     88.65
# 41           False     88.65

# %%
pruned_80
# Out:
#     total_pruned  pruning_step  finetune_epochs          method  \
# 3            0.8          0.80                6  L1Unstructured
# 50           0.8          0.04                4  L1Unstructured
# 51           0.8          0.04                3  L1Unstructured
# 48           0.8          0.04                2  L1Unstructured
# 49           0.8          0.04                1  L1Unstructured
# 47           0.8          0.02                4  L1Unstructured
# 45           0.8          0.02                3  L1Unstructured
# 44           0.8          0.02                2  L1Unstructured
# 46           0.8          0.02                1  L1Unstructured
# 53           0.8          0.01                4  L1Unstructured
# 54           0.8          0.01                3  L1Unstructured
# 55           0.8          0.01                2  L1Unstructured
# 52           0.8          0.01                1  L1Unstructured
#
#     early_stopping  accuracy
# 3             True     89.94
# 50           False     87.78
# 51           False     87.78
# 48           False     87.78
# 49           False     87.78
# 47           False     87.83
# 45           False     87.83
# 44           False     87.83
# 46           False     87.83
# 53           False     87.75
# 54           False     87.75
# 55           False     87.75
# 52           False     87.75

# %%
pruned_92
# Out:
#     total_pruned  pruning_step  finetune_epochs          method  \
# 30          0.92          0.92               12  L1Unstructured
# 79          0.92          0.04                4  L1Unstructured
# 76          0.92          0.04                3  L1Unstructured
# 77          0.92          0.04                2  L1Unstructured
# 78          0.92          0.04                1  L1Unstructured
# 74          0.92          0.02                4  L1Unstructured
# 75          0.92          0.02                3  L1Unstructured
# 73          0.92          0.02                2  L1Unstructured
# 72          0.92          0.02                1  L1Unstructured
# 69          0.92          0.01                4  L1Unstructured
# 71          0.92          0.01                3  L1Unstructured
# 68          0.92          0.01                2  L1Unstructured
# 70          0.92          0.01                1  L1Unstructured
#
#     early_stopping  accuracy
# 30            True     88.91
# 79           False     70.08
# 76           False     70.08
# 77           False     70.08
# 78           False     70.08
# 74           False     70.12
# 75           False     70.12
# 73           False     70.12
# 72           False     70.12
# 69           False     70.80
# 71           False     70.80
# 68           False     70.80
# 70           False     70.80

# %%
pruned_96
# Out:
#     total_pruned  pruning_step  finetune_epochs          method  \
# 43          0.96          0.96               10  L1Unstructured
# 88          0.96          0.04                4  L1Unstructured
# 91          0.96          0.04                3  L1Unstructured
# 89          0.96          0.04                2  L1Unstructured
# 90          0.96          0.04                1  L1Unstructured
# 82          0.96          0.02                4  L1Unstructured
# 80          0.96          0.02                3  L1Unstructured
# 83          0.96          0.02                2  L1Unstructured
# 81          0.96          0.02                1  L1Unstructured
# 87          0.96          0.01                4  L1Unstructured
# 84          0.96          0.01                3  L1Unstructured
# 86          0.96          0.01                2  L1Unstructured
# 85          0.96          0.01                1  L1Unstructured
#
#     early_stopping  accuracy
# 43            True     88.61
# 88           False     41.36
# 91           False     41.36
# 89           False     41.36
# 90           False     41.36
# 82           False     44.17
# 80           False     44.17
# 83           False     44.17
# 81           False     44.17
# 87           False     42.19
# 84           False     42.19
# 86           False     42.19
# 85           False     42.19
