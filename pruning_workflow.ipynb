# %%
import torch.nn.utils.prune as prune

import torch

import torch.nn as nn
import torch.optim as optim

from torch.utils.data import DataLoader, random_split
from torchvision import datasets, transforms
from typing import Iterable
from pathlib import Path
from constants import DATA_PATH, MODELS_PATH
from LeNet import LeNet, BATCH_SIZE, LEARNING_RATE, EPOCHS, MOMENTUM
from pruning_metadata import PruningMetadata

from dataclasses import asdict

import utility
import itertools
import copy

# %% [markdown]
# ### Load the data

# %%
# load FashionMNIST data
transform = transforms.Compose([transforms.ToTensor()])

# split into validation and train datasets
train_ds = datasets.FashionMNIST(
    DATA_PATH, train=True, transform=transform, download=True
)
train_ds, valid_ds = random_split(train_ds, [0.8, 0.2])

test_ds = datasets.FashionMNIST(
    DATA_PATH, train=False, transform=transform, download=True
)

# %%
# Get cpu, gpu or mps device for training.
device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")
print(f"Using {torch.cuda.get_device_name(torch.cuda.current_device())}")
# Out:
# Using NVIDIA GeForce GTX 1660 Ti

# %%
base_model = LeNet().to(device)

# Define the loss function and optimizer
cross_entropy = nn.CrossEntropyLoss()
early_stopper = utility.early_stopping.EarlyStopper(patience=3, min_delta=0)
optimizer = optim.SGD(base_model.parameters(), lr=LEARNING_RATE, momentum=MOMENTUM)

# create the data loaders
train_loader = DataLoader(train_ds, batch_size=BATCH_SIZE, shuffle=True)
validation_loader = DataLoader(valid_ds, batch_size=BATCH_SIZE)
test_loader = DataLoader(test_ds, batch_size=BATCH_SIZE)

# %% [markdown]
# ## Pruning Phase

# %%
def get_parameters_to_prune(model: nn.Module) -> list[nn.Parameter]:
    return [
        (module, "weight")
        for module in model.modules()
        if isinstance(module, nn.Conv2d | nn.Linear)
    ]


def calculate_total_sparsity(
    module: nn.Module, parameters_to_prune: Iterable[tuple[nn.Module, str]]
) -> float:
    total_weights = 0
    total_zero_weights = 0

    pruned_parameters: set[tuple[nn.Module, str]] = set(parameters_to_prune)

    for _, module in module.named_children():
        for param_name, param in module.named_parameters():
            if (module, param_name) not in pruned_parameters:
                continue

            if "weight" in param_name:
                total_weights += float(param.nelement())
                total_zero_weights += float(torch.sum(param == 0))

    sparsity = 100.0 * total_zero_weights / total_weights
    return sparsity

# %%
def calculate_parameters_amount(modules: Iterable[tuple[nn.Module, str]]) -> int:
    """Calculate the total amount of parameters in a list of modules.

    Args:
        modules (Iterable[tuple[nn.Module, str]]): List of modules and the parameter names.

    Returns:
        int: The total amount of parameters.
    """

    total_parameters = 0
    for module, parameter in modules:
        for param_name, param in module.named_parameters():
            if param_name == parameter:
                total_parameters += param.nelement()

    return total_parameters

# %% [markdown]
# ### One shot pruning

# %%
PRUNING_VALUES = [0.2, 0.4, 0.6, 0.8, 0.88, 0.92, 0.96]
PRUNING_NAME_TO_METHOD = {
    "RandomUnstructured": prune.RandomUnstructured,
    "L1Unstructured": prune.L1Unstructured,
}

# %%
one_shot_configs = []

for pruning_rate in PRUNING_VALUES:
    one_shot_configs.append(
        PruningMetadata(
            total_pruned=pruning_rate,
            pruning_step=pruning_rate,
            finetune_epochs=None,  # to be filled in later
            method=prune.L1Unstructured,
            early_stopping=True,
        )
    )

# %%
results = []

for config in one_shot_configs:
    pruning_rate = config.pruning_step
    method = config.method
    early_stopping = config.early_stopping
    fine_tune_epochs = config.finetune_epochs

    pruning_value = int(
        round(
            calculate_parameters_amount(get_parameters_to_prune(base_model))
            * pruning_rate
        )
    )

    # load the model
    temp_model = LeNet().to(device)
    temp_model.load_state_dict(
        torch.load(MODELS_PATH / Path("LeNet_fmnist/LeNet_fmnist.pth"))
    )
    model_name = temp_model.__class__.__name__
    model_parameters = get_parameters_to_prune(temp_model)

    optimizer = optim.SGD(temp_model.parameters(), lr=LEARNING_RATE, momentum=MOMENTUM)
    early_stopper = utility.early_stopping.EarlyStopper(patience=3, min_delta=0)

    # prune the model
    prune.global_unstructured(
        parameters=model_parameters,
        pruning_method=method,
        amount=pruning_value,
    )

    print(f"Pruning rate: {pruning_rate}, method: {method.__name__}")

    valid_loss, valid_accuracy = utility.training.validate(
        module=temp_model,
        valid_dl=validation_loader,
        loss_function=cross_entropy,
        device=device,
    )

    print(
        f"After pruning:\nValid Loss: {valid_loss:.4f}, Valid Accuracy: {valid_accuracy:.4f}"
    )

    # retrain the model
    print("Retraining the model")
    for epoch in range(EPOCHS):
        train_loss = utility.training.train_epoch(
            module=temp_model,
            train_dl=train_loader,
            optimizer=optimizer,
            loss_function=cross_entropy,
            device=device,
        )

        valid_loss, valid_accuracy = utility.training.validate(
            module=temp_model,
            valid_dl=validation_loader,
            loss_function=cross_entropy,
            device=device,
        )

        print(
            f"Epoch: {epoch:}\nTrain Loss: {train_loss:.4f}, Valid Loss: {valid_loss:.4f}, Valid Accuracy: {valid_accuracy:.4f}"
        )

        if early_stopping and early_stopper.early_stop(valid_loss):
            last_epoch = epoch
            print("Early stopping")
            break

    for module, name in model_parameters:
        prune.remove(module, name)

    config.finetune_epochs = last_epoch + 1
    config.method = method.__name__
    utility.save.save_model_with_metadata(
        model=temp_model,
        path=f"{MODELS_PATH}/{model_name}_pruned_{pruning_rate}_{method.__name__}",
        model_name=f"{model_name}_pruned_{pruning_rate}_{method.__name__}",
        metadata=asdict(config),
    )
# Out:
# Pruning rate: 0.2, method: L1Unstructured
# After pruning:
# Valid Loss: 0.2376, Valid Accuracy: 0.9088
# Retraining the model
# Epoch: 0
# Train Loss: 0.2286, Valid Loss: 0.2254, Valid Accuracy: 0.9148
# Epoch: 1
# Train Loss: 0.2167, Valid Loss: 0.2390, Valid Accuracy: 0.9118
# Epoch: 2
# Train Loss: 0.2098, Valid Loss: 0.2336, Valid Accuracy: 0.9118
# Epoch: 3
# Train Loss: 0.2016, Valid Loss: 0.2337, Valid Accuracy: 0.9145
# Early stopping
# Pruning rate: 0.4, method: L1Unstructured
# After pruning:
# Valid Loss: 0.2384, Valid Accuracy: 0.9078
# Retraining the model
# Epoch: 0
# Train Loss: 0.2241, Valid Loss: 0.2423, Valid Accuracy: 0.9085
# Epoch: 1
# Train Loss: 0.2128, Valid Loss: 0.2403, Valid Accuracy: 0.9087
# Epoch: 2
# Train Loss: 0.2040, Valid Loss: 0.2318, Valid Accuracy: 0.9133
# Epoch: 3
# Train Loss: 0.2002, Valid Loss: 0.2331, Valid Accuracy: 0.9128
# Epoch: 4
# Train Loss: 0.1945, Valid Loss: 0.2409, Valid Accuracy: 0.9099
# Epoch: 5
# Train Loss: 0.1868, Valid Loss: 0.2295, Valid Accuracy: 0.9151
# Epoch: 6
# Train Loss: 0.1822, Valid Loss: 0.2550, Valid Accuracy: 0.9101
# Epoch: 7
# Train Loss: 0.1775, Valid Loss: 0.2479, Valid Accuracy: 0.9098
# Epoch: 8
# Train Loss: 0.1714, Valid Loss: 0.2656, Valid Accuracy: 0.9064
# Early stopping
# Pruning rate: 0.6, method: L1Unstructured
# After pruning:
# Valid Loss: 0.2497, Valid Accuracy: 0.9049
# Retraining the model
# Epoch: 0
# Train Loss: 0.2240, Valid Loss: 0.2166, Valid Accuracy: 0.9218
# Epoch: 1
# Train Loss: 0.2151, Valid Loss: 0.2268, Valid Accuracy: 0.9157
# Epoch: 2
# Train Loss: 0.2075, Valid Loss: 0.2418, Valid Accuracy: 0.9113
# Epoch: 3
# Train Loss: 0.1994, Valid Loss: 0.2222, Valid Accuracy: 0.9177
# Early stopping
# Pruning rate: 0.8, method: L1Unstructured
# After pruning:
# Valid Loss: 0.2881, Valid Accuracy: 0.8952
# Retraining the model
# Epoch: 0
# Train Loss: 0.2342, Valid Loss: 0.2325, Valid Accuracy: 0.9144
# Epoch: 1
# Train Loss: 0.2198, Valid Loss: 0.2367, Valid Accuracy: 0.9115
# Epoch: 2
# Train Loss: 0.2139, Valid Loss: 0.2277, Valid Accuracy: 0.9126
# Epoch: 3
# Train Loss: 0.2080, Valid Loss: 0.2302, Valid Accuracy: 0.9150
# Epoch: 4
# Train Loss: 0.2046, Valid Loss: 0.2471, Valid Accuracy: 0.9064
# Epoch: 5
# Train Loss: 0.2012, Valid Loss: 0.2467, Valid Accuracy: 0.9092
# Early stopping
# Pruning rate: 0.88, method: L1Unstructured
# After pruning:
# Valid Loss: 0.4357, Valid Accuracy: 0.8425
# Retraining the model
# Epoch: 0
# Train Loss: 0.2520, Valid Loss: 0.2568, Valid Accuracy: 0.9013
# Epoch: 1
# Train Loss: 0.2338, Valid Loss: 0.2383, Valid Accuracy: 0.9129
# Epoch: 2
# Train Loss: 0.2272, Valid Loss: 0.2472, Valid Accuracy: 0.9057
# Epoch: 3
# Train Loss: 0.2221, Valid Loss: 0.2483, Valid Accuracy: 0.9071
# Epoch: 4
# Train Loss: 0.2167, Valid Loss: 0.2383, Valid Accuracy: 0.9113
# Epoch: 5
# Train Loss: 0.2138, Valid Loss: 0.2438, Valid Accuracy: 0.9062
# Epoch: 6
# Train Loss: 0.2120, Valid Loss: 0.2523, Valid Accuracy: 0.9025
# Epoch: 7
# Train Loss: 0.2061, Valid Loss: 0.2430, Valid Accuracy: 0.9091
# Early stopping
# Pruning rate: 0.92, method: L1Unstructured
# After pruning:
# Valid Loss: 0.8226, Valid Accuracy: 0.7127
# Retraining the model
# Epoch: 0
# Train Loss: 0.2817, Valid Loss: 0.2817, Valid Accuracy: 0.8921
# Epoch: 1
# Train Loss: 0.2514, Valid Loss: 0.2615, Valid Accuracy: 0.9028
# Epoch: 2
# Train Loss: 0.2442, Valid Loss: 0.2686, Valid Accuracy: 0.8984
# Epoch: 3
# Train Loss: 0.2378, Valid Loss: 0.2590, Valid Accuracy: 0.9030
# Epoch: 4
# Train Loss: 0.2320, Valid Loss: 0.2556, Valid Accuracy: 0.9042
# Epoch: 5
# Train Loss: 0.2292, Valid Loss: 0.2577, Valid Accuracy: 0.9037
# Epoch: 6
# Train Loss: 0.2254, Valid Loss: 0.2476, Valid Accuracy: 0.9070
# Epoch: 7
# Train Loss: 0.2231, Valid Loss: 0.2466, Valid Accuracy: 0.9093
# Epoch: 8
# Train Loss: 0.2199, Valid Loss: 0.2456, Valid Accuracy: 0.9074
# Epoch: 9
# Train Loss: 0.2178, Valid Loss: 0.2511, Valid Accuracy: 0.9047
# Epoch: 10
# Train Loss: 0.2176, Valid Loss: 0.2595, Valid Accuracy: 0.8997
# Epoch: 11
# Train Loss: 0.2142, Valid Loss: 0.2747, Valid Accuracy: 0.8978
# Early stopping
# Pruning rate: 0.96, method: L1Unstructured
# After pruning:
# Valid Loss: 1.5187, Valid Accuracy: 0.4273
# Retraining the model
# Epoch: 0
# Train Loss: 0.3667, Valid Loss: 0.3175, Valid Accuracy: 0.8857
# Epoch: 1
# Train Loss: 0.3050, Valid Loss: 0.3141, Valid Accuracy: 0.8863
# Epoch: 2
# Train Loss: 0.2908, Valid Loss: 0.2960, Valid Accuracy: 0.8914
# Epoch: 3
# Train Loss: 0.2821, Valid Loss: 0.2853, Valid Accuracy: 0.8981
# Epoch: 4
# Train Loss: 0.2753, Valid Loss: 0.2883, Valid Accuracy: 0.8948
# Epoch: 5
# Train Loss: 0.2723, Valid Loss: 0.2942, Valid Accuracy: 0.8926
# Epoch: 6
# Train Loss: 0.2674, Valid Loss: 0.2784, Valid Accuracy: 0.8986
# Epoch: 7
# Train Loss: 0.2637, Valid Loss: 0.2907, Valid Accuracy: 0.8930
# Epoch: 8
# Train Loss: 0.2616, Valid Loss: 0.2895, Valid Accuracy: 0.8950
# Epoch: 9
# Train Loss: 0.2586, Valid Loss: 0.2897, Valid Accuracy: 0.8942
# Early stopping

# %% [markdown]
# ### Iterative pruning

# %%
ITER_PRUNING_RATES = [0.01, 0.02, 0.04]
RETRAIN_EPOCHS = [1, 2, 3, 4]
max_pruning_percent = max(PRUNING_VALUES)

# %% [markdown]
# Create iterative pruning configs

# %%
iterative_pruning_configs = []

for pruning_step, finetune_epochs in itertools.product(
    ITER_PRUNING_RATES, RETRAIN_EPOCHS
):
    iterative_pruning_configs.append(
        PruningMetadata(
            total_pruned=max_pruning_percent,
            pruning_step=pruning_step,
            finetune_epochs=finetune_epochs,
            method=prune.L1Unstructured,
            early_stopping=False,
        )
    )

# %%
for config in iterative_pruning_configs:
    total_pruned = config.total_pruned
    pruning_step = config.pruning_step
    finetune_epochs = config.finetune_epochs
    method = config.method
    method_name = method.__name__

    pruning_value = int(
        round(
            calculate_parameters_amount(get_parameters_to_prune(base_model))
            * pruning_step
        )
    )

    print(
        f"Target total pruning: {total_pruned}, pruning_step: {pruning_step}, method: {method_name}, finetune_epochs: {finetune_epochs}"
    )

    iterative_model = LeNet().to(device)
    iterative_model.load_state_dict(
        torch.load(MODELS_PATH / Path("LeNet_fmnist/LeNet_fmnist.pth"))
    )
    model_name = iterative_model.__class__.__name__

    iterative_model_parameters = get_parameters_to_prune(iterative_model)
    optimizer = optim.SGD(temp_model.parameters(), lr=LEARNING_RATE, momentum=MOMENTUM)

    target_sparsity = int(total_pruned * 100)
    pruning_step_percent = int(pruning_step * 100)
    for pruned in range(
        pruning_step_percent,
        target_sparsity + pruning_step_percent,
        pruning_step_percent,
    ):
        prune.global_unstructured(
            parameters=iterative_model_parameters,
            pruning_method=method,
            amount=pruning_value,
        )

        print("Fine tuning the model")
        for epoch in range(finetune_epochs):
            train_loss = utility.training.train_epoch(
                module=iterative_model,
                train_dl=train_loader,
                optimizer=optimizer,
                loss_function=cross_entropy,
                device=device,
            )

            val_loss, val_accuracy = utility.training.validate(
                module=iterative_model,
                valid_dl=validation_loader,
                loss_function=cross_entropy,
                device=device,
            )

            print(
                f"Pruned {pruned} / {target_sparsity}% | Epoch #{epoch}\tvalidation loss: {val_loss:.4f}\t validation accuracy: {val_accuracy:.4f}"
            )

        if pruned in map(lambda x: int(x * 100), PRUNING_VALUES):
            tmp = copy.deepcopy(iterative_model)
            for module, name in get_parameters_to_prune(tmp):
                prune.remove(module, name)

            tmp_config = copy.deepcopy(config)
            tmp_config.total_pruned = pruned / 100
            tmp_config.method = method.__name__
            utility.save.save_model_with_metadata(
                model=tmp,
                path=f"{model_name}_iterative_pruned_{pruned / 100}_step_{pruning_step}_{method_name}_epochs_{finetune_epochs}",
                model_name=f"{model_name}_iterative_pruned_{pruned / 100}_step_{pruning_step}_{method_name}_epochs_{finetune_epochs}",
                metadata=asdict(tmp_config),
            )

    for module, name in iterative_model_parameters:
        prune.remove(module, name)

    config.method = method.__name__
    utility.save.save_model_with_metadata(
        model=iterative_model,
        path=f"{MODELS_PATH}/{model_name}_iterative_pruned_{total_pruned}_step_{pruning_step}_{method_name}_epochs_{finetune_epochs}",
        model_name=f"{model_name}_iterative_pruned_{total_pruned}_step_{pruning_step}_{method_name}_epochs_{finetune_epochs}",
        metadata=asdict(config),
    )
# Out:
# Target total pruning: 0.96, pruning_step: 0.01, method: L1Unstructured, finetune_epochs: 1
# Fine tuning the model
# Pruned 1 / 96% | Epoch #0	validation loss: 0.2378	 validation accuracy: 0.9091
# Fine tuning the model
# Pruned 2 / 96% | Epoch #0	validation loss: 0.2378	 validation accuracy: 0.9089
# Fine tuning the model
# Pruned 3 / 96% | Epoch #0	validation loss: 0.2378	 validation accuracy: 0.9089
# Fine tuning the model
# Pruned 4 / 96% | Epoch #0	validation loss: 0.2378	 validation accuracy: 0.9088
# Fine tuning the model
# Pruned 5 / 96% | Epoch #0	validation loss: 0.2378	 validation accuracy: 0.9087
# Fine tuning the model
# Pruned 6 / 96% | Epoch #0	validation loss: 0.2379	 validation accuracy: 0.9087
# Fine tuning the model
# Pruned 7 / 96% | Epoch #0	validation loss: 0.2378	 validation accuracy: 0.9086
# Fine tuning the model
# Pruned 8 / 96% | Epoch #0	validation loss: 0.2377	 validation accuracy: 0.9087
# Fine tuning the model
# Pruned 9 / 96% | Epoch #0	validation loss: 0.2379	 validation accuracy: 0.9086
# Fine tuning the model
# Pruned 10 / 96% | Epoch #0	validation loss: 0.2381	 validation accuracy: 0.9086
# Fine tuning the model
# Pruned 11 / 96% | Epoch #0	validation loss: 0.2380	 validation accuracy: 0.9088
# Fine tuning the model
# Pruned 12 / 96% | Epoch #0	validation loss: 0.2380	 validation accuracy: 0.9088
# Fine tuning the model
# Pruned 13 / 96% | Epoch #0	validation loss: 0.2379	 validation accuracy: 0.9088
# Fine tuning the model
# Pruned 14 / 96% | Epoch #0	validation loss: 0.2377	 validation accuracy: 0.9090
# Fine tuning the model
# Pruned 15 / 96% | Epoch #0	validation loss: 0.2377	 validation accuracy: 0.9090
# Fine tuning the model
# Pruned 16 / 96% | Epoch #0	validation loss: 0.2379	 validation accuracy: 0.9092
# Fine tuning the model
# Pruned 17 / 96% | Epoch #0	validation loss: 0.2376	 validation accuracy: 0.9089
# Fine tuning the model
# Pruned 18 / 96% | Epoch #0	validation loss: 0.2371	 validation accuracy: 0.9091
# Fine tuning the model
# Pruned 19 / 96% | Epoch #0	validation loss: 0.2372	 validation accuracy: 0.9089
# Fine tuning the model
# Pruned 20 / 96% | Epoch #0	validation loss: 0.2376	 validation accuracy: 0.9087
# Fine tuning the model
# Pruned 21 / 96% | Epoch #0	validation loss: 0.2376	 validation accuracy: 0.9088
# Fine tuning the model
# Pruned 22 / 96% | Epoch #0	validation loss: 0.2378	 validation accuracy: 0.9087
# Fine tuning the model
# Pruned 23 / 96% | Epoch #0	validation loss: 0.2377	 validation accuracy: 0.9085
# Fine tuning the model
# Pruned 24 / 96% | Epoch #0	validation loss: 0.2373	 validation accuracy: 0.9083
# Fine tuning the model
# Pruned 25 / 96% | Epoch #0	validation loss: 0.2371	 validation accuracy: 0.9078
# Fine tuning the model
# Pruned 26 / 96% | Epoch #0	validation loss: 0.2372	 validation accuracy: 0.9081
# Fine tuning the model
# Pruned 27 / 96% | Epoch #0	validation loss: 0.2372	 validation accuracy: 0.9080
# Fine tuning the model
# Pruned 28 / 96% | Epoch #0	validation loss: 0.2364	 validation accuracy: 0.9088
# Fine tuning the model
# Pruned 29 / 96% | Epoch #0	validation loss: 0.2361	 validation accuracy: 0.9085
# Fine tuning the model
# Pruned 30 / 96% | Epoch #0	validation loss: 0.2372	 validation accuracy: 0.9080
# Fine tuning the model
# Pruned 31 / 96% | Epoch #0	validation loss: 0.2370	 validation accuracy: 0.9083
# Fine tuning the model
# Pruned 32 / 96% | Epoch #0	validation loss: 0.2370	 validation accuracy: 0.9086
# Fine tuning the model
# Pruned 33 / 96% | Epoch #0	validation loss: 0.2366	 validation accuracy: 0.9081
# Fine tuning the model
# Pruned 34 / 96% | Epoch #0	validation loss: 0.2372	 validation accuracy: 0.9085
# Fine tuning the model
# Pruned 35 / 96% | Epoch #0	validation loss: 0.2380	 validation accuracy: 0.9074
# Fine tuning the model
# Pruned 36 / 96% | Epoch #0	validation loss: 0.2386	 validation accuracy: 0.9074
# Fine tuning the model
# Pruned 37 / 96% | Epoch #0	validation loss: 0.2377	 validation accuracy: 0.9076
# Fine tuning the model
# Pruned 38 / 96% | Epoch #0	validation loss: 0.2381	 validation accuracy: 0.9082
# Fine tuning the model
# Pruned 39 / 96% | Epoch #0	validation loss: 0.2381	 validation accuracy: 0.9082
# Fine tuning the model
# Pruned 40 / 96% | Epoch #0	validation loss: 0.2385	 validation accuracy: 0.9078
# Fine tuning the model
# Pruned 41 / 96% | Epoch #0	validation loss: 0.2393	 validation accuracy: 0.9079
# Fine tuning the model
# Pruned 42 / 96% | Epoch #0	validation loss: 0.2391	 validation accuracy: 0.9083
# Fine tuning the model
# Pruned 43 / 96% | Epoch #0	validation loss: 0.2395	 validation accuracy: 0.9084
# Fine tuning the model
# Pruned 44 / 96% | Epoch #0	validation loss: 0.2394	 validation accuracy: 0.9083
# Fine tuning the model
# Pruned 45 / 96% | Epoch #0	validation loss: 0.2388	 validation accuracy: 0.9091
# Fine tuning the model
# Pruned 46 / 96% | Epoch #0	validation loss: 0.2405	 validation accuracy: 0.9083
# Fine tuning the model
# Pruned 47 / 96% | Epoch #0	validation loss: 0.2416	 validation accuracy: 0.9069
# Fine tuning the model
# Pruned 48 / 96% | Epoch #0	validation loss: 0.2421	 validation accuracy: 0.9064
# Fine tuning the model
# Pruned 49 / 96% | Epoch #0	validation loss: 0.2419	 validation accuracy: 0.9069
# Fine tuning the model
# Pruned 50 / 96% | Epoch #0	validation loss: 0.2405	 validation accuracy: 0.9085
# Fine tuning the model
# Pruned 51 / 96% | Epoch #0	validation loss: 0.2414	 validation accuracy: 0.9075
# Fine tuning the model
# Pruned 52 / 96% | Epoch #0	validation loss: 0.2421	 validation accuracy: 0.9075
# Fine tuning the model
# Pruned 53 / 96% | Epoch #0	validation loss: 0.2429	 validation accuracy: 0.9069
# Fine tuning the model
# Pruned 54 / 96% | Epoch #0	validation loss: 0.2431	 validation accuracy: 0.9077
# Fine tuning the model
# Pruned 55 / 96% | Epoch #0	validation loss: 0.2427	 validation accuracy: 0.9073
# Fine tuning the model
# Pruned 56 / 96% | Epoch #0	validation loss: 0.2438	 validation accuracy: 0.9075
# Fine tuning the model
# Pruned 57 / 96% | Epoch #0	validation loss: 0.2450	 validation accuracy: 0.9072
# Fine tuning the model
# Pruned 58 / 96% | Epoch #0	validation loss: 0.2462	 validation accuracy: 0.9064
# Fine tuning the model
# Pruned 59 / 96% | Epoch #0	validation loss: 0.2476	 validation accuracy: 0.9070
# Fine tuning the model
# Pruned 60 / 96% | Epoch #0	validation loss: 0.2498	 validation accuracy: 0.9051
# Fine tuning the model
# Pruned 61 / 96% | Epoch #0	validation loss: 0.2479	 validation accuracy: 0.9062
# Fine tuning the model
# Pruned 62 / 96% | Epoch #0	validation loss: 0.2471	 validation accuracy: 0.9074
# Fine tuning the model
# Pruned 63 / 96% | Epoch #0	validation loss: 0.2454	 validation accuracy: 0.9073
# Fine tuning the model
# Pruned 64 / 96% | Epoch #0	validation loss: 0.2465	 validation accuracy: 0.9064
# Fine tuning the model
# Pruned 65 / 96% | Epoch #0	validation loss: 0.2463	 validation accuracy: 0.9062
# Fine tuning the model
# Pruned 66 / 96% | Epoch #0	validation loss: 0.2474	 validation accuracy: 0.9069
# Fine tuning the model
# Pruned 67 / 96% | Epoch #0	validation loss: 0.2480	 validation accuracy: 0.9069
# Fine tuning the model
# Pruned 68 / 96% | Epoch #0	validation loss: 0.2485	 validation accuracy: 0.9065
# Fine tuning the model
# Pruned 69 / 96% | Epoch #0	validation loss: 0.2509	 validation accuracy: 0.9070
# Fine tuning the model
# Pruned 70 / 96% | Epoch #0	validation loss: 0.2521	 validation accuracy: 0.9057
# Fine tuning the model
# Pruned 71 / 96% | Epoch #0	validation loss: 0.2527	 validation accuracy: 0.9057
# Fine tuning the model
# Pruned 72 / 96% | Epoch #0	validation loss: 0.2540	 validation accuracy: 0.9059
# Fine tuning the model
# Pruned 73 / 96% | Epoch #0	validation loss: 0.2541	 validation accuracy: 0.9060
# Fine tuning the model
# Pruned 74 / 96% | Epoch #0	validation loss: 0.2567	 validation accuracy: 0.9053
# Fine tuning the model
# Pruned 75 / 96% | Epoch #0	validation loss: 0.2614	 validation accuracy: 0.9044
# Fine tuning the model
# Pruned 76 / 96% | Epoch #0	validation loss: 0.2660	 validation accuracy: 0.9026
# Fine tuning the model
# Pruned 77 / 96% | Epoch #0	validation loss: 0.2647	 validation accuracy: 0.9040
# Fine tuning the model
# Pruned 78 / 96% | Epoch #0	validation loss: 0.2729	 validation accuracy: 0.8991
# Fine tuning the model
# Pruned 79 / 96% | Epoch #0	validation loss: 0.2795	 validation accuracy: 0.8959
# Fine tuning the model
# Pruned 80 / 96% | Epoch #0	validation loss: 0.2891	 validation accuracy: 0.8945
# Fine tuning the model
# Pruned 81 / 96% | Epoch #0	validation loss: 0.3008	 validation accuracy: 0.8901
# Fine tuning the model
# Pruned 82 / 96% | Epoch #0	validation loss: 0.3081	 validation accuracy: 0.8870
# Fine tuning the model
# Pruned 83 / 96% | Epoch #0	validation loss: 0.3178	 validation accuracy: 0.8832
# Fine tuning the model
# Pruned 84 / 96% | Epoch #0	validation loss: 0.3310	 validation accuracy: 0.8802
# Fine tuning the model
# Pruned 85 / 96% | Epoch #0	validation loss: 0.3465	 validation accuracy: 0.8781
# Fine tuning the model
# Pruned 86 / 96% | Epoch #0	validation loss: 0.3663	 validation accuracy: 0.8711
# Fine tuning the model
# Pruned 87 / 96% | Epoch #0	validation loss: 0.4012	 validation accuracy: 0.8594
# Fine tuning the model
# Pruned 88 / 96% | Epoch #0	validation loss: 0.4368	 validation accuracy: 0.8433
# Fine tuning the model
# Pruned 89 / 96% | Epoch #0	validation loss: 0.4821	 validation accuracy: 0.8270
# Fine tuning the model
# Pruned 90 / 96% | Epoch #0	validation loss: 0.5463	 validation accuracy: 0.8108
# Fine tuning the model
# Pruned 91 / 96% | Epoch #0	validation loss: 0.6861	 validation accuracy: 0.7471
# Fine tuning the model
# Pruned 92 / 96% | Epoch #0	validation loss: 0.8074	 validation accuracy: 0.7202
# Fine tuning the model
# Pruned 93 / 96% | Epoch #0	validation loss: 0.8957	 validation accuracy: 0.7015
# Fine tuning the model
# Pruned 94 / 96% | Epoch #0	validation loss: 1.1486	 validation accuracy: 0.6062
# Fine tuning the model
# Pruned 95 / 96% | Epoch #0	validation loss: 1.3046	 validation accuracy: 0.5280
# Fine tuning the model
# Pruned 96 / 96% | Epoch #0	validation loss: 1.5240	 validation accuracy: 0.4339
# Target total pruning: 0.96, pruning_step: 0.01, method: L1Unstructured, finetune_epochs: 2
# Fine tuning the model
# Pruned 1 / 96% | Epoch #0	validation loss: 0.2378	 validation accuracy: 0.9091
# Pruned 1 / 96% | Epoch #1	validation loss: 0.2378	 validation accuracy: 0.9091
# Fine tuning the model
# Pruned 2 / 96% | Epoch #0	validation loss: 0.2378	 validation accuracy: 0.9089
# Pruned 2 / 96% | Epoch #1	validation loss: 0.2378	 validation accuracy: 0.9089
# Fine tuning the model
# Pruned 3 / 96% | Epoch #0	validation loss: 0.2378	 validation accuracy: 0.9089
# Pruned 3 / 96% | Epoch #1	validation loss: 0.2378	 validation accuracy: 0.9089
# Fine tuning the model
# Pruned 4 / 96% | Epoch #0	validation loss: 0.2378	 validation accuracy: 0.9088
# Pruned 4 / 96% | Epoch #1	validation loss: 0.2378	 validation accuracy: 0.9088
# Fine tuning the model
# Pruned 5 / 96% | Epoch #0	validation loss: 0.2378	 validation accuracy: 0.9087
# Pruned 5 / 96% | Epoch #1	validation loss: 0.2378	 validation accuracy: 0.9087
# Fine tuning the model
# Pruned 6 / 96% | Epoch #0	validation loss: 0.2379	 validation accuracy: 0.9087
# Pruned 6 / 96% | Epoch #1	validation loss: 0.2379	 validation accuracy: 0.9087
# Fine tuning the model
# Pruned 7 / 96% | Epoch #0	validation loss: 0.2378	 validation accuracy: 0.9086
# Pruned 7 / 96% | Epoch #1	validation loss: 0.2378	 validation accuracy: 0.9086
# Fine tuning the model
# Pruned 8 / 96% | Epoch #0	validation loss: 0.2377	 validation accuracy: 0.9087
# Pruned 8 / 96% | Epoch #1	validation loss: 0.2377	 validation accuracy: 0.9087
# Fine tuning the model
# Pruned 9 / 96% | Epoch #0	validation loss: 0.2379	 validation accuracy: 0.9086
# Pruned 9 / 96% | Epoch #1	validation loss: 0.2379	 validation accuracy: 0.9086
# Fine tuning the model
# Pruned 10 / 96% | Epoch #0	validation loss: 0.2381	 validation accuracy: 0.9086
# Pruned 10 / 96% | Epoch #1	validation loss: 0.2381	 validation accuracy: 0.9086
# Fine tuning the model
# Pruned 11 / 96% | Epoch #0	validation loss: 0.2380	 validation accuracy: 0.9088
# Pruned 11 / 96% | Epoch #1	validation loss: 0.2380	 validation accuracy: 0.9088
# Fine tuning the model
# Pruned 12 / 96% | Epoch #0	validation loss: 0.2380	 validation accuracy: 0.9088
# Pruned 12 / 96% | Epoch #1	validation loss: 0.2380	 validation accuracy: 0.9088
# Fine tuning the model
# Pruned 13 / 96% | Epoch #0	validation loss: 0.2379	 validation accuracy: 0.9088
# Pruned 13 / 96% | Epoch #1	validation loss: 0.2379	 validation accuracy: 0.9088
# Fine tuning the model
# Pruned 14 / 96% | Epoch #0	validation loss: 0.2377	 validation accuracy: 0.9090
# Pruned 14 / 96% | Epoch #1	validation loss: 0.2377	 validation accuracy: 0.9090
# Fine tuning the model
# Pruned 15 / 96% | Epoch #0	validation loss: 0.2377	 validation accuracy: 0.9090
# Pruned 15 / 96% | Epoch #1	validation loss: 0.2377	 validation accuracy: 0.9090
# Fine tuning the model
# Pruned 16 / 96% | Epoch #0	validation loss: 0.2379	 validation accuracy: 0.9092
# Pruned 16 / 96% | Epoch #1	validation loss: 0.2379	 validation accuracy: 0.9092
# Fine tuning the model
# Pruned 17 / 96% | Epoch #0	validation loss: 0.2376	 validation accuracy: 0.9089
# Pruned 17 / 96% | Epoch #1	validation loss: 0.2376	 validation accuracy: 0.9089
# Fine tuning the model
# Pruned 18 / 96% | Epoch #0	validation loss: 0.2371	 validation accuracy: 0.9091
# Pruned 18 / 96% | Epoch #1	validation loss: 0.2371	 validation accuracy: 0.9091
# Fine tuning the model
# Pruned 19 / 96% | Epoch #0	validation loss: 0.2372	 validation accuracy: 0.9089
# Pruned 19 / 96% | Epoch #1	validation loss: 0.2372	 validation accuracy: 0.9089
# Fine tuning the model
# Pruned 20 / 96% | Epoch #0	validation loss: 0.2376	 validation accuracy: 0.9087
# Pruned 20 / 96% | Epoch #1	validation loss: 0.2376	 validation accuracy: 0.9087
# Fine tuning the model
# Pruned 21 / 96% | Epoch #0	validation loss: 0.2376	 validation accuracy: 0.9088
# Pruned 21 / 96% | Epoch #1	validation loss: 0.2376	 validation accuracy: 0.9088
# Fine tuning the model
# Pruned 22 / 96% | Epoch #0	validation loss: 0.2378	 validation accuracy: 0.9087
# Pruned 22 / 96% | Epoch #1	validation loss: 0.2378	 validation accuracy: 0.9087
# Fine tuning the model
# Pruned 23 / 96% | Epoch #0	validation loss: 0.2377	 validation accuracy: 0.9085
# Pruned 23 / 96% | Epoch #1	validation loss: 0.2377	 validation accuracy: 0.9085
# Fine tuning the model
# Pruned 24 / 96% | Epoch #0	validation loss: 0.2373	 validation accuracy: 0.9083
# Pruned 24 / 96% | Epoch #1	validation loss: 0.2373	 validation accuracy: 0.9083
# Fine tuning the model
# Pruned 25 / 96% | Epoch #0	validation loss: 0.2371	 validation accuracy: 0.9078
# Pruned 25 / 96% | Epoch #1	validation loss: 0.2371	 validation accuracy: 0.9078
# Fine tuning the model
# Pruned 26 / 96% | Epoch #0	validation loss: 0.2372	 validation accuracy: 0.9081
# Pruned 26 / 96% | Epoch #1	validation loss: 0.2372	 validation accuracy: 0.9081
# Fine tuning the model
# Pruned 27 / 96% | Epoch #0	validation loss: 0.2372	 validation accuracy: 0.9080
# Pruned 27 / 96% | Epoch #1	validation loss: 0.2372	 validation accuracy: 0.9080
# Fine tuning the model
# Pruned 28 / 96% | Epoch #0	validation loss: 0.2364	 validation accuracy: 0.9088
# Pruned 28 / 96% | Epoch #1	validation loss: 0.2364	 validation accuracy: 0.9088
# Fine tuning the model
# Pruned 29 / 96% | Epoch #0	validation loss: 0.2361	 validation accuracy: 0.9085
# Pruned 29 / 96% | Epoch #1	validation loss: 0.2361	 validation accuracy: 0.9085
# Fine tuning the model
# Pruned 30 / 96% | Epoch #0	validation loss: 0.2372	 validation accuracy: 0.9080
# Pruned 30 / 96% | Epoch #1	validation loss: 0.2372	 validation accuracy: 0.9080
# Fine tuning the model
# Pruned 31 / 96% | Epoch #0	validation loss: 0.2370	 validation accuracy: 0.9083
# Pruned 31 / 96% | Epoch #1	validation loss: 0.2370	 validation accuracy: 0.9083
# Fine tuning the model
# Pruned 32 / 96% | Epoch #0	validation loss: 0.2370	 validation accuracy: 0.9086
# Pruned 32 / 96% | Epoch #1	validation loss: 0.2370	 validation accuracy: 0.9086
# Fine tuning the model
# Pruned 33 / 96% | Epoch #0	validation loss: 0.2366	 validation accuracy: 0.9081
# Pruned 33 / 96% | Epoch #1	validation loss: 0.2366	 validation accuracy: 0.9081
# Fine tuning the model
# Pruned 34 / 96% | Epoch #0	validation loss: 0.2372	 validation accuracy: 0.9085
# Pruned 34 / 96% | Epoch #1	validation loss: 0.2372	 validation accuracy: 0.9085
# Fine tuning the model
# Pruned 35 / 96% | Epoch #0	validation loss: 0.2380	 validation accuracy: 0.9074
# Pruned 35 / 96% | Epoch #1	validation loss: 0.2380	 validation accuracy: 0.9074
# Fine tuning the model
# Pruned 36 / 96% | Epoch #0	validation loss: 0.2386	 validation accuracy: 0.9074
# Pruned 36 / 96% | Epoch #1	validation loss: 0.2386	 validation accuracy: 0.9074
# Fine tuning the model
# Pruned 37 / 96% | Epoch #0	validation loss: 0.2377	 validation accuracy: 0.9076
# Pruned 37 / 96% | Epoch #1	validation loss: 0.2377	 validation accuracy: 0.9076
# Fine tuning the model
# Pruned 38 / 96% | Epoch #0	validation loss: 0.2381	 validation accuracy: 0.9082
# Pruned 38 / 96% | Epoch #1	validation loss: 0.2381	 validation accuracy: 0.9082
# Fine tuning the model
# Pruned 39 / 96% | Epoch #0	validation loss: 0.2381	 validation accuracy: 0.9082
# Pruned 39 / 96% | Epoch #1	validation loss: 0.2381	 validation accuracy: 0.9082
# Fine tuning the model
# Pruned 40 / 96% | Epoch #0	validation loss: 0.2385	 validation accuracy: 0.9078
# Pruned 40 / 96% | Epoch #1	validation loss: 0.2385	 validation accuracy: 0.9078
# Fine tuning the model
# Pruned 41 / 96% | Epoch #0	validation loss: 0.2393	 validation accuracy: 0.9079
# Pruned 41 / 96% | Epoch #1	validation loss: 0.2393	 validation accuracy: 0.9079
# Fine tuning the model
# Pruned 42 / 96% | Epoch #0	validation loss: 0.2391	 validation accuracy: 0.9083
# Pruned 42 / 96% | Epoch #1	validation loss: 0.2391	 validation accuracy: 0.9083
# Fine tuning the model
# Pruned 43 / 96% | Epoch #0	validation loss: 0.2395	 validation accuracy: 0.9084
# Pruned 43 / 96% | Epoch #1	validation loss: 0.2395	 validation accuracy: 0.9084
# Fine tuning the model
# Pruned 44 / 96% | Epoch #0	validation loss: 0.2394	 validation accuracy: 0.9083
# Pruned 44 / 96% | Epoch #1	validation loss: 0.2394	 validation accuracy: 0.9083
# Fine tuning the model
# Pruned 45 / 96% | Epoch #0	validation loss: 0.2388	 validation accuracy: 0.9091
# Pruned 45 / 96% | Epoch #1	validation loss: 0.2388	 validation accuracy: 0.9091
# Fine tuning the model
# Pruned 46 / 96% | Epoch #0	validation loss: 0.2405	 validation accuracy: 0.9083
# Pruned 46 / 96% | Epoch #1	validation loss: 0.2405	 validation accuracy: 0.9083
# Fine tuning the model
# Pruned 47 / 96% | Epoch #0	validation loss: 0.2416	 validation accuracy: 0.9069
# Pruned 47 / 96% | Epoch #1	validation loss: 0.2416	 validation accuracy: 0.9069
# Fine tuning the model
# Pruned 48 / 96% | Epoch #0	validation loss: 0.2421	 validation accuracy: 0.9064
# Pruned 48 / 96% | Epoch #1	validation loss: 0.2421	 validation accuracy: 0.9064
# Fine tuning the model
# Pruned 49 / 96% | Epoch #0	validation loss: 0.2419	 validation accuracy: 0.9069
# Pruned 49 / 96% | Epoch #1	validation loss: 0.2419	 validation accuracy: 0.9069
# Fine tuning the model
# Pruned 50 / 96% | Epoch #0	validation loss: 0.2405	 validation accuracy: 0.9085
# Pruned 50 / 96% | Epoch #1	validation loss: 0.2405	 validation accuracy: 0.9085
# Fine tuning the model
# Pruned 51 / 96% | Epoch #0	validation loss: 0.2414	 validation accuracy: 0.9075
# Pruned 51 / 96% | Epoch #1	validation loss: 0.2414	 validation accuracy: 0.9075
# Fine tuning the model
# Pruned 52 / 96% | Epoch #0	validation loss: 0.2421	 validation accuracy: 0.9075
# Pruned 52 / 96% | Epoch #1	validation loss: 0.2421	 validation accuracy: 0.9075
# Fine tuning the model
# Pruned 53 / 96% | Epoch #0	validation loss: 0.2429	 validation accuracy: 0.9069
# Pruned 53 / 96% | Epoch #1	validation loss: 0.2429	 validation accuracy: 0.9069
# Fine tuning the model
# Pruned 54 / 96% | Epoch #0	validation loss: 0.2431	 validation accuracy: 0.9077
# Pruned 54 / 96% | Epoch #1	validation loss: 0.2431	 validation accuracy: 0.9077
# Fine tuning the model
# Pruned 55 / 96% | Epoch #0	validation loss: 0.2427	 validation accuracy: 0.9073
# Pruned 55 / 96% | Epoch #1	validation loss: 0.2427	 validation accuracy: 0.9073
# Fine tuning the model
# Pruned 56 / 96% | Epoch #0	validation loss: 0.2438	 validation accuracy: 0.9075
# Pruned 56 / 96% | Epoch #1	validation loss: 0.2438	 validation accuracy: 0.9075
# Fine tuning the model
# Pruned 57 / 96% | Epoch #0	validation loss: 0.2450	 validation accuracy: 0.9072
# Pruned 57 / 96% | Epoch #1	validation loss: 0.2450	 validation accuracy: 0.9072
# Fine tuning the model
# Pruned 58 / 96% | Epoch #0	validation loss: 0.2462	 validation accuracy: 0.9064
# Pruned 58 / 96% | Epoch #1	validation loss: 0.2462	 validation accuracy: 0.9064
# Fine tuning the model
# Pruned 59 / 96% | Epoch #0	validation loss: 0.2476	 validation accuracy: 0.9070
# Pruned 59 / 96% | Epoch #1	validation loss: 0.2476	 validation accuracy: 0.9070
# Fine tuning the model
# Pruned 60 / 96% | Epoch #0	validation loss: 0.2498	 validation accuracy: 0.9051
# Pruned 60 / 96% | Epoch #1	validation loss: 0.2498	 validation accuracy: 0.9051
# Fine tuning the model
# Pruned 61 / 96% | Epoch #0	validation loss: 0.2479	 validation accuracy: 0.9062
# Pruned 61 / 96% | Epoch #1	validation loss: 0.2479	 validation accuracy: 0.9062
# Fine tuning the model
# Pruned 62 / 96% | Epoch #0	validation loss: 0.2471	 validation accuracy: 0.9074
# Pruned 62 / 96% | Epoch #1	validation loss: 0.2471	 validation accuracy: 0.9074
# Fine tuning the model
# Pruned 63 / 96% | Epoch #0	validation loss: 0.2454	 validation accuracy: 0.9073
# Pruned 63 / 96% | Epoch #1	validation loss: 0.2454	 validation accuracy: 0.9073
# Fine tuning the model
# Pruned 64 / 96% | Epoch #0	validation loss: 0.2465	 validation accuracy: 0.9064
# Pruned 64 / 96% | Epoch #1	validation loss: 0.2465	 validation accuracy: 0.9064
# Fine tuning the model
# Pruned 65 / 96% | Epoch #0	validation loss: 0.2463	 validation accuracy: 0.9062
# Pruned 65 / 96% | Epoch #1	validation loss: 0.2463	 validation accuracy: 0.9062
# Fine tuning the model
# Pruned 66 / 96% | Epoch #0	validation loss: 0.2474	 validation accuracy: 0.9069
# Pruned 66 / 96% | Epoch #1	validation loss: 0.2474	 validation accuracy: 0.9069
# Fine tuning the model
# Pruned 67 / 96% | Epoch #0	validation loss: 0.2480	 validation accuracy: 0.9069
# Pruned 67 / 96% | Epoch #1	validation loss: 0.2480	 validation accuracy: 0.9069
# Fine tuning the model
# Pruned 68 / 96% | Epoch #0	validation loss: 0.2485	 validation accuracy: 0.9065
# Pruned 68 / 96% | Epoch #1	validation loss: 0.2485	 validation accuracy: 0.9065
# Fine tuning the model
# Pruned 69 / 96% | Epoch #0	validation loss: 0.2509	 validation accuracy: 0.9070
# Pruned 69 / 96% | Epoch #1	validation loss: 0.2509	 validation accuracy: 0.9070
# Fine tuning the model
# Pruned 70 / 96% | Epoch #0	validation loss: 0.2521	 validation accuracy: 0.9057
# Pruned 70 / 96% | Epoch #1	validation loss: 0.2521	 validation accuracy: 0.9057
# Fine tuning the model
# Pruned 71 / 96% | Epoch #0	validation loss: 0.2527	 validation accuracy: 0.9057
# Pruned 71 / 96% | Epoch #1	validation loss: 0.2527	 validation accuracy: 0.9057
# Fine tuning the model
# Pruned 72 / 96% | Epoch #0	validation loss: 0.2540	 validation accuracy: 0.9059
# Pruned 72 / 96% | Epoch #1	validation loss: 0.2540	 validation accuracy: 0.9059
# Fine tuning the model
# Pruned 73 / 96% | Epoch #0	validation loss: 0.2541	 validation accuracy: 0.9060
# Pruned 73 / 96% | Epoch #1	validation loss: 0.2541	 validation accuracy: 0.9060
# Fine tuning the model
# Pruned 74 / 96% | Epoch #0	validation loss: 0.2567	 validation accuracy: 0.9053
# Pruned 74 / 96% | Epoch #1	validation loss: 0.2567	 validation accuracy: 0.9053
# Fine tuning the model
# Pruned 75 / 96% | Epoch #0	validation loss: 0.2614	 validation accuracy: 0.9044
# Pruned 75 / 96% | Epoch #1	validation loss: 0.2614	 validation accuracy: 0.9044
# Fine tuning the model
# Pruned 76 / 96% | Epoch #0	validation loss: 0.2660	 validation accuracy: 0.9026
# Pruned 76 / 96% | Epoch #1	validation loss: 0.2660	 validation accuracy: 0.9026
# Fine tuning the model
# Pruned 77 / 96% | Epoch #0	validation loss: 0.2647	 validation accuracy: 0.9040
# Pruned 77 / 96% | Epoch #1	validation loss: 0.2647	 validation accuracy: 0.9040
# Fine tuning the model
# Pruned 78 / 96% | Epoch #0	validation loss: 0.2729	 validation accuracy: 0.8991
# Pruned 78 / 96% | Epoch #1	validation loss: 0.2729	 validation accuracy: 0.8991
# Fine tuning the model
# Pruned 79 / 96% | Epoch #0	validation loss: 0.2795	 validation accuracy: 0.8959
# Pruned 79 / 96% | Epoch #1	validation loss: 0.2795	 validation accuracy: 0.8959
# Fine tuning the model
# Pruned 80 / 96% | Epoch #0	validation loss: 0.2891	 validation accuracy: 0.8945
# Pruned 80 / 96% | Epoch #1	validation loss: 0.2891	 validation accuracy: 0.8945
# Fine tuning the model
# Pruned 81 / 96% | Epoch #0	validation loss: 0.3008	 validation accuracy: 0.8901
# Pruned 81 / 96% | Epoch #1	validation loss: 0.3008	 validation accuracy: 0.8901
# Fine tuning the model
# Pruned 82 / 96% | Epoch #0	validation loss: 0.3081	 validation accuracy: 0.8870
# Pruned 82 / 96% | Epoch #1	validation loss: 0.3081	 validation accuracy: 0.8870
# Fine tuning the model
# Pruned 83 / 96% | Epoch #0	validation loss: 0.3178	 validation accuracy: 0.8832
# Pruned 83 / 96% | Epoch #1	validation loss: 0.3178	 validation accuracy: 0.8832
# Fine tuning the model
# Pruned 84 / 96% | Epoch #0	validation loss: 0.3310	 validation accuracy: 0.8802
# Pruned 84 / 96% | Epoch #1	validation loss: 0.3310	 validation accuracy: 0.8802
# Fine tuning the model
# Pruned 85 / 96% | Epoch #0	validation loss: 0.3465	 validation accuracy: 0.8781
# Pruned 85 / 96% | Epoch #1	validation loss: 0.3465	 validation accuracy: 0.8781
# Fine tuning the model
# Pruned 86 / 96% | Epoch #0	validation loss: 0.3663	 validation accuracy: 0.8711
# Pruned 86 / 96% | Epoch #1	validation loss: 0.3663	 validation accuracy: 0.8711
# Fine tuning the model
# Pruned 87 / 96% | Epoch #0	validation loss: 0.4012	 validation accuracy: 0.8594
# Pruned 87 / 96% | Epoch #1	validation loss: 0.4012	 validation accuracy: 0.8594
# Fine tuning the model
# Pruned 88 / 96% | Epoch #0	validation loss: 0.4368	 validation accuracy: 0.8433
# Pruned 88 / 96% | Epoch #1	validation loss: 0.4368	 validation accuracy: 0.8433
# Fine tuning the model
# Pruned 89 / 96% | Epoch #0	validation loss: 0.4821	 validation accuracy: 0.8270
# Pruned 89 / 96% | Epoch #1	validation loss: 0.4821	 validation accuracy: 0.8270
# Fine tuning the model
# Pruned 90 / 96% | Epoch #0	validation loss: 0.5463	 validation accuracy: 0.8108
# Pruned 90 / 96% | Epoch #1	validation loss: 0.5463	 validation accuracy: 0.8108
# Fine tuning the model
# Pruned 91 / 96% | Epoch #0	validation loss: 0.6861	 validation accuracy: 0.7471
# Pruned 91 / 96% | Epoch #1	validation loss: 0.6861	 validation accuracy: 0.7471
# Fine tuning the model
# Pruned 92 / 96% | Epoch #0	validation loss: 0.8074	 validation accuracy: 0.7202
# Pruned 92 / 96% | Epoch #1	validation loss: 0.8074	 validation accuracy: 0.7202
# Fine tuning the model
# Pruned 93 / 96% | Epoch #0	validation loss: 0.8957	 validation accuracy: 0.7015
# Pruned 93 / 96% | Epoch #1	validation loss: 0.8957	 validation accuracy: 0.7015
# Fine tuning the model
# Pruned 94 / 96% | Epoch #0	validation loss: 1.1486	 validation accuracy: 0.6062
# Pruned 94 / 96% | Epoch #1	validation loss: 1.1486	 validation accuracy: 0.6062
# Fine tuning the model
# Pruned 95 / 96% | Epoch #0	validation loss: 1.3046	 validation accuracy: 0.5280
# Pruned 95 / 96% | Epoch #1	validation loss: 1.3046	 validation accuracy: 0.5280
# Fine tuning the model
# Pruned 96 / 96% | Epoch #0	validation loss: 1.5240	 validation accuracy: 0.4339
# Pruned 96 / 96% | Epoch #1	validation loss: 1.5240	 validation accuracy: 0.4339
# Target total pruning: 0.96, pruning_step: 0.01, method: L1Unstructured, finetune_epochs: 3
# Fine tuning the model
# Pruned 1 / 96% | Epoch #0	validation loss: 0.2378	 validation accuracy: 0.9091
# Pruned 1 / 96% | Epoch #1	validation loss: 0.2378	 validation accuracy: 0.9091
# Pruned 1 / 96% | Epoch #2	validation loss: 0.2378	 validation accuracy: 0.9091
# Fine tuning the model
# Pruned 2 / 96% | Epoch #0	validation loss: 0.2378	 validation accuracy: 0.9089
# Pruned 2 / 96% | Epoch #1	validation loss: 0.2378	 validation accuracy: 0.9089
# Pruned 2 / 96% | Epoch #2	validation loss: 0.2378	 validation accuracy: 0.9089
# Fine tuning the model
# Pruned 3 / 96% | Epoch #0	validation loss: 0.2378	 validation accuracy: 0.9089
# Pruned 3 / 96% | Epoch #1	validation loss: 0.2378	 validation accuracy: 0.9089
# Pruned 3 / 96% | Epoch #2	validation loss: 0.2378	 validation accuracy: 0.9089
# Fine tuning the model
# Pruned 4 / 96% | Epoch #0	validation loss: 0.2378	 validation accuracy: 0.9088
# Pruned 4 / 96% | Epoch #1	validation loss: 0.2378	 validation accuracy: 0.9088
# Pruned 4 / 96% | Epoch #2	validation loss: 0.2378	 validation accuracy: 0.9088
# Fine tuning the model
# Pruned 5 / 96% | Epoch #0	validation loss: 0.2378	 validation accuracy: 0.9087
# Pruned 5 / 96% | Epoch #1	validation loss: 0.2378	 validation accuracy: 0.9087
# Pruned 5 / 96% | Epoch #2	validation loss: 0.2378	 validation accuracy: 0.9087
# Fine tuning the model
# Pruned 6 / 96% | Epoch #0	validation loss: 0.2379	 validation accuracy: 0.9087
# Pruned 6 / 96% | Epoch #1	validation loss: 0.2379	 validation accuracy: 0.9087
# Pruned 6 / 96% | Epoch #2	validation loss: 0.2379	 validation accuracy: 0.9087
# Fine tuning the model
# Pruned 7 / 96% | Epoch #0	validation loss: 0.2378	 validation accuracy: 0.9086
# Pruned 7 / 96% | Epoch #1	validation loss: 0.2378	 validation accuracy: 0.9086
# Pruned 7 / 96% | Epoch #2	validation loss: 0.2378	 validation accuracy: 0.9086
# Fine tuning the model
# Pruned 8 / 96% | Epoch #0	validation loss: 0.2377	 validation accuracy: 0.9087
# Pruned 8 / 96% | Epoch #1	validation loss: 0.2377	 validation accuracy: 0.9087
# Pruned 8 / 96% | Epoch #2	validation loss: 0.2377	 validation accuracy: 0.9087
# Fine tuning the model
# Pruned 9 / 96% | Epoch #0	validation loss: 0.2379	 validation accuracy: 0.9086
# Pruned 9 / 96% | Epoch #1	validation loss: 0.2379	 validation accuracy: 0.9086
# Pruned 9 / 96% | Epoch #2	validation loss: 0.2379	 validation accuracy: 0.9086
# Fine tuning the model
# Pruned 10 / 96% | Epoch #0	validation loss: 0.2381	 validation accuracy: 0.9086
# Pruned 10 / 96% | Epoch #1	validation loss: 0.2381	 validation accuracy: 0.9086
# Pruned 10 / 96% | Epoch #2	validation loss: 0.2381	 validation accuracy: 0.9086
# Fine tuning the model
# Pruned 11 / 96% | Epoch #0	validation loss: 0.2380	 validation accuracy: 0.9088
# Pruned 11 / 96% | Epoch #1	validation loss: 0.2380	 validation accuracy: 0.9088
# Pruned 11 / 96% | Epoch #2	validation loss: 0.2380	 validation accuracy: 0.9088
# Fine tuning the model
# Pruned 12 / 96% | Epoch #0	validation loss: 0.2380	 validation accuracy: 0.9088
# Pruned 12 / 96% | Epoch #1	validation loss: 0.2380	 validation accuracy: 0.9088
# Pruned 12 / 96% | Epoch #2	validation loss: 0.2380	 validation accuracy: 0.9088
# Fine tuning the model
# Pruned 13 / 96% | Epoch #0	validation loss: 0.2379	 validation accuracy: 0.9088
# Pruned 13 / 96% | Epoch #1	validation loss: 0.2379	 validation accuracy: 0.9088
# Pruned 13 / 96% | Epoch #2	validation loss: 0.2379	 validation accuracy: 0.9088
# Fine tuning the model
# Pruned 14 / 96% | Epoch #0	validation loss: 0.2377	 validation accuracy: 0.9090
# Pruned 14 / 96% | Epoch #1	validation loss: 0.2377	 validation accuracy: 0.9090
# Pruned 14 / 96% | Epoch #2	validation loss: 0.2377	 validation accuracy: 0.9090
# Fine tuning the model
# Pruned 15 / 96% | Epoch #0	validation loss: 0.2377	 validation accuracy: 0.9090
# Pruned 15 / 96% | Epoch #1	validation loss: 0.2377	 validation accuracy: 0.9090
# Pruned 15 / 96% | Epoch #2	validation loss: 0.2377	 validation accuracy: 0.9090
# Fine tuning the model
# Pruned 16 / 96% | Epoch #0	validation loss: 0.2379	 validation accuracy: 0.9092
# Pruned 16 / 96% | Epoch #1	validation loss: 0.2379	 validation accuracy: 0.9092
# Pruned 16 / 96% | Epoch #2	validation loss: 0.2379	 validation accuracy: 0.9092
# Fine tuning the model
# Pruned 17 / 96% | Epoch #0	validation loss: 0.2376	 validation accuracy: 0.9089
# Pruned 17 / 96% | Epoch #1	validation loss: 0.2376	 validation accuracy: 0.9089
# Pruned 17 / 96% | Epoch #2	validation loss: 0.2376	 validation accuracy: 0.9089
# Fine tuning the model
# Pruned 18 / 96% | Epoch #0	validation loss: 0.2371	 validation accuracy: 0.9091
# Pruned 18 / 96% | Epoch #1	validation loss: 0.2371	 validation accuracy: 0.9091
# Pruned 18 / 96% | Epoch #2	validation loss: 0.2371	 validation accuracy: 0.9091
# Fine tuning the model
# Pruned 19 / 96% | Epoch #0	validation loss: 0.2372	 validation accuracy: 0.9089
# Pruned 19 / 96% | Epoch #1	validation loss: 0.2372	 validation accuracy: 0.9089
# Pruned 19 / 96% | Epoch #2	validation loss: 0.2372	 validation accuracy: 0.9089
# Fine tuning the model
# Pruned 20 / 96% | Epoch #0	validation loss: 0.2376	 validation accuracy: 0.9087
# Pruned 20 / 96% | Epoch #1	validation loss: 0.2376	 validation accuracy: 0.9087
# Pruned 20 / 96% | Epoch #2	validation loss: 0.2376	 validation accuracy: 0.9087
# Fine tuning the model
# Pruned 21 / 96% | Epoch #0	validation loss: 0.2376	 validation accuracy: 0.9088
# Pruned 21 / 96% | Epoch #1	validation loss: 0.2376	 validation accuracy: 0.9088
# Pruned 21 / 96% | Epoch #2	validation loss: 0.2376	 validation accuracy: 0.9088
# Fine tuning the model
# Pruned 22 / 96% | Epoch #0	validation loss: 0.2378	 validation accuracy: 0.9087
# Pruned 22 / 96% | Epoch #1	validation loss: 0.2378	 validation accuracy: 0.9087
# Pruned 22 / 96% | Epoch #2	validation loss: 0.2378	 validation accuracy: 0.9087
# Fine tuning the model
# Pruned 23 / 96% | Epoch #0	validation loss: 0.2377	 validation accuracy: 0.9085
# Pruned 23 / 96% | Epoch #1	validation loss: 0.2377	 validation accuracy: 0.9085
# Pruned 23 / 96% | Epoch #2	validation loss: 0.2377	 validation accuracy: 0.9085
# Fine tuning the model
# Pruned 24 / 96% | Epoch #0	validation loss: 0.2373	 validation accuracy: 0.9083
# Pruned 24 / 96% | Epoch #1	validation loss: 0.2373	 validation accuracy: 0.9083
# Pruned 24 / 96% | Epoch #2	validation loss: 0.2373	 validation accuracy: 0.9083
# Fine tuning the model
# Pruned 25 / 96% | Epoch #0	validation loss: 0.2371	 validation accuracy: 0.9078
# Pruned 25 / 96% | Epoch #1	validation loss: 0.2371	 validation accuracy: 0.9078
# Pruned 25 / 96% | Epoch #2	validation loss: 0.2371	 validation accuracy: 0.9078
# Fine tuning the model
# Pruned 26 / 96% | Epoch #0	validation loss: 0.2372	 validation accuracy: 0.9081
# Pruned 26 / 96% | Epoch #1	validation loss: 0.2372	 validation accuracy: 0.9081
# Pruned 26 / 96% | Epoch #2	validation loss: 0.2372	 validation accuracy: 0.9081
# Fine tuning the model
# Pruned 27 / 96% | Epoch #0	validation loss: 0.2372	 validation accuracy: 0.9080
# Pruned 27 / 96% | Epoch #1	validation loss: 0.2372	 validation accuracy: 0.9080
# Pruned 27 / 96% | Epoch #2	validation loss: 0.2372	 validation accuracy: 0.9080
# Fine tuning the model
# Pruned 28 / 96% | Epoch #0	validation loss: 0.2364	 validation accuracy: 0.9088
# Pruned 28 / 96% | Epoch #1	validation loss: 0.2364	 validation accuracy: 0.9088
# Pruned 28 / 96% | Epoch #2	validation loss: 0.2364	 validation accuracy: 0.9088
# Fine tuning the model
# Pruned 29 / 96% | Epoch #0	validation loss: 0.2361	 validation accuracy: 0.9085
# Pruned 29 / 96% | Epoch #1	validation loss: 0.2361	 validation accuracy: 0.9085
# Pruned 29 / 96% | Epoch #2	validation loss: 0.2361	 validation accuracy: 0.9085
# Fine tuning the model
# Pruned 30 / 96% | Epoch #0	validation loss: 0.2372	 validation accuracy: 0.9080
# Pruned 30 / 96% | Epoch #1	validation loss: 0.2372	 validation accuracy: 0.9080
# Pruned 30 / 96% | Epoch #2	validation loss: 0.2372	 validation accuracy: 0.9080
# Fine tuning the model
# Pruned 31 / 96% | Epoch #0	validation loss: 0.2370	 validation accuracy: 0.9083
# Pruned 31 / 96% | Epoch #1	validation loss: 0.2370	 validation accuracy: 0.9083
# Pruned 31 / 96% | Epoch #2	validation loss: 0.2370	 validation accuracy: 0.9083
# Fine tuning the model
# Pruned 32 / 96% | Epoch #0	validation loss: 0.2370	 validation accuracy: 0.9086
# Pruned 32 / 96% | Epoch #1	validation loss: 0.2370	 validation accuracy: 0.9086
# Pruned 32 / 96% | Epoch #2	validation loss: 0.2370	 validation accuracy: 0.9086
# Fine tuning the model
# Pruned 33 / 96% | Epoch #0	validation loss: 0.2366	 validation accuracy: 0.9081
# Pruned 33 / 96% | Epoch #1	validation loss: 0.2366	 validation accuracy: 0.9081
# Pruned 33 / 96% | Epoch #2	validation loss: 0.2366	 validation accuracy: 0.9081
# Fine tuning the model
# Pruned 34 / 96% | Epoch #0	validation loss: 0.2372	 validation accuracy: 0.9085
# Pruned 34 / 96% | Epoch #1	validation loss: 0.2372	 validation accuracy: 0.9085
# Pruned 34 / 96% | Epoch #2	validation loss: 0.2372	 validation accuracy: 0.9085
# Fine tuning the model
# Pruned 35 / 96% | Epoch #0	validation loss: 0.2380	 validation accuracy: 0.9074
# Pruned 35 / 96% | Epoch #1	validation loss: 0.2380	 validation accuracy: 0.9074
# Pruned 35 / 96% | Epoch #2	validation loss: 0.2380	 validation accuracy: 0.9074
# Fine tuning the model
# Pruned 36 / 96% | Epoch #0	validation loss: 0.2386	 validation accuracy: 0.9074
# Pruned 36 / 96% | Epoch #1	validation loss: 0.2386	 validation accuracy: 0.9074
# Pruned 36 / 96% | Epoch #2	validation loss: 0.2386	 validation accuracy: 0.9074
# Fine tuning the model
# Pruned 37 / 96% | Epoch #0	validation loss: 0.2377	 validation accuracy: 0.9076
# Pruned 37 / 96% | Epoch #1	validation loss: 0.2377	 validation accuracy: 0.9076
# Pruned 37 / 96% | Epoch #2	validation loss: 0.2377	 validation accuracy: 0.9076
# Fine tuning the model
# Pruned 38 / 96% | Epoch #0	validation loss: 0.2381	 validation accuracy: 0.9082
# Pruned 38 / 96% | Epoch #1	validation loss: 0.2381	 validation accuracy: 0.9082
# Pruned 38 / 96% | Epoch #2	validation loss: 0.2381	 validation accuracy: 0.9082
# Fine tuning the model
# Pruned 39 / 96% | Epoch #0	validation loss: 0.2381	 validation accuracy: 0.9082
# Pruned 39 / 96% | Epoch #1	validation loss: 0.2381	 validation accuracy: 0.9082
# Pruned 39 / 96% | Epoch #2	validation loss: 0.2381	 validation accuracy: 0.9082
# Fine tuning the model
# Pruned 40 / 96% | Epoch #0	validation loss: 0.2385	 validation accuracy: 0.9078
# Pruned 40 / 96% | Epoch #1	validation loss: 0.2385	 validation accuracy: 0.9078
# Pruned 40 / 96% | Epoch #2	validation loss: 0.2385	 validation accuracy: 0.9078
# Fine tuning the model
# Pruned 41 / 96% | Epoch #0	validation loss: 0.2393	 validation accuracy: 0.9079
# Pruned 41 / 96% | Epoch #1	validation loss: 0.2393	 validation accuracy: 0.9079
# Pruned 41 / 96% | Epoch #2	validation loss: 0.2393	 validation accuracy: 0.9079
# Fine tuning the model
# Pruned 42 / 96% | Epoch #0	validation loss: 0.2391	 validation accuracy: 0.9083
# Pruned 42 / 96% | Epoch #1	validation loss: 0.2391	 validation accuracy: 0.9083
# Pruned 42 / 96% | Epoch #2	validation loss: 0.2391	 validation accuracy: 0.9083
# Fine tuning the model
# Pruned 43 / 96% | Epoch #0	validation loss: 0.2395	 validation accuracy: 0.9084
# Pruned 43 / 96% | Epoch #1	validation loss: 0.2395	 validation accuracy: 0.9084
# Pruned 43 / 96% | Epoch #2	validation loss: 0.2395	 validation accuracy: 0.9084
# Fine tuning the model
# Pruned 44 / 96% | Epoch #0	validation loss: 0.2394	 validation accuracy: 0.9083
# Pruned 44 / 96% | Epoch #1	validation loss: 0.2394	 validation accuracy: 0.9083
# Pruned 44 / 96% | Epoch #2	validation loss: 0.2394	 validation accuracy: 0.9083
# Fine tuning the model
# Pruned 45 / 96% | Epoch #0	validation loss: 0.2388	 validation accuracy: 0.9091
# Pruned 45 / 96% | Epoch #1	validation loss: 0.2388	 validation accuracy: 0.9091
# Pruned 45 / 96% | Epoch #2	validation loss: 0.2388	 validation accuracy: 0.9091
# Fine tuning the model
# Pruned 46 / 96% | Epoch #0	validation loss: 0.2405	 validation accuracy: 0.9083
# Pruned 46 / 96% | Epoch #1	validation loss: 0.2405	 validation accuracy: 0.9083
# Pruned 46 / 96% | Epoch #2	validation loss: 0.2405	 validation accuracy: 0.9083
# Fine tuning the model
# Pruned 47 / 96% | Epoch #0	validation loss: 0.2416	 validation accuracy: 0.9069
# Pruned 47 / 96% | Epoch #1	validation loss: 0.2416	 validation accuracy: 0.9069
# Pruned 47 / 96% | Epoch #2	validation loss: 0.2416	 validation accuracy: 0.9069
# Fine tuning the model
# Pruned 48 / 96% | Epoch #0	validation loss: 0.2421	 validation accuracy: 0.9064
# Pruned 48 / 96% | Epoch #1	validation loss: 0.2421	 validation accuracy: 0.9064
# Pruned 48 / 96% | Epoch #2	validation loss: 0.2421	 validation accuracy: 0.9064
# Fine tuning the model
# Pruned 49 / 96% | Epoch #0	validation loss: 0.2419	 validation accuracy: 0.9069
# Pruned 49 / 96% | Epoch #1	validation loss: 0.2419	 validation accuracy: 0.9069
# Pruned 49 / 96% | Epoch #2	validation loss: 0.2419	 validation accuracy: 0.9069
# Fine tuning the model
# Pruned 50 / 96% | Epoch #0	validation loss: 0.2405	 validation accuracy: 0.9085
# Pruned 50 / 96% | Epoch #1	validation loss: 0.2405	 validation accuracy: 0.9085
# Pruned 50 / 96% | Epoch #2	validation loss: 0.2405	 validation accuracy: 0.9085
# Fine tuning the model
# Pruned 51 / 96% | Epoch #0	validation loss: 0.2414	 validation accuracy: 0.9075
# Pruned 51 / 96% | Epoch #1	validation loss: 0.2414	 validation accuracy: 0.9075
# Pruned 51 / 96% | Epoch #2	validation loss: 0.2414	 validation accuracy: 0.9075
# Fine tuning the model
# Pruned 52 / 96% | Epoch #0	validation loss: 0.2421	 validation accuracy: 0.9075
# Pruned 52 / 96% | Epoch #1	validation loss: 0.2421	 validation accuracy: 0.9075
# Pruned 52 / 96% | Epoch #2	validation loss: 0.2421	 validation accuracy: 0.9075
# Fine tuning the model
# Pruned 53 / 96% | Epoch #0	validation loss: 0.2429	 validation accuracy: 0.9069
# Pruned 53 / 96% | Epoch #1	validation loss: 0.2429	 validation accuracy: 0.9069
# Pruned 53 / 96% | Epoch #2	validation loss: 0.2429	 validation accuracy: 0.9069
# Fine tuning the model
# Pruned 54 / 96% | Epoch #0	validation loss: 0.2431	 validation accuracy: 0.9077
# Pruned 54 / 96% | Epoch #1	validation loss: 0.2431	 validation accuracy: 0.9077
# Pruned 54 / 96% | Epoch #2	validation loss: 0.2431	 validation accuracy: 0.9077
# Fine tuning the model
# Pruned 55 / 96% | Epoch #0	validation loss: 0.2427	 validation accuracy: 0.9073
# Pruned 55 / 96% | Epoch #1	validation loss: 0.2427	 validation accuracy: 0.9073
# Pruned 55 / 96% | Epoch #2	validation loss: 0.2427	 validation accuracy: 0.9073
# Fine tuning the model
# Pruned 56 / 96% | Epoch #0	validation loss: 0.2438	 validation accuracy: 0.9075
# Pruned 56 / 96% | Epoch #1	validation loss: 0.2438	 validation accuracy: 0.9075
# Pruned 56 / 96% | Epoch #2	validation loss: 0.2438	 validation accuracy: 0.9075
# Fine tuning the model
# Pruned 57 / 96% | Epoch #0	validation loss: 0.2450	 validation accuracy: 0.9072
# Pruned 57 / 96% | Epoch #1	validation loss: 0.2450	 validation accuracy: 0.9072
# Pruned 57 / 96% | Epoch #2	validation loss: 0.2450	 validation accuracy: 0.9072
# Fine tuning the model
# Pruned 58 / 96% | Epoch #0	validation loss: 0.2462	 validation accuracy: 0.9064
# Pruned 58 / 96% | Epoch #1	validation loss: 0.2462	 validation accuracy: 0.9064
# Pruned 58 / 96% | Epoch #2	validation loss: 0.2462	 validation accuracy: 0.9064
# Fine tuning the model
# Pruned 59 / 96% | Epoch #0	validation loss: 0.2476	 validation accuracy: 0.9070
# Pruned 59 / 96% | Epoch #1	validation loss: 0.2476	 validation accuracy: 0.9070
# Pruned 59 / 96% | Epoch #2	validation loss: 0.2476	 validation accuracy: 0.9070
# Fine tuning the model
# Pruned 60 / 96% | Epoch #0	validation loss: 0.2498	 validation accuracy: 0.9051
# Pruned 60 / 96% | Epoch #1	validation loss: 0.2498	 validation accuracy: 0.9051
# Pruned 60 / 96% | Epoch #2	validation loss: 0.2498	 validation accuracy: 0.9051
# Fine tuning the model
# Pruned 61 / 96% | Epoch #0	validation loss: 0.2479	 validation accuracy: 0.9062
# Pruned 61 / 96% | Epoch #1	validation loss: 0.2479	 validation accuracy: 0.9062
# Pruned 61 / 96% | Epoch #2	validation loss: 0.2479	 validation accuracy: 0.9062
# Fine tuning the model
# Pruned 62 / 96% | Epoch #0	validation loss: 0.2471	 validation accuracy: 0.9074
# Pruned 62 / 96% | Epoch #1	validation loss: 0.2471	 validation accuracy: 0.9074
# Pruned 62 / 96% | Epoch #2	validation loss: 0.2471	 validation accuracy: 0.9074
# Fine tuning the model
# Pruned 63 / 96% | Epoch #0	validation loss: 0.2454	 validation accuracy: 0.9073
# Pruned 63 / 96% | Epoch #1	validation loss: 0.2454	 validation accuracy: 0.9073
# Pruned 63 / 96% | Epoch #2	validation loss: 0.2454	 validation accuracy: 0.9073
# Fine tuning the model
# Pruned 64 / 96% | Epoch #0	validation loss: 0.2465	 validation accuracy: 0.9064
# Pruned 64 / 96% | Epoch #1	validation loss: 0.2465	 validation accuracy: 0.9064
# Pruned 64 / 96% | Epoch #2	validation loss: 0.2465	 validation accuracy: 0.9064
# Fine tuning the model
# Pruned 65 / 96% | Epoch #0	validation loss: 0.2463	 validation accuracy: 0.9062
# Pruned 65 / 96% | Epoch #1	validation loss: 0.2463	 validation accuracy: 0.9062
# Pruned 65 / 96% | Epoch #2	validation loss: 0.2463	 validation accuracy: 0.9062
# Fine tuning the model
# Pruned 66 / 96% | Epoch #0	validation loss: 0.2474	 validation accuracy: 0.9069
# Pruned 66 / 96% | Epoch #1	validation loss: 0.2474	 validation accuracy: 0.9069
# Pruned 66 / 96% | Epoch #2	validation loss: 0.2474	 validation accuracy: 0.9069
# Fine tuning the model
# Pruned 67 / 96% | Epoch #0	validation loss: 0.2480	 validation accuracy: 0.9069
# Pruned 67 / 96% | Epoch #1	validation loss: 0.2480	 validation accuracy: 0.9069
# Pruned 67 / 96% | Epoch #2	validation loss: 0.2480	 validation accuracy: 0.9069
# Fine tuning the model
# Pruned 68 / 96% | Epoch #0	validation loss: 0.2485	 validation accuracy: 0.9065
# Pruned 68 / 96% | Epoch #1	validation loss: 0.2485	 validation accuracy: 0.9065
# Pruned 68 / 96% | Epoch #2	validation loss: 0.2485	 validation accuracy: 0.9065
# Fine tuning the model
# Pruned 69 / 96% | Epoch #0	validation loss: 0.2509	 validation accuracy: 0.9070
# Pruned 69 / 96% | Epoch #1	validation loss: 0.2509	 validation accuracy: 0.9070
# Pruned 69 / 96% | Epoch #2	validation loss: 0.2509	 validation accuracy: 0.9070
# Fine tuning the model
# Pruned 70 / 96% | Epoch #0	validation loss: 0.2521	 validation accuracy: 0.9057
# Pruned 70 / 96% | Epoch #1	validation loss: 0.2521	 validation accuracy: 0.9057
# Pruned 70 / 96% | Epoch #2	validation loss: 0.2521	 validation accuracy: 0.9057
# Fine tuning the model
# Pruned 71 / 96% | Epoch #0	validation loss: 0.2527	 validation accuracy: 0.9057
# Pruned 71 / 96% | Epoch #1	validation loss: 0.2527	 validation accuracy: 0.9057
# Pruned 71 / 96% | Epoch #2	validation loss: 0.2527	 validation accuracy: 0.9057
# Fine tuning the model
# Pruned 72 / 96% | Epoch #0	validation loss: 0.2540	 validation accuracy: 0.9059
# Pruned 72 / 96% | Epoch #1	validation loss: 0.2540	 validation accuracy: 0.9059
# Pruned 72 / 96% | Epoch #2	validation loss: 0.2540	 validation accuracy: 0.9059
# Fine tuning the model
# Pruned 73 / 96% | Epoch #0	validation loss: 0.2541	 validation accuracy: 0.9060
# Pruned 73 / 96% | Epoch #1	validation loss: 0.2541	 validation accuracy: 0.9060
# Pruned 73 / 96% | Epoch #2	validation loss: 0.2541	 validation accuracy: 0.9060
# Fine tuning the model
# Pruned 74 / 96% | Epoch #0	validation loss: 0.2567	 validation accuracy: 0.9053
# Pruned 74 / 96% | Epoch #1	validation loss: 0.2567	 validation accuracy: 0.9053
# Pruned 74 / 96% | Epoch #2	validation loss: 0.2567	 validation accuracy: 0.9053
# Fine tuning the model
# Pruned 75 / 96% | Epoch #0	validation loss: 0.2614	 validation accuracy: 0.9044
# Pruned 75 / 96% | Epoch #1	validation loss: 0.2614	 validation accuracy: 0.9044
# Pruned 75 / 96% | Epoch #2	validation loss: 0.2614	 validation accuracy: 0.9044
# Fine tuning the model
# Pruned 76 / 96% | Epoch #0	validation loss: 0.2660	 validation accuracy: 0.9026
# Pruned 76 / 96% | Epoch #1	validation loss: 0.2660	 validation accuracy: 0.9026
# Pruned 76 / 96% | Epoch #2	validation loss: 0.2660	 validation accuracy: 0.9026
# Fine tuning the model
# Pruned 77 / 96% | Epoch #0	validation loss: 0.2647	 validation accuracy: 0.9040
# Pruned 77 / 96% | Epoch #1	validation loss: 0.2647	 validation accuracy: 0.9040
# Pruned 77 / 96% | Epoch #2	validation loss: 0.2647	 validation accuracy: 0.9040
# Fine tuning the model
# Pruned 78 / 96% | Epoch #0	validation loss: 0.2729	 validation accuracy: 0.8991
# Pruned 78 / 96% | Epoch #1	validation loss: 0.2729	 validation accuracy: 0.8991
# Pruned 78 / 96% | Epoch #2	validation loss: 0.2729	 validation accuracy: 0.8991
# Fine tuning the model
# ...
# Fine tuning the model
# Pruned 72 / 96% | Epoch #0	validation loss: 0.2541	 validation accuracy: 0.9058
# Pruned 72 / 96% | Epoch #1	validation loss: 0.2541	 validation accuracy: 0.9058
# Fine tuning the model
# Pruned 76 / 96% | Epoch #0	validation loss: 0.2659	 validation accuracy: 0.9024
# Pruned 76 / 96% | Epoch #1	validation loss: 0.2659	 validation accuracy: 0.9024
# Fine tuning the model
# Pruned 80 / 96% | Epoch #0	validation loss: 0.2886	 validation accuracy: 0.8951
# Pruned 80 / 96% | Epoch #1	validation loss: 0.2886	 validation accuracy: 0.8951
# Fine tuning the model
# Pruned 84 / 96% | Epoch #0	validation loss: 0.3323	 validation accuracy: 0.8792
# Pruned 84 / 96% | Epoch #1	validation loss: 0.3323	 validation accuracy: 0.8792
# Fine tuning the model
# Pruned 88 / 96% | Epoch #0	validation loss: 0.4372	 validation accuracy: 0.8411
# Pruned 88 / 96% | Epoch #1	validation loss: 0.4372	 validation accuracy: 0.8411
# Fine tuning the model
# Pruned 92 / 96% | Epoch #0	validation loss: 0.8242	 validation accuracy: 0.7113
# Pruned 92 / 96% | Epoch #1	validation loss: 0.8242	 validation accuracy: 0.7113
# Fine tuning the model
# Pruned 96 / 96% | Epoch #0	validation loss: 1.5288	 validation accuracy: 0.4237
# Pruned 96 / 96% | Epoch #1	validation loss: 1.5288	 validation accuracy: 0.4237
# Target total pruning: 0.96, pruning_step: 0.04, method: L1Unstructured, finetune_epochs: 3
# Fine tuning the model
# Pruned 4 / 96% | Epoch #0	validation loss: 0.2378	 validation accuracy: 0.9088
# Pruned 4 / 96% | Epoch #1	validation loss: 0.2378	 validation accuracy: 0.9088
# Pruned 4 / 96% | Epoch #2	validation loss: 0.2378	 validation accuracy: 0.9088
# Fine tuning the model
# Pruned 8 / 96% | Epoch #0	validation loss: 0.2377	 validation accuracy: 0.9087
# Pruned 8 / 96% | Epoch #1	validation loss: 0.2377	 validation accuracy: 0.9087
# Pruned 8 / 96% | Epoch #2	validation loss: 0.2377	 validation accuracy: 0.9087
# Fine tuning the model
# Pruned 12 / 96% | Epoch #0	validation loss: 0.2380	 validation accuracy: 0.9088
# Pruned 12 / 96% | Epoch #1	validation loss: 0.2380	 validation accuracy: 0.9088
# Pruned 12 / 96% | Epoch #2	validation loss: 0.2380	 validation accuracy: 0.9088
# Fine tuning the model
# Pruned 16 / 96% | Epoch #0	validation loss: 0.2379	 validation accuracy: 0.9091
# Pruned 16 / 96% | Epoch #1	validation loss: 0.2379	 validation accuracy: 0.9091
# Pruned 16 / 96% | Epoch #2	validation loss: 0.2379	 validation accuracy: 0.9091
# Fine tuning the model
# Pruned 20 / 96% | Epoch #0	validation loss: 0.2376	 validation accuracy: 0.9088
# Pruned 20 / 96% | Epoch #1	validation loss: 0.2376	 validation accuracy: 0.9088
# Pruned 20 / 96% | Epoch #2	validation loss: 0.2376	 validation accuracy: 0.9088
# Fine tuning the model
# Pruned 24 / 96% | Epoch #0	validation loss: 0.2373	 validation accuracy: 0.9083
# Pruned 24 / 96% | Epoch #1	validation loss: 0.2373	 validation accuracy: 0.9083
# Pruned 24 / 96% | Epoch #2	validation loss: 0.2373	 validation accuracy: 0.9083
# Fine tuning the model
# Pruned 28 / 96% | Epoch #0	validation loss: 0.2365	 validation accuracy: 0.9084
# Pruned 28 / 96% | Epoch #1	validation loss: 0.2365	 validation accuracy: 0.9084
# Pruned 28 / 96% | Epoch #2	validation loss: 0.2365	 validation accuracy: 0.9084
# Fine tuning the model
# Pruned 32 / 96% | Epoch #0	validation loss: 0.2370	 validation accuracy: 0.9084
# Pruned 32 / 96% | Epoch #1	validation loss: 0.2370	 validation accuracy: 0.9084
# Pruned 32 / 96% | Epoch #2	validation loss: 0.2370	 validation accuracy: 0.9084
# Fine tuning the model
# Pruned 36 / 96% | Epoch #0	validation loss: 0.2387	 validation accuracy: 0.9074
# Pruned 36 / 96% | Epoch #1	validation loss: 0.2387	 validation accuracy: 0.9074
# Pruned 36 / 96% | Epoch #2	validation loss: 0.2387	 validation accuracy: 0.9074
# Fine tuning the model
# Pruned 40 / 96% | Epoch #0	validation loss: 0.2384	 validation accuracy: 0.9078
# Pruned 40 / 96% | Epoch #1	validation loss: 0.2384	 validation accuracy: 0.9078
# Pruned 40 / 96% | Epoch #2	validation loss: 0.2384	 validation accuracy: 0.9078
# Fine tuning the model
# Pruned 44 / 96% | Epoch #0	validation loss: 0.2398	 validation accuracy: 0.9085
# Pruned 44 / 96% | Epoch #1	validation loss: 0.2398	 validation accuracy: 0.9085
# Pruned 44 / 96% | Epoch #2	validation loss: 0.2398	 validation accuracy: 0.9085
# Fine tuning the model
# Pruned 48 / 96% | Epoch #0	validation loss: 0.2421	 validation accuracy: 0.9064
# Pruned 48 / 96% | Epoch #1	validation loss: 0.2421	 validation accuracy: 0.9064
# Pruned 48 / 96% | Epoch #2	validation loss: 0.2421	 validation accuracy: 0.9064
# Fine tuning the model
# Pruned 52 / 96% | Epoch #0	validation loss: 0.2421	 validation accuracy: 0.9073
# Pruned 52 / 96% | Epoch #1	validation loss: 0.2421	 validation accuracy: 0.9073
# Pruned 52 / 96% | Epoch #2	validation loss: 0.2421	 validation accuracy: 0.9073
# Fine tuning the model
# Pruned 56 / 96% | Epoch #0	validation loss: 0.2438	 validation accuracy: 0.9073
# Pruned 56 / 96% | Epoch #1	validation loss: 0.2438	 validation accuracy: 0.9073
# Pruned 56 / 96% | Epoch #2	validation loss: 0.2438	 validation accuracy: 0.9073
# Fine tuning the model
# Pruned 60 / 96% | Epoch #0	validation loss: 0.2497	 validation accuracy: 0.9051
# Pruned 60 / 96% | Epoch #1	validation loss: 0.2497	 validation accuracy: 0.9051
# Pruned 60 / 96% | Epoch #2	validation loss: 0.2497	 validation accuracy: 0.9051
# Fine tuning the model
# Pruned 64 / 96% | Epoch #0	validation loss: 0.2466	 validation accuracy: 0.9063
# Pruned 64 / 96% | Epoch #1	validation loss: 0.2466	 validation accuracy: 0.9063
# Pruned 64 / 96% | Epoch #2	validation loss: 0.2466	 validation accuracy: 0.9063
# Fine tuning the model
# Pruned 68 / 96% | Epoch #0	validation loss: 0.2485	 validation accuracy: 0.9065
# Pruned 68 / 96% | Epoch #1	validation loss: 0.2485	 validation accuracy: 0.9065
# Pruned 68 / 96% | Epoch #2	validation loss: 0.2485	 validation accuracy: 0.9065
# Fine tuning the model
# Pruned 72 / 96% | Epoch #0	validation loss: 0.2541	 validation accuracy: 0.9058
# Pruned 72 / 96% | Epoch #1	validation loss: 0.2541	 validation accuracy: 0.9058
# Pruned 72 / 96% | Epoch #2	validation loss: 0.2541	 validation accuracy: 0.9058
# Fine tuning the model
# Pruned 76 / 96% | Epoch #0	validation loss: 0.2659	 validation accuracy: 0.9024
# Pruned 76 / 96% | Epoch #1	validation loss: 0.2659	 validation accuracy: 0.9024
# Pruned 76 / 96% | Epoch #2	validation loss: 0.2659	 validation accuracy: 0.9024
# Fine tuning the model
# Pruned 80 / 96% | Epoch #0	validation loss: 0.2886	 validation accuracy: 0.8951
# Pruned 80 / 96% | Epoch #1	validation loss: 0.2886	 validation accuracy: 0.8951
# Pruned 80 / 96% | Epoch #2	validation loss: 0.2886	 validation accuracy: 0.8951
# Fine tuning the model
# Pruned 84 / 96% | Epoch #0	validation loss: 0.3323	 validation accuracy: 0.8792
# Pruned 84 / 96% | Epoch #1	validation loss: 0.3323	 validation accuracy: 0.8792
# Pruned 84 / 96% | Epoch #2	validation loss: 0.3323	 validation accuracy: 0.8792
# Fine tuning the model
# Pruned 88 / 96% | Epoch #0	validation loss: 0.4372	 validation accuracy: 0.8411
# Pruned 88 / 96% | Epoch #1	validation loss: 0.4372	 validation accuracy: 0.8411
# Pruned 88 / 96% | Epoch #2	validation loss: 0.4372	 validation accuracy: 0.8411
# Fine tuning the model
# Pruned 92 / 96% | Epoch #0	validation loss: 0.8242	 validation accuracy: 0.7113
# Pruned 92 / 96% | Epoch #1	validation loss: 0.8242	 validation accuracy: 0.7113
# Pruned 92 / 96% | Epoch #2	validation loss: 0.8242	 validation accuracy: 0.7113
# Fine tuning the model
# Pruned 96 / 96% | Epoch #0	validation loss: 1.5288	 validation accuracy: 0.4237
# Pruned 96 / 96% | Epoch #1	validation loss: 1.5288	 validation accuracy: 0.4237
# Pruned 96 / 96% | Epoch #2	validation loss: 1.5288	 validation accuracy: 0.4237
# Target total pruning: 0.96, pruning_step: 0.04, method: L1Unstructured, finetune_epochs: 4
# Fine tuning the model
# Pruned 4 / 96% | Epoch #0	validation loss: 0.2378	 validation accuracy: 0.9088
# Pruned 4 / 96% | Epoch #1	validation loss: 0.2378	 validation accuracy: 0.9088
# Pruned 4 / 96% | Epoch #2	validation loss: 0.2378	 validation accuracy: 0.9088
# Pruned 4 / 96% | Epoch #3	validation loss: 0.2378	 validation accuracy: 0.9088
# Fine tuning the model
# Pruned 8 / 96% | Epoch #0	validation loss: 0.2377	 validation accuracy: 0.9087
# Pruned 8 / 96% | Epoch #1	validation loss: 0.2377	 validation accuracy: 0.9087
# Pruned 8 / 96% | Epoch #2	validation loss: 0.2377	 validation accuracy: 0.9087
# Pruned 8 / 96% | Epoch #3	validation loss: 0.2377	 validation accuracy: 0.9087
# Fine tuning the model
# Pruned 12 / 96% | Epoch #0	validation loss: 0.2380	 validation accuracy: 0.9088
# Pruned 12 / 96% | Epoch #1	validation loss: 0.2380	 validation accuracy: 0.9088
# Pruned 12 / 96% | Epoch #2	validation loss: 0.2380	 validation accuracy: 0.9088
# Pruned 12 / 96% | Epoch #3	validation loss: 0.2380	 validation accuracy: 0.9088
# Fine tuning the model
# Pruned 16 / 96% | Epoch #0	validation loss: 0.2379	 validation accuracy: 0.9091
# Pruned 16 / 96% | Epoch #1	validation loss: 0.2379	 validation accuracy: 0.9091
# Pruned 16 / 96% | Epoch #2	validation loss: 0.2379	 validation accuracy: 0.9091
# Pruned 16 / 96% | Epoch #3	validation loss: 0.2379	 validation accuracy: 0.9091
# Fine tuning the model
# Pruned 20 / 96% | Epoch #0	validation loss: 0.2376	 validation accuracy: 0.9088
# Pruned 20 / 96% | Epoch #1	validation loss: 0.2376	 validation accuracy: 0.9088
# Pruned 20 / 96% | Epoch #2	validation loss: 0.2376	 validation accuracy: 0.9088
# Pruned 20 / 96% | Epoch #3	validation loss: 0.2376	 validation accuracy: 0.9088
# Fine tuning the model
# Pruned 24 / 96% | Epoch #0	validation loss: 0.2373	 validation accuracy: 0.9083
# Pruned 24 / 96% | Epoch #1	validation loss: 0.2373	 validation accuracy: 0.9083
# Pruned 24 / 96% | Epoch #2	validation loss: 0.2373	 validation accuracy: 0.9083
# Pruned 24 / 96% | Epoch #3	validation loss: 0.2373	 validation accuracy: 0.9083
# Fine tuning the model
# Pruned 28 / 96% | Epoch #0	validation loss: 0.2365	 validation accuracy: 0.9084
# Pruned 28 / 96% | Epoch #1	validation loss: 0.2365	 validation accuracy: 0.9084
# Pruned 28 / 96% | Epoch #2	validation loss: 0.2365	 validation accuracy: 0.9084
# Pruned 28 / 96% | Epoch #3	validation loss: 0.2365	 validation accuracy: 0.9084
# Fine tuning the model
# Pruned 32 / 96% | Epoch #0	validation loss: 0.2370	 validation accuracy: 0.9084
# Pruned 32 / 96% | Epoch #1	validation loss: 0.2370	 validation accuracy: 0.9084
# Pruned 32 / 96% | Epoch #2	validation loss: 0.2370	 validation accuracy: 0.9084
# Pruned 32 / 96% | Epoch #3	validation loss: 0.2370	 validation accuracy: 0.9084
# Fine tuning the model
# Pruned 36 / 96% | Epoch #0	validation loss: 0.2387	 validation accuracy: 0.9074
# Pruned 36 / 96% | Epoch #1	validation loss: 0.2387	 validation accuracy: 0.9074
# Pruned 36 / 96% | Epoch #2	validation loss: 0.2387	 validation accuracy: 0.9074
# Pruned 36 / 96% | Epoch #3	validation loss: 0.2387	 validation accuracy: 0.9074
# Fine tuning the model
# Pruned 40 / 96% | Epoch #0	validation loss: 0.2384	 validation accuracy: 0.9078
# Pruned 40 / 96% | Epoch #1	validation loss: 0.2384	 validation accuracy: 0.9078
# Pruned 40 / 96% | Epoch #2	validation loss: 0.2384	 validation accuracy: 0.9078
# Pruned 40 / 96% | Epoch #3	validation loss: 0.2384	 validation accuracy: 0.9078
# Fine tuning the model
# Pruned 44 / 96% | Epoch #0	validation loss: 0.2398	 validation accuracy: 0.9085
# Pruned 44 / 96% | Epoch #1	validation loss: 0.2398	 validation accuracy: 0.9085
# Pruned 44 / 96% | Epoch #2	validation loss: 0.2398	 validation accuracy: 0.9085
# Pruned 44 / 96% | Epoch #3	validation loss: 0.2398	 validation accuracy: 0.9085
# Fine tuning the model
# Pruned 48 / 96% | Epoch #0	validation loss: 0.2421	 validation accuracy: 0.9064
# Pruned 48 / 96% | Epoch #1	validation loss: 0.2421	 validation accuracy: 0.9064
# Pruned 48 / 96% | Epoch #2	validation loss: 0.2421	 validation accuracy: 0.9064
# Pruned 48 / 96% | Epoch #3	validation loss: 0.2421	 validation accuracy: 0.9064
# Fine tuning the model
# Pruned 52 / 96% | Epoch #0	validation loss: 0.2421	 validation accuracy: 0.9073
# Pruned 52 / 96% | Epoch #1	validation loss: 0.2421	 validation accuracy: 0.9073
# Pruned 52 / 96% | Epoch #2	validation loss: 0.2421	 validation accuracy: 0.9073
# Pruned 52 / 96% | Epoch #3	validation loss: 0.2421	 validation accuracy: 0.9073
# Fine tuning the model
# Pruned 56 / 96% | Epoch #0	validation loss: 0.2438	 validation accuracy: 0.9073
# Pruned 56 / 96% | Epoch #1	validation loss: 0.2438	 validation accuracy: 0.9073
# Pruned 56 / 96% | Epoch #2	validation loss: 0.2438	 validation accuracy: 0.9073
# Pruned 56 / 96% | Epoch #3	validation loss: 0.2438	 validation accuracy: 0.9073
# Fine tuning the model
# Pruned 60 / 96% | Epoch #0	validation loss: 0.2497	 validation accuracy: 0.9051
# Pruned 60 / 96% | Epoch #1	validation loss: 0.2497	 validation accuracy: 0.9051
# Pruned 60 / 96% | Epoch #2	validation loss: 0.2497	 validation accuracy: 0.9051
# Pruned 60 / 96% | Epoch #3	validation loss: 0.2497	 validation accuracy: 0.9051
# Fine tuning the model
# Pruned 64 / 96% | Epoch #0	validation loss: 0.2466	 validation accuracy: 0.9063
# Pruned 64 / 96% | Epoch #1	validation loss: 0.2466	 validation accuracy: 0.9063
# Pruned 64 / 96% | Epoch #2	validation loss: 0.2466	 validation accuracy: 0.9063
# Pruned 64 / 96% | Epoch #3	validation loss: 0.2466	 validation accuracy: 0.9063
# Fine tuning the model
# Pruned 68 / 96% | Epoch #0	validation loss: 0.2485	 validation accuracy: 0.9065
# Pruned 68 / 96% | Epoch #1	validation loss: 0.2485	 validation accuracy: 0.9065
# Pruned 68 / 96% | Epoch #2	validation loss: 0.2485	 validation accuracy: 0.9065
# Pruned 68 / 96% | Epoch #3	validation loss: 0.2485	 validation accuracy: 0.9065
# Fine tuning the model
# Pruned 72 / 96% | Epoch #0	validation loss: 0.2541	 validation accuracy: 0.9058
# Pruned 72 / 96% | Epoch #1	validation loss: 0.2541	 validation accuracy: 0.9058
# Pruned 72 / 96% | Epoch #2	validation loss: 0.2541	 validation accuracy: 0.9058
# Pruned 72 / 96% | Epoch #3	validation loss: 0.2541	 validation accuracy: 0.9058
# Fine tuning the model
# Pruned 76 / 96% | Epoch #0	validation loss: 0.2659	 validation accuracy: 0.9024
# Pruned 76 / 96% | Epoch #1	validation loss: 0.2659	 validation accuracy: 0.9024
# Pruned 76 / 96% | Epoch #2	validation loss: 0.2659	 validation accuracy: 0.9024
# Pruned 76 / 96% | Epoch #3	validation loss: 0.2659	 validation accuracy: 0.9024
# Fine tuning the model
# Pruned 80 / 96% | Epoch #0	validation loss: 0.2886	 validation accuracy: 0.8951
# Pruned 80 / 96% | Epoch #1	validation loss: 0.2886	 validation accuracy: 0.8951
# Pruned 80 / 96% | Epoch #2	validation loss: 0.2886	 validation accuracy: 0.8951
# Pruned 80 / 96% | Epoch #3	validation loss: 0.2886	 validation accuracy: 0.8951
# Fine tuning the model
# Pruned 84 / 96% | Epoch #0	validation loss: 0.3323	 validation accuracy: 0.8792
# Pruned 84 / 96% | Epoch #1	validation loss: 0.3323	 validation accuracy: 0.8792
# Pruned 84 / 96% | Epoch #2	validation loss: 0.3323	 validation accuracy: 0.8792
# Pruned 84 / 96% | Epoch #3	validation loss: 0.3323	 validation accuracy: 0.8792
# Fine tuning the model
# Pruned 88 / 96% | Epoch #0	validation loss: 0.4372	 validation accuracy: 0.8411
# Pruned 88 / 96% | Epoch #1	validation loss: 0.4372	 validation accuracy: 0.8411
# Pruned 88 / 96% | Epoch #2	validation loss: 0.4372	 validation accuracy: 0.8411
# Pruned 88 / 96% | Epoch #3	validation loss: 0.4372	 validation accuracy: 0.8411
# Fine tuning the model
# Pruned 92 / 96% | Epoch #0	validation loss: 0.8242	 validation accuracy: 0.7113
# Pruned 92 / 96% | Epoch #1	validation loss: 0.8242	 validation accuracy: 0.7113
# Pruned 92 / 96% | Epoch #2	validation loss: 0.8242	 validation accuracy: 0.7113
# Pruned 92 / 96% | Epoch #3	validation loss: 0.8242	 validation accuracy: 0.7113
# Fine tuning the model
# Pruned 96 / 96% | Epoch #0	validation loss: 1.5288	 validation accuracy: 0.4237
# Pruned 96 / 96% | Epoch #1	validation loss: 1.5288	 validation accuracy: 0.4237
# Pruned 96 / 96% | Epoch #2	validation loss: 1.5288	 validation accuracy: 0.4237
# Pruned 96 / 96% | Epoch #3	validation loss: 1.5288	 validation accuracy: 0.4237
